# %%
# %reload_ext autoreload
# %autoreload 2

import dut_func as dut
import serial
import time
import struct
import numpy as np
# from bitarray import bitarray
from bitstring import BitArray
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
import dut_a0 as a0

from misc import *

# dut.drv.serUSB = 'COM19'
drv = dut.drv

ser = serial.Serial('COM3', 9600, timeout=1)
dut.connect(ser)

# %%
dut.power_on()
# Out:
# DAC initialized to a span from -5 V to 5 V

# %%
ar=2
r=31
c=0


Vreads = np.arange(0, 0.5, 0.01)
# Vgates = np.arange(0,5,0.5)
# Vgates = [1, 1.1, 1.2, 1.3, 1.4, 1.5, 5]
# Vgates = [4, 3, 2, 1.5]
Vgates = [5]
Vref = 0.5

volts_set = []

for Vgate in Vgates:
    print(f'{Vgate:.2f}', end='-')
    volts = []
    for vread in Vreads:
        volts.append( a0.read_single_int(vread, Vgate, array=ar, row=r, col=c, gain=2, Vref = Vref) )
    volts_set.append(volts)
    
for volts in volts_set:
    plt.plot(Vreads, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('V_device')
plt.ylabel('Caculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)
# Out:
# 5.00-

# %%
ar=2
r=31
c=0


Vreads = np.arange(0, 0.5, 0.01)
# Vgates = np.arange(0,5,0.5)
# Vgates = [1, 1.1, 1.2, 1.3, 1.4, 1.5, 5]
# Vgates = [4, 3, 2, 1.5]
Vgates = [5]
Vref = 0.5

volts_set = []

for Vgate in Vgates:
    print(f'{Vgate:.2f}', end='-')
    volts = []
    for vread in Vreads:
        volts.append( a0.read_single(vread, Vgate, array=ar, row=r, col=c, gain=2) )
    volts_set.append(volts)
    
for volts in volts_set:
    plt.plot(Vreads, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('V_device')
plt.ylabel('Caculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)
# Out:
# 5.00-

# %%
ar=2
r=31
c=0

Vreset = np.arange(0.5, 1.2, 0.1)
Vgate = 5
Vread = 0.2
volts = []

for Vs in Vreset:
    a0.reset_single_int(Vs, Vgate, array=ar, row=r, col=c)
    volts.append( a0.read_single_int(Vread, Vgate, array=ar, row=r, col=c, gain=2) )
    

plt.plot(Vreset, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('Vreset')
plt.ylabel('Calculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2224971533eb> in <module>
#      13
#      14
# ---> 15 plt.plot(Vset, [i* 1e6 for i in volts], '.-')
#      16
#      17 plt.xlabel('Vreset')
#
# NameError: name 'Vset' is not defined

# %%
plt.plot(Vreset, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('Vreset')
plt.ylabel('Calculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)

# %%
ar=2
r=31
c=0


Vreads = np.arange(0, 0.5, 0.01)
# Vgates = np.arange(0,5,0.5)
# Vgates = [1, 1.1, 1.2, 1.3, 1.4, 1.5, 5]
# Vgates = [4, 3, 2, 1.5]
Vgates = [5]
Vref = 0.5

volts_set = []

for Vgate in Vgates:
    print(f'{Vgate:.2f}', end='-')
    volts = []
    for vread in Vreads:
        volts.append( a0.read_single_int(vread, Vgate, array=ar, row=r, col=c, gain=2, Vref = Vref) )
    volts_set.append(volts)
    
for volts in volts_set:
    plt.plot(Vreads, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('V_device')
plt.ylabel('Caculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)
# Out:
# 5.00-

# %%
ar=2
r=31
c=0

Vreset = np.arange(0.5, 1.5, 0.1)
Vgate = 5
Vread = 0.2
volts = []

for Vs in Vreset:
    a0.reset_single_int(Vs, Vgate, array=ar, row=r, col=c)
    volts.append( a0.read_single_int(Vread, Vgate, array=ar, row=r, col=c, gain=2) )
    

plt.plot(Vreset, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('Vreset')
plt.ylabel('Calculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)

# %%
ar=2
r=31
c=0


Vreads = np.arange(0, 0.5, 0.01)
# Vgates = np.arange(0,5,0.5)
# Vgates = [1, 1.1, 1.2, 1.3, 1.4, 1.5, 5]
# Vgates = [4, 3, 2, 1.5]
Vgates = [5]
Vref = 0.5

volts_set = []

for Vgate in Vgates:
    print(f'{Vgate:.2f}', end='-')
    volts = []
    for vread in Vreads:
        volts.append( a0.read_single_int(vread, Vgate, array=ar, row=r, col=c, gain=3, Vref = Vref) )
    volts_set.append(volts)
    
for volts in volts_set:
    plt.plot(Vreads, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('V_device')
plt.ylabel('Caculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)
# Out:
# 5.00-

# %%
ar=2
r=31
c=0


Vreads = np.arange(0, 0.5, 0.01)
# Vgates = np.arange(0,5,0.5)
# Vgates = [1, 1.1, 1.2, 1.3, 1.4, 1.5, 5]
# Vgates = [4, 3, 2, 1.5]
Vgates = [5]
Vref = 0.5

volts_set = []

for Vgate in Vgates:
    print(f'{Vgate:.2f}', end='-')
    volts = []
    for vread in Vreads:
        volts.append( a0.read_single_int(vread, Vgate, array=ar, row=r, col=c, gain=4, Vref = Vref) )
    volts_set.append(volts)
    
for volts in volts_set:
    plt.plot(Vreads, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('V_device')
plt.ylabel('Caculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)
# Out:
# 5.00-

# %%
Vread = 0.2

Vgate = 5
gain_list = [2]
n_array = 2

Gmap_all = []

N_ROW=16
N_COL=16

for gain in gain_list:
#     Gmap = []
    Gmap = np.zeros((N_ROW, N_COL))

    for r in range(16):
        if r%5 ==0:
            print(f'r={r}, ')
        Grow = []
        for c in range(16):
            curr = a0.read_single(Vread=Vread, Vgate=Vgate, array=n_array, row=4*r, col=4*c, gain=gain)
            Gmap[r,c] = curr / Vread 
    
    Gmap_all.append(Gmap)
# Out:
# r=0,
# r=5,
# r=10,
# r=15,

# %%
# plt.imshow(Gmap_all[0])
plt.imshow(Gmap)
plt.colorbar()
# plt.clim(0, 500e-6)

# %%
# %reload_ext autoreload
# %autoreload 2

import dut_func as dut
import serial
import time
import struct
import numpy as np
# from bitarray import bitarray
from bitstring import BitArray
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
import dut_a0 as a0

from misc import *

# %%
Vreset = np.arange(0.5, 1.5, 0.1)
Vgate = 500

Vread = 0.2
volts = []

for Vs in Vreset:
    #a0.reset_single_int(Vs, Vgate, array=ar, row=r, col=c)
    volts.append(Vs)
    

plt.plot(Vreset, [i* 1 for i in volts], '.-')
    
plt.xlabel('Vreset')
plt.ylabel('Calculated current (uA)')
plt.grid(True, alpha=0.3)

# %%
numGvals = 32
numReps = 3
rows = np.linspace(0,numGvals-1,numGvals)
cols = np.linspace(0,numReps-1,numReps)

VgateON = np.arange(0.4, 2.1, 0.1)
VgateOFF = np.arange(5.0, 5.5, 0.5)
VappliedON = np.arange(0.4, 4.15, 0.25)
VappliedOFF = np.arange(0.4, 3.65, 0.25)

Gtarget = np.linspace(2e-6, 200e-6,numGvals)
Vread = 0.2
volts = []

for Vs in Vreset:
    #a0.reset_single_int(Vs, Vgate, array=ar, row=r, col=c)
    volts.append(Vs)
    

plt.plot(Vreset, [i* 1 for i in volts], '.-')
    
plt.xlabel('Vreset')
plt.ylabel('Calculated current (uA)')
plt.grid(True, alpha=0.3)

# %%
import dut_func as dut
import serial
import time
import struct
import numpy as np
# from bitarray import bitarray
from bitstring import BitArray
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
import dut_a0 as a0

from misc import *

# %%
Vreset = np.arange(0.5, 1.5, 0.1)
Vgate = 500

Vread = 0.2
volts = []

for Vs in Vreset:
    #a0.reset_single_int(Vs, Vgate, array=ar, row=r, col=c)
    volts.append(Vs)
    

plt.plot(Vreset, [i* 1 for i in volts], '.-')
    
plt.xlabel('Vreset')
plt.ylabel('Calculated current (uA)')
plt.grid(True, alpha=0.3)

# %%
from np import random
from np.random import Generator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-183a12b0395b> in <module>
# ----> 1 from np import random
#       2 from np.random import Generator
#
# ModuleNotFoundError: No module named 'np'

# %%
from np import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d816fcaad8b7> in <module>
# ----> 1 from np import random
#
# ModuleNotFoundError: No module named 'np'

# %%
from numpy import random

# %%
numpy.random.Generator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-2f7ebbe44340> in <module>
# ----> 1 from np.random import Generator
#
# ModuleNotFoundError: No module named 'np'

# %%
random.standard_normal()
# Out:
# 1.980850776396778
