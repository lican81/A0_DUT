# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from IPython import display

from tqdm.notebook import tqdm

# %matplotlib inline
# %config InlineBackend.figure_formats = ['retina']

import matplotlib
matplotlib.rcParams['font.sans-serif'] = "Arial"
matplotlib.rcParams['figure.dpi'] = 80
# matplotlib.rcParams['figure.figsize'] = [17, 4]
matplotlib.rcParams['axes.grid'] = True

# %%
# !pip install --upgrade pip --proxy=https://web-proxy.labs.hpecorp.net:8088
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)

# %%
import sys
sys.path.insert(0, '../')

from lib_data import *
from lib_nn_dpe import NN_dpe

# %%
load_workspace(vars(), 'data/20190821-051552-mnist_xs')
load_workspace(vars(), 'data/20200130-100802-mnist_config')
# Out:
# Loaded: In, Out, weights, train_images, train_labels, test_images, test_labels, g, img_idx, image, vectors, outputs, software, c, x, y, mat_contents, finalGconv, g1, g2, linear_factors_conv, xs, acc, result, x1,
# Loaded: xs, new_lin_cor_fc1, new_lin_cor_fc2, lin_cor_conv, finalGfc, finalGconv, weights,

# %%
del train_images
del train_labels
# del test_images
# del test_labels
del xs

# %%
from lib_ecc import *

# %% [markdown]
# ## Construct NN

# %%
nn = NN_dpe(weights)

nn.Gratio = 100e-6

plt.imshow(nn.Mconv); plt.colorbar()

# %%
nn.Gratio
# Out:
# 0.0001

# %% [markdown]
# ## ECC matrix

# %%
from dpeECC import dpeECC

delta = 1
Delta = 8 * delta

m = nn.Mconv.shape[0]
k = nn.Mconv.shape[1]

print(k, np.ceil(np.sqrt(k+1))+1, 2*k/(np.floor(Delta/(2*delta))-2))

ecc = dpeECC(nn.Mconv, delta, Delta)
M_conv_ecc = ecc.encode()

print('The number of redundancy column is chosen to be the smallest even number', ecc.r)
print(M_conv_ecc.shape)

plt.imshow(M_conv_ecc); plt.colorbar()
# Out:
# 7 4.0 7.0
# The number of redundancy column is chosen to be the smallest even number 8
# (26, 15)

# %% [markdown]
# Convert to conductance

# %%
G_conv_ecc = weight2conductance(M_conv_ecc)
G_parity_ecc = weight2conductance(ecc.H.T)

plt.figure(1)
plt.imshow(G_conv_ecc * 1e6); plt.colorbar()

plt.figure(2)
plt.imshow(G_parity_ecc * 1e6); plt.colorbar()

# %% [markdown]
# ## Program the array

# %%
from dpe import DPE

dpe = DPE('COM9')
dpe.set_clock(50)
# Out:
# DAC initialized to a span from -10 V to 10 V
# Setting vrefs to default
# Setting ADC_CK freq=50000.0kHz
# Setting CK_ARRAY freq=50000.0kHz

# %%
g = dpe.read(1, method='slow')
plt.imshow(g)
# Out:
# ....

# %%
Gtarget = np.zeros((64,64))

rs = 0
cs = 0

Gtarget[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]] = G_conv_ecc

Gtarget[rs+G_conv_ecc.shape[0]: rs+G_conv_ecc.shape[0]*2, 
        cs+G_conv_ecc.shape[1]: cs+G_conv_ecc.shape[1]*2] = G_conv_ecc

Msel = np.ones((64,64))
# Msel[20:,20:] = 1
# Msel[Gtarget<4e-6] = 0

# Msel = np.zeros((64,64))
# Msel[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]] = 1
# Msel[rs+G_conv_ecc.shape[0]: rs+G_conv_ecc.shape[0]*2, 
#         cs+G_conv_ecc.shape[1]: cs+G_conv_ecc.shape[1]*2] = 1

# %%
plt.imshow(Gtarget)
plt.colorbar()

plt.figure()
plt.imshow(Msel)
plt.colorbar()

# %%
data = dpe.tune_conductance(1,  Gtarget, saveHistory=True, maxSteps=1000, method='slow',
                           vSetRamp=[1, 3, 0.25], vGateSetRamp=[0.5, 1.4, 0.05],
                           vResetRamp=[0.3, 1.5, 0.05], vGateResetRamp=[5.0, 5.5, 0.5], 
                           Twidth=10e-6, TwidthReset=1e-3,  Msel=Msel, Gtol_in=4e-6, Gtol_out=10e-6, numReads=1)
# Out:
# Start programming, step=409, maxBound=8 yield= 87.94% - 95.19%
# 250.0 devices to be programmed...reset 89.0, set 169.0
# Setting 162 devices...
# Programming with external timing Twidth=10.000 us
# Resetting 89 devices...
# Programming with external timing Twidth=1000.000 us

# %%
g2 = dpe.read(1, method='slow')
plt.imshow(g2*1e6); plt.colorbar()
plt.grid(False)
# Out:
# ....

# %%
# g2 = dpe.read(1, method='slow')

# plt.imshow(g2)
# # plt.imshow(g2[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]]*1e6); plt.colorbar()
# plt.grid(False)
# plt.colorbar()

# %%
plt.imshow((g2-Gtarget)[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]]* 1e6 )
plt.colorbar()

# %%
data = dpe.tune_conductance(1,  Gtarget, saveHistory=True, maxSteps=300, method='slow',
                           vSetRamp=[1, 3, 0.25], vGateSetRamp=[0.5, 1.4, 0.05],
                           vResetRamp=[0.3, 2.2, 0.05], vGateResetRamp=[5.0, 5.5, 0.5], 
                           Twidth=10e-6, TwidthReset=10e-3,  Msel=Msel, Gtol_in=50e-6, Gtol_out=110e-6, numReads=1)
# Out:
# Start programming, step=11, maxBound=0 yield= 99.68% - 100.00%
# 6.0 devices to be programmed...reset 5.0, set 1.0
# Setting 1 devices...
# Programming with external timing Twidth=10.000 us
# Resetting 5 devices...
# Programming with external timing Twidth=10000.000 us
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-055a722fad50> in <module>
#       2                            vSetRamp=[1, 3, 0.25], vGateSetRamp=[0.5, 1.4, 0.05],
#       3                            vResetRamp=[0.3, 2.2, 0.05], vGateResetRamp=[5.0, 5.5, 0.5],
# ----> 4                            Twidth=10e-6, TwidthReset=10e-3,  Msel=Msel, Gtol_in=50e-6, Gtol_out=110e-6, numReads=1)
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in tune_conductance(self, array, Gtarget, **kwargs)
#     323             # Read conductance and take average
#     324             Gread = self.read(array, Tdly=Tdly, method=method, numReads=numReads,
# --> 325                               Msel=Msel)  # Msel parameter only applies to single read
#     326
#     327             # Determine the devices to be programmed..
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in wrapper_with_ser(*args, **kwargs)
#      27
#      28             ts = time.time()
# ---> 29             result = func(*args, **kwargs)
#      30             #print(f'[INFO] Elapsed time = {time.time()-ts:.2f}s')
#      31
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in read(self, array, Vread, gain, method, numReads, **kwargs)
#      96         for _ in range(numReads):
#      97             if method == 'slow':
# ---> 98                 Gmap = a0.pic_read_batch(array, Vread=Vread, gain=gain, **kwargs) / Vread
#      99             elif method == 'fast':
#     100                 input = [0x1 << i for i in range(self.shape[0])]
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dut_a0.py in pic_read_batch(array, raw, **kwargs)
#     178     r = 0
#     179     while True:
# --> 180         value = drv.ser.read(2 * 256)
#     181         if len(value) == 0:
#     182             print(f'.', end='')
#
# c:\users\localuser\.venvs\py37\lib\site-packages\serial\serialwin32.py in read(self, size)
#     288                     ctypes.byref(self._overlapped_read),
#     289                     ctypes.byref(rc),
# --> 290                     True)
#     291                 if not result_ok:
#     292                     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:

# %%
Msel = np.zeros((64,64))
Msel[20:,20:] = 1

# %%
gdiff = (g2-Gtarget)[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]]* 1e6 

_ = plt.hist((gdiff.reshape(-1)), 100)

plt.xlabel('Gerr ($\mu S$)')
plt.ylabel('Count')

# plt.xlim((-30, 30))
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## CNN test

# %%
rs = G_conv_ecc.shape[0]
cs = G_conv_ecc.shape[1]

i = 0

N_IMG = 10

vectors_list = []
output_list = []

for img, lab in tqdm(zip(test_images, test_labels), total=N_IMG):
    i += 1

    vectors = nn._conv_flattern(img)
    output = dpe.multiply(
            1, 
            vectors, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500) / (nn.Gratio)
#             c_sel=[0, 0+G_conv_ecc.shape[1]], 
#             r_start=0, mode=0, Tdly=500) / (nn.Gratio)
    
    vectors_list.append(vectors)
    output_list.append(output)
    
    if i >= N_IMG:
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
vectors = np.concatenate(vectors_list, axis=1)
output = np.concatenate(output_list, axis=0)

# %%
output_soft = vectors.T @ G_conv_ecc / nn.Gratio

# %%
plt.subplot(121)
plt.imshow(output_soft[:100])

plt.subplot(122)
plt.imshow(output[:100])

print(output.shape, output_soft.shape)
# Out:
# (4000, 30) (4000, 30)

# %% [markdown]
# Core output

# %%
for c in range(output.shape[1]):
    plt.plot(output_soft[:,c], output[:,c], '.')

# %% [markdown]
# Linear correction

# %%
lin_cor_conv = []
for c in range(output.shape[1]):
    lin_cor_conv.append( np.polyfit(output[:,c], output_soft[:,c], 1))
    
output_cor = dpe.lin_corr(output, lin_cor_conv)

# %%
for c in range(output.shape[1]):
    plt.plot(output_soft[:,c], output_cor[:,c], '.')

# %%
_ = plt.hist((output_cor - output_soft ).reshape(-1), 100)
plt.xlabel('Output error')

plt.yscale('log')

# %%
# save_workspace(vars(), note='programming1', skip_mat=True)

# %% [markdown]
# # CNN test fixed gain

# %%
rs = G_conv_ecc.shape[0]
cs = G_conv_ecc.shape[1]

i = 0

N_IMG = 10

vectors_list = []
output_list = []

for img, lab in tqdm(zip(test_images, test_labels), total=N_IMG):
    i += 1

    vectors = nn._conv_flattern(img)
    output = dpe.multiply(
            1, 
            vectors, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=1) / (nn.Gratio)
#             c_sel=[0, 0+G_conv_ecc.shape[1]], 
#             r_start=0, mode=0, Tdly=500) / (nn.Gratio)
    
    vectors_list.append(vectors)
    output_list.append(output)
    
    if i >= N_IMG:
        break
        
vectors = np.concatenate(vectors_list, axis=1)
output = np.concatenate(output_list, axis=0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
output_soft = vectors.T @ G_conv_ecc / nn.Gratio

plt.subplot(121)
plt.imshow(output_soft[:100])

plt.subplot(122)
plt.imshow(output[:100])

print(output.shape, output_soft.shape)
# Out:
# (4000, 30) (4000, 30)

# %%
output.shape, output_soft.shape
# Out:
# ((4000, 30), (4000, 30))

# %%
for c in range(output.shape[1]):
    plt.plot(output_soft[:,c], output[:,c], '.')
    
plt.ylabel('Experimental DPE output')
plt.xlabel('Expected output')
# Out:
# Text(0.5, 0, 'Expected output')

# %%
lin_cor_conv = []
for c in range(output.shape[1]):
    lin_cor_conv.append( np.polyfit(output[:,c], output_soft[:,c], 1))
    
output_cor = dpe.lin_corr(output, lin_cor_conv)

# %%
for c in range(output.shape[1]):
    plt.plot(output_soft[:,c], output_cor[:,c], '.')

# %%
_ = plt.hist((output_cor - output_soft ).reshape(-1), 100)
plt.xlabel('Output error')

plt.yscale('log')

# %% [markdown]
# ## Linear correction for different gains

# %%
rs = G_conv_ecc.shape[0]
cs = G_conv_ecc.shape[1]

i = 0

N_IMG = 10

gain_list = [1,2]

output_gain = []

for gain in tqdm(gain_list):
    vectors_list = []
    output_list = []

    for img, lab in tqdm(zip(test_images[:N_IMG], test_labels[:N_IMG]), total=N_IMG):
        i += 1

        vectors = nn._conv_flattern(img)
        output = dpe.multiply(
                1, 
                vectors, 
                c_sel=[cs, cs+G_conv_ecc.shape[1]], 
                r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)

        vectors_list.append(vectors)
        output_list.append(output)

    #     if i >= N_IMG:
    #         break

    vectors = np.concatenate(vectors_list, axis=1)
    output = np.concatenate(output_list, axis=0)
    
    output_gain.append(output.copy())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
gain_th = [
    5.82*30,
    5.82*6,
    5.82, #verified
    0.875,
    0.175
]

gain_value = np.zeros_like(output_soft)

# %%
output_soft = vectors.T @ G_conv_ecc / nn.Gratio

for i, gain in enumerate(gain_list):
    
    plt.figure(i+1)
    for c in range(output_gain[i].shape[1]):
        plt.plot(output_soft[:,c], output_gain[i][:,c], '.')
        
        
    gain_value[:,0] = gain_th[gain]
    plt.plot(output_soft[:,0], gain_value[:,0]* 0.95, '--')
    plt.plot(output_soft[:,0], gain_value[:,0]* 0.01, '--')
    
    plt.ylabel('Experimental DPE output')
    plt.xlabel('Expected output')

# %% [markdown]
# ## Fitting

# %%
lin_cor_gain = []

th_rel = [0.9, 0.02]

for i, output in enumerate(output_gain):
    output = output.copy()
    
    gain = gain_list[i]
    print(i, gain, gain_th[gain])
    
    output[output > gain_th[gain] * th_rel[0]] = np.nan
    output[output < gain_th[gain] * th_rel[1]] = np.nan
    
#     plt.figure(i+1)
#     for c in range(output_gain[i].shape[1]):
#         plt.plot(output_soft[:,c], output[:,c], '.')
        
    lin_cor = []
    for c in range(output.shape[1]):
        
        idx = np.isfinite(output[:,c]) & np.isfinite(output_soft[:,c])
        if sum(idx) > 0:
            lin_cor.append( np.polyfit(output[idx,c], output_soft[idx,c], 1))
        else:
            lin_cor.append(np.array([0, 0]))
            
    lin_cor_gain.append(lin_cor)
# Out:
# 0 1 34.92
# 1 2 5.82
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %% [markdown]
# ## Correction

# %%
output_cor = np.ones_like(output_soft) * 0

i = len(output_gain)
for output in output_gain[::-1]:
    i -= 1
    
    output = output.copy()
    gain = gain_list[i]
    print(i, gain, gain_th[gain])
    
    output[output > gain_th[gain] * th_rel[0]] = np.nan
    output[output < gain_th[gain] * th_rel[1]] = np.nan
    
    lin_cor = lin_cor_gain[i]
    
    for c in range(output.shape[1]):
        
        idx = np.isfinite(output[:,c])
        output_cor[idx,c] = output[idx,c] * lin_cor[c][0] + lin_cor[c][1]
# Out:
# 1 2 5.82
# 0 1 34.92
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %%
for c in range(output_cor.shape[1]):
    plt.plot(output_soft[:,c], output_cor[:,c], '.', alpha=0.2)

# %%
_ = plt.hist((output_cor - output_soft ).reshape(-1), 100)
plt.xlabel('Output error')

plt.yscale('log')

# %%
def lin_cor_gains(output_gain, lin_cor_gain):
    output_cor = np.ones_like(output_gain[0]) * 0

    i = len(output_gain)
    for output in output_gain[::-1]:
        i -= 1

        output = output.copy()
        gain = gain_list[i]

        output[output > gain_th[gain] * th_rel[0]] = np.nan
        output[output < gain_th[gain] * th_rel[1]] = np.nan

        lin_cor = lin_cor_gain[i]

        for c in range(output.shape[1]):

            idx = np.isfinite(output[:,c]) 
            output_cor[idx,c] = output[idx,c] * lin_cor[c][0] + lin_cor[c][1]
            
    return output_cor

# %%
output_cor = lin_cor_gains(output_gain, lin_cor_gain)
# Out:
# 1 2 5.82
# 0 1 34.92
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in less
#   del sys.path[0]

# %% [markdown]
# ## Plot the difference

# %%
delta = 0.15
Delta = 8 * delta

m = nn.Mconv.shape[0]
k = nn.Mconv.shape[1]

ecc = dpeECC(nn.Mconv, delta, Delta)

# %%
N_IMG = 100

y1_raw_list = []
y1_ecc_list = []
y1_soft_list = []

i = 0

n_detected = 0
n_corrected = 0
n_other = 0

for img, lab in tqdm(zip(test_images[:N_IMG], test_labels[:N_IMG]), total=N_IMG):
    vectors = nn._conv_flattern(img)
    
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)

    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1 = output[:, ::2] - output[:, 1::2]
    
    output_soft = vectors.T @ G_conv_ecc / nn.Gratio
    y1_soft = output_soft[:, ::2] - output_soft[:, 1::2]
    
    y1_raw_list.append(y1.copy())
    y1_soft_list.append(y1_soft.copy())
    
    # ECC
    S = (y1 @ G_parity_ecc / nn.Gratio)
    S = S[:, ::2] - S[:, 1::2]

    for s, yy in zip(S, y1):
        ecc_loc, ecc_range = ecc.decode_w_syndrome(s)
        
        if ecc_loc != -1:
            if ecc_loc == -2:
                # Detected but could not be corrected
                n_detected += 1
                
            elif ecc_loc >=0:
                # Correct
                n_corrected += 1
                yy[ecc_loc] -= (ecc_range[0]+ecc_range[1])/2
            else:
                n_other += 1
                
    y1_ecc_list.append(y1.copy())
    
    k = nn.Gconv.shape[1] //2
    
    x = y1[:, :k]

    x = x.reshape(20, 20, -1)

    x1 = nn.relu(x)
    x1 = nn.max_pooling(x1)
    x1 = nn.flattern(x1)
    x1 = np.append(x1, 1)

    y = x1.T @ finalGfc
    y = y[::2] - y[1::2]

#     y_pred.append(y.argmax())
    
    print(y.argmax(), lab)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':
# 7 7
# 2 2
# 1 1
# 0 0
# 4 4
# 1 1
# 4 4
# 9 9
# 5 5
# 9 9
# 0 0
# 6 6
# 9 9
# 0 0
# 1 1
# 5 5
# 9 9
# 7 7
# 8 3
# 4 4
# 9 9
# 6 6
# 6 6
# 5 5
# 4 4
# 0 0
# 7 7
# 4 4
# 0 0
# 1 1
# 3 3
# 1 1
# 3 3
# 4 4
# 7 7
# 2 2
# 7 7
# 1 1
# 2 2
# 1 1
# 1 1
# 7 7
# 4 4
# 2 2
# 3 3
# 5 5
# 1 1
# 2 2
# 4 4
# 4 4
# 6 6
# 3 3
# 5 5
# 5 5
# 6 6
# 0 0
# 4 4
# 1 1
# 9 9
# 5 5
# 7 7
# 8 8
# 9 9
# 3 3
# 7 7
# 4 4
# 6 6
# 4 4
# 3 3
# 0 0
# 7 7
# 0 0
# 2 2
# 9 9
# 1 1
# 7 7
# 3 3
# 2 2
# 9 9
# 7 7
# 7 7
# 6 6
# 2 2
# 7 7
# 8 8
# 4 4
# 7 7
# 3 3
# 6 6
# 1 1
# 3 3
# 6 6
# 9 9
# 3 3
# 1 1
# 4 4
# 1 1
# 7 7
# 6 6
# 9 9

# %%
save_workspace(vars(), note='multi-gain-fitting-100')
# Out:
# Saving In(<class 'list'>), Out(<class 'dict'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), mat_contents(<class 'dict'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'float'>), Delta(<class 'float'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), idx(<class 'numpy.ndarray'>), lin_cor(<class 'list'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), S(<class 'numpy.ndarray'>), s(<class 'numpy.ndarray'>), yy(<class 'numpy.ndarray'>), ecc_loc(<class 'int'>), y_pred(<class 'list'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), err_raw(<class 'numpy.ndarray'>), err_ecc(<class 'numpy.ndarray'>), to 20200623-230438-multi-gain-fitting-100.pkl
# Saving In(<class 'list'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'float'>), Delta(<class 'float'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), idx(<class 'numpy.ndarray'>), lin_cor(<class 'list'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), S(<class 'numpy.ndarray'>), s(<class 'numpy.ndarray'>), yy(<class 'numpy.ndarray'>), ecc_loc(<class 'int'>), y_pred(<class 'list'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), err_raw(<class 'numpy.ndarray'>), err_ecc(<class 'numpy.ndarray'>), to 20200623-230438-multi-gain-fitting-100.mat

# %%
load_workspace(vars(), filename='20200623-230438-multi-gain-fitting-100')
# Out:
# Loaded: In, Out, weights, test_images, test_labels, g, img_idx, image, vectors, outputs, software, c, x, y, mat_contents, finalGconv, g1, g2, linear_factors_conv, acc, result, x1, new_lin_cor_fc1, new_lin_cor_fc2, lin_cor_conv, finalGfc, delta, Delta, m, k, M_conv_ecc, G_conv_ecc, G_parity_ecc, rs, cs, i, N_IMG, vectors_list, output_list, img, output, output_soft, output_cor, gain_list, output_gain, gain, gain_th, gain_value, idx, lin_cor, lin_cor_gain, th_rel, y1_raw_list, y1_ecc_list, y1_soft_list, n_detected, n_corrected, n_other, y1, y1_soft, S, s, yy, ecc_loc, y_pred, y1_raw, y1_ecc, err_raw, err_ecc,

# %%
n_detected, n_corrected, n_other
# Out:
# (6917, 14168, 0)

# %%
y1_raw = np.array(y1_raw_list)
y1_soft = np.array(y1_soft_list)
y1_ecc = np.array(y1_ecc_list)

y1_raw.shape, y1_soft.shape, y1_ecc.shape
# Out:
# ((100, 400, 15), (100, 400, 15), (100, 400, 15))

# %%
plt.figure(figsize=(17, 6))

plt.subplot(1,2,1)

_ = plt.hist((y1_raw - y1_soft ).reshape(-1), 100)
plt.xlabel('Output error')
plt.yscale('log')
plt.xlim((-1.5,1.5))

plt.subplot(1,2,2)
_ = plt.hist((y1_ecc - y1_soft ).reshape(-1), 100)
plt.xlabel('Output error')
plt.yscale('log')
plt.xlim((-1.5,1.5))
# Out:
# (-1.5, 1.5)

# %%
err_raw = (y1_raw - y1_soft).reshape(-1)

np.std(err_raw)
# Out:
# 0.21585839136361998

# %%
err_ecc = (y1_ecc - y1_soft).reshape(-1)

np.std(err_ecc)
# Out:
# 0.21341056136780065

# %%
_ = plt.hist(abs(err_raw), density=True, histtype='step', cumulative=-1,
        label='RAW', bins=100)

_ = plt.hist(abs(err_ecc), density=True, histtype='step', cumulative=-1,
        label='ECC', bins=100)

plt.legend()

plt.yscale('log')

plt.xlabel('Absolute error')
plt.ylabel('Cummulative number of error')
# Out:
# Text(0, 0.5, 'Cummulative number of error')

# %% [markdown]
# ## Explore delta

# %%
from lib_ecc import *

# %%
y1_raw = np.array(y1_raw_list).reshape(-1, 15)
y1_soft = np.array(y1_soft_list).reshape(-1, 15)
# y1_ecc = np.array(y1_ecc_list).reshape()

# %%
delta_list = np.arange(0.02, 0.5, 0.02)

y1_ecc_list_list = []

for delta in tqdm(delta_list):
    y1_ecc_list = []
    
    Delta = 8 * delta
    ecc = dpeECC(nn.Mconv, delta, Delta)

#     for y1_raw in y1_raw_list:
    y1_ecc_list.append( correct_ecc(y1_raw, ecc) )
        
    y1_ecc_list_list.append(y1_ecc_list)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=24.0), HTML(value='')))

# %%
# output_soft = vectors.T @ G_conv_ecc / nn.Gratio
# y1_soft = output_soft[:, ::2] - output_soft[:, 1::2]

plt.figure(figsize=(17,20))

# for i in range(len(y1_list)):
for i in range(20):
    
    plt.subplot(5,4,i+1)

#     y1_raw = y1_raw_list[0]
    y1_ecc = y1_ecc_list_list[i]


    err_raw = (y1_raw - y1_soft).reshape(-1)
    err_ecc = (y1_ecc - y1_soft).reshape(-1)


    _ = plt.hist(abs(err_raw), density=True, histtype='step', cumulative=-1,
            label='RAW', bins=100)

    _ = plt.hist(abs(err_ecc), density=True, histtype='step', cumulative=-1,
            label='ECC', bins=100)

    plt.legend()

    plt.yscale('log')
    plt.xlabel('Absolute error')
    plt.ylabel('Cummulative number of error')
    
    plt.title(f'delta = {delta_list[i]:.2f}')
    
plt.tight_layout()
