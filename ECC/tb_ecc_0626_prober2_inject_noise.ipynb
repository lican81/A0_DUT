# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import numpy as np
from IPython import display

from tqdm.notebook import tqdm

# %matplotlib inline
# %config InlineBackend.figure_formats = ['retina']

import matplotlib
matplotlib.rcParams['font.sans-serif'] = "Arial"
matplotlib.rcParams['figure.dpi'] = 80
# matplotlib.rcParams['figure.figsize'] = [17, 4]
matplotlib.rcParams['axes.grid'] = True

# %%
# !pip install --upgrade pip --proxy=https://web-proxy.labs.hpecorp.net:8088
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=7, micro=4, releaselevel='final', serial=0)

# %%
import sys
sys.path.insert(0, '../')

from lib_data import *
from lib_nn_dpe import NN_dpe

# %%
load_workspace(vars(), 'data/20190821-051552-mnist_xs')
load_workspace(vars(), 'data/20200130-100802-mnist_config')
# Out:
# Loaded: In, Out, weights, train_images, train_labels, test_images, test_labels, g, img_idx, image, vectors, outputs, software, c, x, y, mat_contents, finalGconv, g1, g2, linear_factors_conv, xs, acc, result, x1,
# Loaded: xs, new_lin_cor_fc1, new_lin_cor_fc2, lin_cor_conv, finalGfc, finalGconv, weights,

# %%
del train_images
del train_labels
# del test_images
# del test_labels
del xs

# %%
from lib_ecc import *

# %% [markdown]
# ## Construct NN

# %%
nn = NN_dpe(weights)

nn.Gratio = 100e-6

plt.imshow(nn.Mconv); plt.colorbar()

# %%
nn.Gratio
# Out:
# 0.0001

# %% [markdown]
# ## ECC matrix

# %%
from dpeECC import dpeECC

delta = 1
Delta = 8 * delta

m = nn.Mconv.shape[0]
k = nn.Mconv.shape[1]

print(k, np.ceil(np.sqrt(k+1))+1, 2*k/(np.floor(Delta/(2*delta))-2))

ecc = dpeECC(nn.Mconv, delta, Delta)
M_conv_ecc = ecc.encode()

print('The number of redundancy column is chosen to be the smallest even number', ecc.r)
print(M_conv_ecc.shape)

plt.imshow(M_conv_ecc); plt.colorbar()
# Out:
# 7 4.0 7.0
# The number of redundancy column is chosen to be the smallest even number 8
# (26, 15)

# %% [markdown]
# Convert to conductance

# %%
G_conv_ecc = weight2conductance(M_conv_ecc)
G_parity_ecc = weight2conductance(ecc.H.T)

plt.figure(1)
plt.imshow(G_conv_ecc * 1e6); plt.colorbar()

plt.figure(2)
plt.imshow(G_parity_ecc * 1e6); plt.colorbar()

# %% [markdown]
# ## Program the array

# %%
from dpe import DPE

dpe = DPE('COM9')
dpe.set_clock(50)
# Out:
# DAC initialized to a span from -10 V to 10 V
# Setting vrefs to default
# Setting ADC_CK freq=50000.0kHz
# Setting CK_ARRAY freq=50000.0kHz

# %%
g = dpe.read(1, method='slow')
plt.imshow(g)
# Out:
# ....

# %%
Gtarget = np.zeros((64,64))

rs = 0
cs = 0

Gtarget[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]] = G_conv_ecc

Gtarget[rs+G_conv_ecc.shape[0]: rs+G_conv_ecc.shape[0]*2, 
        cs+G_conv_ecc.shape[1]: cs+G_conv_ecc.shape[1]*2] = G_conv_ecc

Gtarget[rs+G_conv_ecc.shape[0]*2: rs+G_conv_ecc.shape[0]*2+3, 
        cs+G_conv_ecc.shape[1]+9] = 100e-6

Msel = np.ones((64,64))
# Msel[20:,20:] = 1
# Msel[Gtarget<4e-6] = 0

# Msel = np.zeros((64,64))
# Msel[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]] = 1
# Msel[rs+G_conv_ecc.shape[0]: rs+G_conv_ecc.shape[0]*2, 
#         cs+G_conv_ecc.shape[1]: cs+G_conv_ecc.shape[1]*2] = 1

# %%
g[54,39] * 1e6
# Out:
# 19.843597262952102

# %%
plt.imshow(Gtarget)
plt.colorbar()

plt.figure()
plt.imshow(Msel)
plt.colorbar()

# %%
data = dpe.tune_conductance(1,  Gtarget, saveHistory=True, maxSteps=1000, method='slow',
                           vSetRamp=[1, 3, 0.25], vGateSetRamp=[0.5, 1.4, 0.05],
                           vResetRamp=[0.3, 1.5, 0.05], vGateResetRamp=[5.0, 5.5, 0.5], 
                           Twidth=10e-6, TwidthReset=1e-3,  Msel=Msel, Gtol_in=4e-6, Gtol_out=10e-6, numReads=1)
# Out:
# Start programming, step=999, maxBound=8 yield= 88.77% - 95.92%
# 214.0 devices to be programmed...reset 89.0, set 133.0
# Setting 126 devices...
# Programming with external timing Twidth=10.000 us
# Resetting 89 devices...
# Programming with external timing Twidth=1000.000 us

# %%
g = dpe.read(1, method='slow')
plt.imshow(g*1e6); plt.colorbar()
plt.grid(False)
# Out:
# ....

# %%
# g2 = dpe.read(1, method='slow')

# plt.imshow(g2)
# # plt.imshow(g2[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]]*1e6); plt.colorbar()
# plt.grid(False)
# plt.colorbar()


rs = G_conv_ecc.shape[0]
cs = G_conv_ecc.shape[1]

# %%
plt.imshow((g-Gtarget)[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]]* 1e6 )
plt.colorbar()

# %%
data = dpe.tune_conductance(1,  Gtarget, saveHistory=True, maxSteps=300, method='slow',
                           vSetRamp=[1, 3, 0.25], vGateSetRamp=[0.5, 1.4, 0.05],
                           vResetRamp=[0.3, 2.2, 0.05], vGateResetRamp=[5.0, 5.5, 0.5], 
                           Twidth=10e-6, TwidthReset=10e-3,  Msel=Msel, Gtol_in=50e-6, Gtol_out=110e-6, numReads=1)
# Out:
# Start programming, step=11, maxBound=0 yield= 99.68% - 100.00%
# 6.0 devices to be programmed...reset 5.0, set 1.0
# Setting 1 devices...
# Programming with external timing Twidth=10.000 us
# Resetting 5 devices...
# Programming with external timing Twidth=10000.000 us
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-055a722fad50> in <module>
#       2                            vSetRamp=[1, 3, 0.25], vGateSetRamp=[0.5, 1.4, 0.05],
#       3                            vResetRamp=[0.3, 2.2, 0.05], vGateResetRamp=[5.0, 5.5, 0.5],
# ----> 4                            Twidth=10e-6, TwidthReset=10e-3,  Msel=Msel, Gtol_in=50e-6, Gtol_out=110e-6, numReads=1)
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in tune_conductance(self, array, Gtarget, **kwargs)
#     323             # Read conductance and take average
#     324             Gread = self.read(array, Tdly=Tdly, method=method, numReads=numReads,
# --> 325                               Msel=Msel)  # Msel parameter only applies to single read
#     326
#     327             # Determine the devices to be programmed..
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in wrapper_with_ser(*args, **kwargs)
#      27
#      28             ts = time.time()
# ---> 29             result = func(*args, **kwargs)
#      30             #print(f'[INFO] Elapsed time = {time.time()-ts:.2f}s')
#      31
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in read(self, array, Vread, gain, method, numReads, **kwargs)
#      96         for _ in range(numReads):
#      97             if method == 'slow':
# ---> 98                 Gmap = a0.pic_read_batch(array, Vread=Vread, gain=gain, **kwargs) / Vread
#      99             elif method == 'fast':
#     100                 input = [0x1 << i for i in range(self.shape[0])]
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dut_a0.py in pic_read_batch(array, raw, **kwargs)
#     178     r = 0
#     179     while True:
# --> 180         value = drv.ser.read(2 * 256)
#     181         if len(value) == 0:
#     182             print(f'.', end='')
#
# c:\users\localuser\.venvs\py37\lib\site-packages\serial\serialwin32.py in read(self, size)
#     288                     ctypes.byref(self._overlapped_read),
#     289                     ctypes.byref(rc),
# --> 290                     True)
#     291                 if not result_ok:
#     292                     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:

# %%
Msel = np.zeros((64,64))
Msel[20:,20:] = 1

# %%
gdiff = (g-Gtarget)[rs:rs+G_conv_ecc.shape[0], cs:cs+G_conv_ecc.shape[1]]* 1e6 

_ = plt.hist((gdiff.reshape(-1)), 100)

plt.xlabel('Gerr ($\mu S$)')
plt.ylabel('Count')

# plt.xlim((-30, 30))
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # Linear correction for different gains

# %%
rs = G_conv_ecc.shape[0]
cs = G_conv_ecc.shape[1]

i = 0

N_IMG = 10

gain_list = [1, 2, 3]

output_gain = []

for gain in tqdm(gain_list):
    vectors_list = []
    output_list = []

    for img, lab in tqdm(zip(test_images[:N_IMG], test_labels[:N_IMG]), total=N_IMG):
        i += 1

        vectors = nn._conv_flattern(img)
        output = dpe.multiply(
                1, 
                vectors, 
                c_sel=[cs, cs+G_conv_ecc.shape[1]], 
                r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)

        vectors_list.append(vectors)
        output_list.append(output)

    #     if i >= N_IMG:
    #         break

    vectors = np.concatenate(vectors_list, axis=1)
    output = np.concatenate(output_list, axis=0)
    
    output_gain.append(output.copy())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
gain_th = [
    5.82*30,
    5.82*6,
    5.82, #verified
    0.875,
    0.175
]

gain_value = np.zeros_like(output_soft)

# %%
output_soft = vectors.T @ G_conv_ecc / nn.Gratio

for i, gain in enumerate(gain_list):
    
    plt.figure(i+1)
    for c in range(output_gain[i].shape[1]):
        plt.plot(output_soft[:,c], output_gain[i][:,c], '.')
        
        
    gain_value[:,0] = gain_th[gain]
    plt.plot(output_soft[:,0], gain_value[:,0]* 0.95, '--')
    plt.plot(output_soft[:,0], gain_value[:,0]* 0.01, '--')
    
    plt.ylabel('Experimental DPE output')
    plt.xlabel('Expected output')

# %% [markdown]
# ## Fitting

# %%
lin_cor_gain = []

th_rel = [0.9, 0.02]

for i, output in enumerate(output_gain):
    output = output.copy()
    
    gain = gain_list[i]
    print(i, gain, gain_th[gain])
    
    output[output > gain_th[gain] * th_rel[0]] = np.nan
    output[output < gain_th[gain] * th_rel[1]] = np.nan
    
#     plt.figure(i+1)
#     for c in range(output_gain[i].shape[1]):
#         plt.plot(output_soft[:,c], output[:,c], '.')
        
    lin_cor = []
    for c in range(output.shape[1]):
        
        idx = np.isfinite(output[:,c]) & np.isfinite(output_soft[:,c])
        if sum(idx) > 0:
            lin_cor.append( np.polyfit(output[idx,c], output_soft[idx,c], 1))
        else:
            lin_cor.append(np.array([0, 0]))
            
    lin_cor_gain.append(lin_cor)
# Out:
# 0 1 34.92
# 1 2 5.82
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':
# 2 3 0.875

# %% [markdown]
# ## Correction

# %%
output_cor = np.ones_like(output_soft) * 0

i = len(output_gain)
for output in output_gain[::-1]:
    i -= 1
    
    output = output.copy()
    gain = gain_list[i]
    print(i, gain, gain_th[gain])
    
    output[output > gain_th[gain] * th_rel[0]] = np.nan
    output[output < gain_th[gain] * th_rel[1]] = np.nan
    
    lin_cor = lin_cor_gain[i]
    
    for c in range(output.shape[1]):
        
        idx = np.isfinite(output[:,c])
        output_cor[idx,c] = output[idx,c] * lin_cor[c][0] + lin_cor[c][1]
# Out:
# 2 3 0.875
# 1 2 5.82
# 0 1 34.92
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %%
for c in range(output_cor.shape[1]):
    plt.plot(output_soft[:,c], output_cor[:,c], '.', alpha=0.2)

# %%
_ = plt.hist((output_cor - output_soft ).reshape(-1), 100)
plt.xlabel('Output error')

plt.yscale('log')

# %%
_ = plt.hist((output_cor - output_soft ).reshape(-1), 100)
plt.xlabel('Output error')

plt.yscale('log')

# %%
def lin_cor_gains(output_gain, lin_cor_gain):
    output_cor = np.ones_like(output_gain[0]) * 0

    i = len(output_gain)
    for output in output_gain[::-1]:
        i -= 1

        output = output.copy()
        gain = gain_list[i]

        output[output > gain_th[gain] * th_rel[0]] = np.nan
        output[output < gain_th[gain] * th_rel[1]] = np.nan

        lin_cor = lin_cor_gain[i]

        for c in range(output.shape[1]):

            idx = np.isfinite(output[:,c]) 
            output_cor[idx,c] = output[idx,c] * lin_cor[c][0] + lin_cor[c][1]
            
    return output_cor

# %%
output_cor = lin_cor_gains(output_gain, lin_cor_gain)
# Out:
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %% [markdown]
# ## Plot the difference

# %%
from lib_ecc import *

delta = 0.15
Delta = 8 * delta

m = nn.Mconv.shape[0]
k = nn.Mconv.shape[1]

ecc = dpeECC(nn.Mconv, delta, Delta)

# %%
N_IMG = 10

y1_raw_list = []
y1_ecc_list = []
y1_soft_list = []
y1_noise_list = []
y1_noise_list0 = []

i = 0

n_detected = 0
n_corrected = 0
n_other = 0

pbar = tqdm(zip(test_images[:N_IMG], test_labels[:N_IMG]), total=N_IMG)
y_preds = []

for img, lab in pbar:
    vectors = nn._conv_flattern(img)
    
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)

    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1 = output[:, ::2] - output[:, 1::2]
    
    output_soft = vectors.T @ G_conv_ecc / nn.Gratio
    y1_soft = output_soft[:, ::2] - output_soft[:, 1::2]
    
    y1_raw_list.append(y1.copy())
    y1_soft_list.append(y1_soft.copy())
    
    ## Inject noise
    vectors_expand = np.zeros((vectors.shape[0]+3, vectors.shape[1]))
    vectors_noise = vectors_expand.copy()
    vectors_noise[:vectors.shape[0],:] = vectors
    vectors_noise[-3:,:] = 1
    
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors_noise, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)
        
    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1_noise = output[:, ::2] - output[:, 1::2]
    y1_noise_list.append(y1_noise.copy())
    
    ## Inject noise 0 for refernce
    vectors_expand = np.zeros((vectors.shape[0]+3, vectors.shape[1]))
    vectors_noise0 = vectors_expand.copy()
    vectors_noise0[:vectors.shape[0],:] = vectors
    vectors_noise0[-3:,:] = 0
    
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors_noise0, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)
        
    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1_noise = output[:, ::2] - output[:, 1::2]
    y1_noise_list0.append(y1_noise.copy())
    

    ## Next layer
    y1_corrected = correct_ecc(y1, ecc)
    y1_ecc_list.append( y1_corrected )
    
#     y1_ecc_list.append(y1.copy())
    k = nn.Gconv.shape[1] //2
    x = y1[:, :k]
    
    y_pred = dense(x, nn, finalGfc)

    i+=1

    y_preds.append(y_pred)
    pbar.set_description(f'Accuracy={np.mean(test_labels[:i] == np.array(y_preds))*100:.2f}%')
    
    if i%500 ==0:
        save_workspace(vars(), note='multi-gain-repeat-all')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':

# %%
plt.imshow(vectors_noise0[:,:100]); plt.colorbar()

# %%
vectors.shape
# Out:
# (26, 400)

# %%
y1_raw = np.array(y1_raw_list)
y1_soft = np.array(y1_soft_list)
y1_ecc = np.array(y1_ecc_list)
y1_noise = np.array(y1_noise_list)
y1_noise0 = np.array(y1_noise_list0)

y1_raw.shape, y1_soft.shape, y1_ecc.shape
# Out:
# ((10, 400, 15), (10, 400, 15), (0,))

# %%
plt.figure(figsize=(3.5,3))

plt.plot(y1_raw.reshape(-1, 15)[:,4].reshape(-1), 
         y1_noise0.reshape(-1, 15)[:,4].reshape(-1), '.', ms=2)

plt.plot([-6, 6], [-6, 6], '--', lw=0.5)

plt.xlabel('Raw output')
plt.ylabel('Without artifitial current')
# Out:
# Text(0, 0.5, 'Without artifitial current')

# %%
plt.figure(figsize=(3.5,3))

plt.plot(y1_raw.reshape(-1, 15)[:,4].reshape(-1), 
         y1_noise.reshape(-1, 15)[:,4].reshape(-1), '.', ms=2)

plt.plot([-6, 6], [-6, 6], '--', lw=0.5)

plt.xlabel('Raw output')
plt.ylabel('With artifitial current')
# Out:
# Text(0, 0.5, 'With artifitial current')

# %%
_ = plt.hist((y1_raw - y1_noise ).reshape(-1, 15)[:,:].reshape(-1), 100)
# plt.yscale('log')

# %%
save_workspace(vars(), note='inject_noise_uniform-10')
# Out:
# Saving In(<class 'list'>), Out(<class 'dict'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), mat_contents(<class 'dict'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'float'>), Delta(<class 'float'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), Gtarget(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), Msel(<class 'numpy.ndarray'>), gdiff(<class 'numpy.ndarray'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), lin_cor(<class 'list'>), idx(<class 'numpy.ndarray'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y_preds(<class 'list'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), y1_corrected(<class 'numpy.ndarray'>), y1_noise_list(<class 'list'>), vectors_expand(<class 'numpy.ndarray'>), vectors_noise(<class 'numpy.ndarray'>), y1_noise(<class 'numpy.ndarray'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), data(<class 'dict'>), y1_noise_list0(<class 'list'>), y1_noise0(<class 'numpy.ndarray'>), vectors_noise0(<class 'numpy.ndarray'>), to 20200627-001327-inject_noise_uniform-10.pkl
# Saving In(<class 'list'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'float'>), Delta(<class 'float'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), Gtarget(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), Msel(<class 'numpy.ndarray'>), gdiff(<class 'numpy.ndarray'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), lin_cor(<class 'list'>), idx(<class 'numpy.ndarray'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y_preds(<class 'list'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), y1_corrected(<class 'numpy.ndarray'>), y1_noise_list(<class 'list'>), vectors_expand(<class 'numpy.ndarray'>), vectors_noise(<class 'numpy.ndarray'>), y1_noise(<class 'numpy.ndarray'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), y1_noise_list0(<class 'list'>), y1_noise0(<class 'numpy.ndarray'>), vectors_noise0(<class 'numpy.ndarray'>), to 20200627-001327-inject_noise_uniform-10.mat

# %%
plt.figure(figsize=(17, 6))

plt.subplot(1,2,1)

_ = plt.hist((y1_raw - y1_soft ).reshape(-1), 100)
plt.xlabel('Output error')
plt.yscale('log')
plt.xlim((-1.5,1.5))

plt.subplot(1,2,2)
_ = plt.hist((y1_ecc - y1_soft ).reshape(-1), 100)
plt.xlabel('Output error')
plt.yscale('log')
plt.xlim((-1.5,1.5))
# Out:
# (-1.5, 1.5)

# %% [markdown]
# ## Explore delta

# %%
from lib_ecc import *

# %%
y1_raw = np.array(y1_noise_list).reshape(-1, 15)
y1_soft = np.array(y1_soft_list).reshape(-1, 15)
# y1_ecc = np.array(y1_ecc_list).reshape()

# %%
delta_list = np.arange(0.05, 1.05, 0.05)

y1_ecc_list_list = []

for delta in tqdm(delta_list):
    y1_ecc_list = []
    
    Delta = 8 * delta
    ecc = dpeECC(nn.Mconv, delta, Delta)

#     for y1_raw in y1_raw_list:
    y1_ecc_list_list.append( correct_ecc(y1_raw, ecc) )
        
#     y1_ecc_list_list.append(y1_ecc_list)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))

# %%
# output_soft = vectors.T @ G_conv_ecc / nn.Gratio
# y1_soft = output_soft[:, ::2] - output_soft[:, 1::2]

plt.figure(figsize=(17,20))

# for i in range(len(y1_list)):
for i in range(20):
    
    plt.subplot(5,4,i+1)

#     y1_raw = y1_raw_list[0]
    y1_ecc = y1_ecc_list_list[i]


    err_raw = (y1_raw - y1_soft)[:,:].reshape(-1)
    err_ecc = (y1_ecc - y1_soft)[:,:].reshape(-1)


    _ = plt.hist(abs(err_raw), density=True, histtype='step', cumulative=-1,
            label='RAW', bins=100)

    _ = plt.hist(abs(err_ecc), density=True, histtype='step', cumulative=-1,
            label='ECC', bins=100)

    plt.legend()

    plt.yscale('log')
    plt.xlabel('Absolute error')
    plt.ylabel('Cummulative number of error')
    
    plt.title(f'delta = {delta_list[i]:.2f}')
    
plt.tight_layout()

# %% [markdown]
# # CNN experiment

# %%
from lib_ecc import *

delta = 0.3
Delta = 8 * delta

m = nn.Mconv.shape[0]
k = nn.Mconv.shape[1]

ecc = dpeECC(nn.Mconv, delta, Delta)

# %%
N_IMG = 10000

y1_raw_list = []
y1_ecc_list = []
y1_soft_list = []
y1_noise_list = []
# y1_noise_list0 = []

i = 0

n_detected = 0
n_corrected = 0
n_other = 0

pbar = tqdm(zip(test_images[:N_IMG], test_labels[:N_IMG]), total=N_IMG)

y_preds_raw = []
y_preds_noise = []
y_preds_ecc = []

for img, lab in pbar:
    vectors = nn._conv_flattern(img)
    
    # Raw
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)

    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1 = output[:, ::2] - output[:, 1::2]
    
    output_soft = vectors.T @ G_conv_ecc / nn.Gratio
    y1_soft = output_soft[:, ::2] - output_soft[:, 1::2]
    
    y1_raw_list.append(y1.copy())
    y1_soft_list.append(y1_soft.copy())
    
    ## Raw next layer
    k = nn.Gconv.shape[1] //2
    x = y1[:, :k]
    y_pred = dense(x, nn, finalGfc)
    y_preds_raw.append(y_pred.copy())
    
    ## Inject noise
    vectors_expand = np.zeros((vectors.shape[0]+3, vectors.shape[1]))
    vectors_noise = vectors_expand.copy()
    vectors_noise[:vectors.shape[0],:] = vectors
    vectors_noise[-3:,:] = 1
    
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors_noise, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)
        
    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1_noise = output[:, ::2] - output[:, 1::2]
    y1_noise_list.append(y1_noise.copy())
    

    ## Next layer noise
    x = y1_noise[:, :k]
    
    y_pred = dense(x, nn, finalGfc)
    y_preds_noise.append(y_pred)
    
    ## Next layer ECC
    y1_corrected = correct_ecc(y1_noise, ecc)
    y1_ecc_list.append( y1_corrected.copy() )
    
    x = y1[:, :k]
    
    y_pred = dense(x, nn, finalGfc)
    y_preds_ecc.append(y_pred.copy())

    i+=1

    
    pbar.set_description(f'Accuracy={np.mean(test_labels[:i] == np.array(y_preds_raw))*100:.2f}%|' + \
                         f'{np.mean(test_labels[:i] == np.array(y_preds_noise))*100:.2f}%->' + \
                         f'{np.mean(test_labels[:i] == np.array(y_preds_ecc))*100:.2f}%)')
    
    if i%500 ==0:
        save_workspace(vars(), note=f'cnn-inject-noise-{i}')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# [ERROR] SPI return wrong value
# [ERROR] SPI return wrong value
# [ERROR] SPI return wrong value
# c:\users\localuser\.venvs\py37\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in less
#   if sys.path[0] == '':
# Saving In(<class 'list'>), Out(<class 'dict'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), mat_contents(<class 'dict'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'numpy.float64'>), Delta(<class 'numpy.float64'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), Gtarget(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), Msel(<class 'numpy.ndarray'>), gdiff(<class 'numpy.ndarray'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), lin_cor(<class 'list'>), idx(<class 'numpy.ndarray'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y_preds(<class 'list'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), y1_corrected(<class 'numpy.ndarray'>), y1_noise_list(<class 'list'>), vectors_expand(<class 'numpy.ndarray'>), vectors_noise(<class 'numpy.ndarray'>), y1_noise(<class 'numpy.ndarray'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), data(<class 'dict'>), y1_noise_list0(<class 'list'>), y1_noise0(<class 'numpy.ndarray'>), vectors_noise0(<class 'numpy.ndarray'>), delta_list(<class 'numpy.ndarray'>), y1_ecc_list_list(<class 'list'>), err_raw(<class 'numpy.ndarray'>), err_ecc(<class 'numpy.ndarray'>), y_preds_raw(<class 'list'>), y_preds_noise(<class 'list'>), y_preds_ecc(<class 'list'>), to 20200627-051117-cnn-inject-noise-500.pkl
# Saving In(<class 'list'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'numpy.float64'>), Delta(<class 'numpy.float64'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), Gtarget(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), Msel(<class 'numpy.ndarray'>), gdiff(<class 'numpy.ndarray'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), lin_cor(<class 'list'>), idx(<class 'numpy.ndarray'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y_preds(<class 'list'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), y1_corrected(<class 'numpy.ndarray'>), y1_noise_list(<class 'list'>), vectors_expand(<class 'numpy.ndarray'>), vectors_noise(<class 'numpy.ndarray'>), y1_noise(<class 'numpy.ndarray'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), y1_noise_list0(<class 'list'>), y1_noise0(<class 'numpy.ndarray'>), vectors_noise0(<class 'numpy.ndarray'>), delta_list(<class 'numpy.ndarray'>), y1_ecc_list_list(<class 'list'>), err_raw(<class 'numpy.ndarray'>), err_ecc(<class 'numpy.ndarray'>), y_preds_raw(<class 'list'>), y_preds_noise(<class 'list'>), y_preds_ecc(<class 'list'>), to 20200627-051117-cnn-inject-noise-500.mat
# Saving In(<class 'list'>), Out(<class 'dict'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), mat_contents(<class 'dict'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'numpy.float64'>), Delta(<class 'numpy.float64'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), Gtarget(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), Msel(<class 'numpy.ndarray'>), gdiff(<class 'numpy.ndarray'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), lin_cor(<class 'list'>), idx(<class 'numpy.ndarray'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y_preds(<class 'list'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), y1_corrected(<class 'numpy.ndarray'>), y1_noise_list(<class 'list'>), vectors_expand(<class 'numpy.ndarray'>), vectors_noise(<class 'numpy.ndarray'>), y1_noise(<class 'numpy.ndarray'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), data(<class 'dict'>), y1_noise_list0(<class 'list'>), y1_noise0(<class 'numpy.ndarray'>), vectors_noise0(<class 'numpy.ndarray'>), delta_list(<class 'numpy.ndarray'>), y1_ecc_list_list(<class 'list'>), err_raw(<class 'numpy.ndarray'>), err_ecc(<class 'numpy.ndarray'>), y_preds_raw(<class 'list'>), y_preds_noise(<class 'list'>), y_preds_ecc(<class 'list'>), to 20200627-095327-cnn-inject-noise-1000.pkl
# Saving In(<class 'list'>), weights(<class 'numpy.ndarray'>), test_images(<class 'numpy.ndarray'>), test_labels(<class 'numpy.ndarray'>), g(<class 'numpy.ndarray'>), img_idx(<class 'int'>), image(<class 'numpy.ndarray'>), vectors(<class 'numpy.ndarray'>), outputs(<class 'numpy.ndarray'>), software(<class 'numpy.ndarray'>), c(<class 'int'>), x(<class 'numpy.ndarray'>), y(<class 'numpy.ndarray'>), finalGconv(<class 'numpy.ndarray'>), g1(<class 'numpy.ndarray'>), g2(<class 'numpy.ndarray'>), linear_factors_conv(<class 'numpy.ndarray'>), acc(<class 'list'>), result(<class 'numpy.ndarray'>), x1(<class 'numpy.ndarray'>), new_lin_cor_fc1(<class 'list'>), new_lin_cor_fc2(<class 'list'>), lin_cor_conv(<class 'list'>), finalGfc(<class 'numpy.ndarray'>), delta(<class 'numpy.float64'>), Delta(<class 'numpy.float64'>), m(<class 'int'>), k(<class 'int'>), M_conv_ecc(<class 'numpy.ndarray'>), G_conv_ecc(<class 'numpy.ndarray'>), G_parity_ecc(<class 'numpy.ndarray'>), Gtarget(<class 'numpy.ndarray'>), rs(<class 'int'>), cs(<class 'int'>), Msel(<class 'numpy.ndarray'>), gdiff(<class 'numpy.ndarray'>), i(<class 'int'>), N_IMG(<class 'int'>), vectors_list(<class 'list'>), output_list(<class 'list'>), img(<class 'numpy.ndarray'>), output(<class 'numpy.ndarray'>), output_soft(<class 'numpy.ndarray'>), output_cor(<class 'numpy.ndarray'>), gain_list(<class 'list'>), output_gain(<class 'list'>), gain(<class 'int'>), gain_th(<class 'list'>), gain_value(<class 'numpy.ndarray'>), lin_cor_gain(<class 'list'>), th_rel(<class 'list'>), lin_cor(<class 'list'>), idx(<class 'numpy.ndarray'>), y1_raw_list(<class 'list'>), y1_ecc_list(<class 'list'>), y1_soft_list(<class 'list'>), n_detected(<class 'int'>), n_corrected(<class 'int'>), n_other(<class 'int'>), y_preds(<class 'list'>), y1(<class 'numpy.ndarray'>), y1_soft(<class 'numpy.ndarray'>), y1_corrected(<class 'numpy.ndarray'>), y1_noise_list(<class 'list'>), vectors_expand(<class 'numpy.ndarray'>), vectors_noise(<class 'numpy.ndarray'>), y1_noise(<class 'numpy.ndarray'>), y1_raw(<class 'numpy.ndarray'>), y1_ecc(<class 'numpy.ndarray'>), y1_noise_list0(<class 'list'>), y1_noise0(<class 'numpy.ndarray'>), vectors_noise0(<class 'numpy.ndarray'>), delta_list(<class 'numpy.ndarray'>), y1_ecc_list_list(<class 'list'>), err_raw(<class 'numpy.ndarray'>), err_ecc(<class 'numpy.ndarray'>), y_preds_raw(<class 'list'>), y_preds_noise(<class 'list'>), y_preds_ecc(<class 'list'>), to 20200627-095327-cnn-inject-noise-1000.mat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-235-d49cdecc6154> in <module>
#      61             vectors_noise,
#      62             c_sel=[cs, cs+G_conv_ecc.shape[1]],
# ---> 63             r_start=rs, mode=0, Tdly=500, gain=gain
#      64         ) / (nn.Gratio)
#      65
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in wrapper_with_ser(*args, **kwargs)
#      27
#      28             ts = time.time()
# ---> 29             result = func(*args, **kwargs)
#      30             #print(f'[INFO] Elapsed time = {time.time()-ts:.2f}s')
#      31
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dpe.py in multiply(self, array, vectors, r_start, c_sel, mode, gain, **kwargs)
#     712
#     713             outputs_dpe = a0.pic_dpe_batch(array, inputs_dpe, gain=gain, mode=1,
# --> 714                                            col_en=self.get_col_en(c_sel), **kwargs)
#     715
#     716             outputs_dpe = outputs_dpe[:, c_sel[0]:c_sel[1]]
#
# C:\microchip\harmony\v2_06\apps\A0_DUT\dut_a0.py in pic_dpe_batch(array, input, skip_conf, raw, col_en, **kwargs)
#     268         r = 0
#     269         while True:
# --> 270             value = drv.ser.read(2 * 256)
#     271             if len(value) == 0:
#     272                 print(f'.', end='')
#
# c:\users\localuser\.venvs\py37\lib\site-packages\serial\serialwin32.py in read(self, size)
#     288                     ctypes.byref(self._overlapped_read),
#     289                     ctypes.byref(rc),
# --> 290                     True)
#     291                 if not result_ok:
#     292                     if win32.GetLastError() != win32.ERROR_OPERATION_ABORTED:
#
# KeyboardInterrupt:

# %% [markdown]
# # CNN with random noise

# %%
N_IMG = 10000

y1_raw_list = []
y1_ecc_list = []
y1_soft_list = []
y1_noise_list = []
# y1_noise_list0 = []

i = 0

n_detected = 0
n_corrected = 0
n_other = 0

pbar = tqdm(zip(test_images[:N_IMG], test_labels[:N_IMG]), total=N_IMG)

y_preds_raw = []
y_preds_noise = []
y_preds_ecc = []

for img, lab in pbar:
    vectors = nn._conv_flattern(img)
    
    # Raw
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)

    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1 = output[:, ::2] - output[:, 1::2]
    
    output_soft = vectors.T @ G_conv_ecc / nn.Gratio
    y1_soft = output_soft[:, ::2] - output_soft[:, 1::2]
    
    y1_raw_list.append(y1.copy())
    y1_soft_list.append(y1_soft.copy())
    
    ## Raw next layer
    k = nn.Gconv.shape[1] //2
    x = y1[:, :k]
    y_pred = dense(x, nn, finalGfc)
    y_preds_raw.append(y_pred.copy())
    
    ## Inject noise
    vectors_expand = np.zeros((vectors.shape[0]+3, vectors.shape[1]))
    vectors_noise = vectors_expand.copy()
    vectors_noise[:vectors.shape[0],:] = vectors
    vectors_noise[-3:,:] = np.random.random((3, vectors_noise.shape[1]))
    
    output_gain = []
    for gain in gain_list:
        output = dpe.multiply(
            1, 
            vectors_noise, 
            c_sel=[cs, cs+G_conv_ecc.shape[1]], 
            r_start=rs, mode=0, Tdly=500, gain=gain
        ) / (nn.Gratio)
        
        output_gain.append(output)
        
    output = lin_cor_gains(output_gain, lin_cor_gain)
    y1_noise = output[:, ::2] - output[:, 1::2]
    y1_noise_list.append(y1_noise.copy())
    

    ## Next layer noise
    x = y1_noise[:, :k]
    
    y_pred = dense(x, nn, finalGfc)
    y_preds_noise.append(y_pred)
    
    ## Next layer ECC
    y1_corrected = correct_ecc(y1_noise, ecc)
    y1_ecc_list.append( y1_corrected.copy() )
    
    x = y1[:, :k]
    
    y_pred = dense(x, nn, finalGfc)
    y_preds_ecc.append(y_pred.copy())

    i+=1

    
    pbar.set_description(f'Accuracy={np.mean(test_labels[:i] == np.array(y_preds_raw))*100:.2f}%|' + \
                         f'{np.mean(test_labels[:i] == np.array(y_preds_noise))*100:.2f}%->' + \
                         f'{np.mean(test_labels[:i] == np.array(y_preds_ecc))*100:.2f}%)')
    
    if i%500 ==0:
        save_workspace(vars(), note=f'cnn-inject-noise-random-{i}')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
