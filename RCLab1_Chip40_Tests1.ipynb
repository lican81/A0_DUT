# %%
dut.disconnect()

# %%
dut.ground_PIC()
# Out:
# DAC initialized to a span from 0 V to 5 V

# %%
dut.reset_chip()
dut.reset_dpe()

# %%
dut.power_off()

# %%
# %reload_ext autoreload
# %autoreload 2

import dut_func as dut
import serial
import time
import struct
import numpy as np
# from bitarray import bitarray
from bitstring import BitArray
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
import dut_a0 as a0

from misc import *

# dut.drv.serUSB = 'COM19'
drv = dut.drv

ser = serial.Serial('COM3', 9600, timeout=2)
dut.connect(ser)

# %%
from dpe import DPE
from lib_data import *
import matplotlib.pyplot as plt
import numpy as np
from lib_nn_dpe import NN_dpe
from IPython import display

import serial
import matplotlib

dpe = DPE('COM6')
dpe.set_clock(50)
# Out:
# Running <function DPE.init_dut at 0x05497390> with serial
# DAC initialized to a span from -10 V to 10 V
# Setting vrefs to default
# [INFO] Elapsed time = 0.04s
# Serial disconnected
# Running <function DPE.set_clock at 0x05497738> with serial
# Setting ADC_CK freq=50000.0kHz
# Setting CK_ARRAY freq=50000.0kHz
# [INFO] Elapsed time = 0.00s
# Serial disconnected

# %%
dut.power_on()
dut.reset_chip()
dut.reset_dpe()
# Out:
# Setting vrefs to default

# %%
g = dpe.read(2)
plt.imshow(g * 1e6)
plt.colorbar()
# Out:
# Running <function DPE.read at 0x05497150> with serial
# [INFO] Elapsed time = 0.28s
# Serial disconnected

# %%
print(g[38,8])
# Out:
# 0.0001459758879113718

# %% [markdown]
# Calibrate all 12 ADCs on A0

# %%
ar=2
r=31
c=0

Vreads = np.arange(0, 0.5, 0.01)
# Vgates = np.arange(0,5,0.5)
# Vgates = [1, 1.1, 1.2, 1.3, 1.4, 1.5, 5]
Vgates = [5]

volts_set = []

for Vgate in Vgates:
    print(f'{Vgate:.2f}', end='-')
    volts = []
    for vread in Vreads:
        volts.append( a0.read_single(vread, Vgate, array=ar, row=r, col=c, gain=4) )
    volts_set.append(volts)
# Out:
# 5.00-

# %%
for volts in volts_set:
    plt.plot(Vreads, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('VPP')
plt.ylabel('Caculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)

# %%
arr=1
rr=9
cc=12

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot([i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot([i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=2
rr=31
cc=0

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=2
rr=38
cc=8

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=1
rr=9
cc=12

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=1
rr=9
cc=12

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.25, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=0
rr=0
cc=0

Vreads = np.arange(0, 0.25, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
    
ts = time.time()
for vRead in Vreads:
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    #rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)    
    #rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    rdCurrs.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))

print(time.time()-ts)
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Read Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()
# Out:
# 11.157131671905518

# %%
arr=0
rr=0
cc=0

Vreads = np.arange(0, 0.25, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
    
ts = time.time()
for vRead in Vreads:
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    #rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)    
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    #rdCurrs.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))

print(time.time()-ts)
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Read Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()
# Out:
# 2.9558515548706055

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0,10])
actualCols = np.array([0,10])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 3.1, 0.1)
vAppliedReset = np.arange(0.1, 3.1, 0.1)
vGateSet = np.arange(0.1, 1.9, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
GTargetOFF = 2e-6
numRepeats = 3

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= maxGProtect:
                    break
            if currG >= maxGProtect:
                break
        if currG >= maxGProtect:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
        fig, ax1 = plt.subplots()
        color = 'tab:blue'
        ax1.set_xlabel('Cycles')
        ax1.set_ylabel('Conductance (uS)', color=color)
        ax1.plot([i* 1e6 for i in thisGHistory], color=color)
        ax1.tick_params(axis='y', labelcolor=color)
        ax2 = ax1.twinx()  
        color = 'tab:red'
        ax2.set_ylabel('Voltage Applied', color=color)
        ax2.plot(thisVHistory, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        fig.tight_layout()  
        plt.show()

    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Array0_SwitchONTests1')
# Out:
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), to 20191009-170427-RCLab1_Array0_SwitchONTests1.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), to 20191009-170427-RCLab1_Array0_SwitchONTests1.mat

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0])
actualCols = np.array([0])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 4.5, 0.1)
vAppliedReset = np.arange(0.1, 3.5, 0.1)
vGateSet = np.arange(0.4, 1.9, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
targetGFormed = 50e-6
GTargetOFF = 2e-6
numRepeats = 1

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= targetGFormed:
                    break
            if currG >= targetGFormed:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
        fig, ax1 = plt.subplots()
        color = 'tab:blue'
        ax1.set_xlabel('Cycles')
        ax1.set_ylabel('Conductance (uS)', color=color)
        ax1.plot([i* 1e6 for i in thisGHistory], color=color)
        ax1.tick_params(axis='y', labelcolor=color)
        ax2 = ax1.twinx()  
        color = 'tab:red'
        ax2.set_ylabel('Voltage Applied', color=color)
        ax2.plot(thisVHistory, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        fig.tight_layout()  
        plt.show()

    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Array0_SwitchONTests1')
# Out:
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.00010948191593352881  Final G= 0.00010948191593352881
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.00010948191593352881  Final G= 1.6422287390029323e-06
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205024-RCLab1_Array0_SwitchONTests1.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205024-RCLab1_Array0_SwitchONTests1.mat

# %%
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Cycles')
ax1.set_ylabel('Conductance (uS)', color=color)
ax1.plot([i* 1e6 for i in thisGHistory], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Voltage Applied', color=color)
ax2.plot(thisVHistory, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0, 10])
actualCols = np.array([0, 10])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 4.5, 0.1)
vAppliedReset = np.arange(0.1, 3.5, 0.1)
vGateSet = np.arange(0.1, 1.9, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
targetGFormed = 100e-6
GTargetOFF = 2e-6
numRepeats = 1

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= targetGFormed:
                    break
            if currG >= targetGFormed:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
        fig, ax1 = plt.subplots()
        color = 'tab:blue'
        ax1.set_xlabel('Cycles')
        ax1.set_ylabel('Conductance (uS)', color=color)
        ax1.plot([i* 1e6 for i in thisGHistory], color=color)
        ax1.tick_params(axis='y', labelcolor=color)
        ax2 = ax1.twinx()  
        color = 'tab:red'
        ax2.set_ylabel('Voltage Applied', color=color)
        ax2.plot(thisVHistory, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        fig.tight_layout()  
        plt.show()

    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Array0_SwitchONTests1')
# Out:
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 1.1119257086999022e-06  Final G= 0.00020869990224828933
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.00020869990224828933  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0  Final G= 0.0001687846203975236
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0001687846203975236  Final G= 0.0
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205912-RCLab1_Array0_SwitchONTests1.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205912-RCLab1_Array0_SwitchONTests1.mat

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0, 10, 20, 30, 40, 50, 60])
actualCols = np.array([0, 10, 20, 30, 40, 50, 60])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 4.5, 0.1)
vAppliedReset = np.arange(0.1, 3.5, 0.1)
vGateSet = np.arange(0.1, 1.9, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
targetGFormed = 200e-6
GTargetOFF = 2e-6
numRepeats = 15

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= targetGFormed:
                    break
            if currG >= targetGFormed:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Arr0_ON_7Dev_20Rep')
# Out:
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 6.842619745845551e-07  Final G= 0.0002029977191267514
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.0002029977191267514  Final G= 1.7106549364613877e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 1  Init G= 1.1290322580645162e-06  Final G= 0.0002018572825024438
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 1  Init G= 0.0002018572825024438  Final G= 0.0
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 2  Init G= 6.842619745845546e-08  Final G= 0.00024633431085043986
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 2  Init G= 0.00024633431085043986  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 3  Init G= 1.0948191593352885e-06  Final G= 0.00028567937438905177
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 3  Init G= 0.00028567937438905177  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 4  Init G= 1.2316715542521993e-06  Final G= 0.0002018572825024438
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 4  Init G= 0.0002018572825024438  Final G= 1.9159335288367544e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 5  Init G= 1.9159335288367544e-06  Final G= 0.00028853046594982083
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 5  Init G= 0.00028853046594982083  Final G= 1.3685239491691102e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 6  Init G= 1.2316715542521993e-06  Final G= 0.00026230042359074617
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 6  Init G= 0.00026230042359074617  Final G= 1.2316715542521993e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 7  Init G= 1.2316715542521993e-06  Final G= 0.0003267350928641251
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 7  Init G= 0.0003267350928641251  Final G= 1.9159335288367544e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 8  Init G= 2.189638318670577e-06  Final G= 0.000229227761485826
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 8  Init G= 0.000229227761485826  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 9  Init G= 5.474095796676442e-07  Final G= 0.0002896709025741284
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 9  Init G= 0.0002896709025741284  Final G= 1.7106549364613877e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 10  Init G= 1.7106549364613877e-06  Final G= 0.00020641902899967414
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 10  Init G= 0.00020641902899967414  Final G= 1.2316715542521993e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 11  Init G= 1.1290322580645162e-06  Final G= 0.0002018572825024438
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 11  Init G= 0.0002018572825024438  Final G= 1.1119257086999022e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 12  Init G= 1.7790811339198436e-06  Final G= 0.0002537471489084392
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 12  Init G= 0.0002537471489084392  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 13  Init G= 1.67644183773216e-06  Final G= 0.00023949169110459433
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 13  Init G= 0.00023949169110459433  Final G= 1.7790811339198436e-06
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 14  Init G= 1.9159335288367544e-06  Final G= 0.00022580645161290321
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 14  Init G= 0.00022580645161290321  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0  Final G= 0.0002577386770935158
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0002577386770935158  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 1  Init G= 1.1290322580645162e-06  Final G= 0.000260019550342131
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 1  Init G= 0.000260019550342131  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 2  Init G= 1.3685239491691093e-07  Final G= 0.00023949169110459433
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 2  Init G= 0.00023949169110459433  Final G= 1.1119257086999022e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 3  Init G= 1.1290322580645162e-06  Final G= 0.00021041055718475072
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 3  Init G= 0.00021041055718475072  Final G= 1.2316715542521993e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 4  Init G= 1.2316715542521993e-06  Final G= 0.00021953405017921144
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 4  Init G= 0.00021953405017921144  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 5  Init G= 1.2316715542521993e-06  Final G= 0.00020641902899967414
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 5  Init G= 0.00020641902899967414  Final G= 1.7790811339198436e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 6  Init G= 1.7790811339198436e-06  Final G= 0.00022580645161290321
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 6  Init G= 0.00022580645161290321  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 7  Init G= 1.2316715542521993e-06  Final G= 0.00020984033887259693
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 7  Init G= 0.00020984033887259693  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 8  Init G= 1.0948191593352885e-06  Final G= 0.0002007168458781362
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 8  Init G= 0.0002007168458781362  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 9  Init G= 1.2316715542521993e-06  Final G= 0.0002919517758227436
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 9  Init G= 0.0002919517758227436  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 10  Init G= 8.211143695014662e-07  Final G= 0.0002029977191267514
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 10  Init G= 0.0002029977191267514  Final G= 1.7106549364613866e-08
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 11  Init G= 0.0  Final G= 0.00027427500814597585
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 11  Init G= 0.00027427500814597585  Final G= 1.1290322580645162e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 12  Init G= 1.0948191593352885e-06  Final G= 0.00023949169110459433
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 12  Init G= 0.00023949169110459433  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 13  Init G= 0.0  Final G= 0.0002007168458781362
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 13  Init G= 0.0002007168458781362  Final G= 1.2316715542521993e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 14  Init G= 1.6422287390029323e-06  Final G= 0.00029651352231997393
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 14  Init G= 0.00029651352231997393  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 0  Init G= 0.0  Final G= 0.0002018572825024438
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 0  Init G= 0.0002018572825024438  Final G= 1.3685239491691102e-06
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 1  Init G= 1.2316715542521993e-06  Final G= 0.0002121212121212121
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 1  Init G= 0.0002121212121212121  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 2  Init G= 8.211143695014662e-07  Final G= 0.00020527859237536654
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 2  Init G= 0.00020527859237536654  Final G= 6.842619745845551e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 3  Init G= 6.842619745845551e-07  Final G= 0.000229227761485826
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 3  Init G= 0.000229227761485826  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 4  Init G= 6.842619745845551e-07  Final G= 0.00023721081785597914
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 4  Init G= 0.00023721081785597914  Final G= 1.9159335288367544e-06
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 5  Init G= 1.9159335288367544e-06  Final G= 0.0002007168458781362
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 5  Init G= 0.0002007168458781362  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 6  Init G= 1.67644183773216e-06  Final G= 0.0002109807754969045
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 6  Init G= 0.0002109807754969045  Final G= 6.842619745845551e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 7  Init G= 6.842619745845551e-07  Final G= 0.0002007168458781362
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 7  Init G= 0.0002007168458781362  Final G= 6.842619745845551e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 8  Init G= 0.0  Final G= 0.000229227761485826
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 8  Init G= 0.000229227761485826  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 9  Init G= 0.0  Final G= 0.00022466601498859562
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 9  Init G= 0.00022466601498859562  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 10  Init G= 5.474095796676442e-07  Final G= 0.00026115998696643855
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 10  Init G= 0.00026115998696643855  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 11  Init G= 1.1119257086999022e-06  Final G= 0.0002149723036819811
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 11  Init G= 0.0002149723036819811  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 12  Init G= 0.0  Final G= 0.0002417725643532095
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 12  Init G= 0.0002417725643532095  Final G= 0.0
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 13  Init G= 0.0  Final G= 0.00024861518409905506
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 13  Init G= 0.00024861518409905506  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 20 col= 20 ) Repeat= 14  Init G= 1.0948191593352885e-06  Final G= 0.00025146627565982406
# RESET: Array 0 , device (row= 20 col= 20 ) Repeat= 14  Init G= 0.00025146627565982406  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 0  Init G= 0.0  Final G= 0.0002560280221570544
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 0  Init G= 0.0002560280221570544  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 1  Init G= 6.842619745845546e-08  Final G= 0.00027142391658520695
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 1  Init G= 0.00027142391658520695  Final G= 1.9159335288367544e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 2  Init G= 1.9159335288367544e-06  Final G= 0.0002554578038449006
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 2  Init G= 0.0002554578038449006  Final G= 1.659335288367546e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 3  Init G= 1.7106549364613877e-06  Final G= 0.0002149723036819811
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 3  Init G= 0.0002149723036819811  Final G= 1.7790811339198436e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 4  Init G= 1.6422287390029323e-06  Final G= 0.00020984033887259693
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 4  Init G= 0.00020984033887259693  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 5  Init G= 2.7370478983382186e-07  Final G= 0.00020755946562398174
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 5  Init G= 0.00020755946562398174  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 6  Init G= 1.163245356793744e-06  Final G= 0.00023435972629521018
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 6  Init G= 0.00023435972629521018  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 7  Init G= 6.765640273704788e-05  Final G= 0.0002007168458781362
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 7  Init G= 0.0002007168458781362  Final G= 0.0
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 8  Init G= 0.0  Final G= 0.0002007168458781362
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 8  Init G= 0.0002007168458781362  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 9  Init G= 6.842619745845551e-07  Final G= 0.0002799771912675138
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 9  Init G= 0.0002799771912675138  Final G= 6.842619745845551e-07
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 10  Init G= 6.842619745845551e-07  Final G= 0.00020128706419029
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 10  Init G= 0.00020128706419029  Final G= 1.7106549364613877e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 11  Init G= 1.6422287390029323e-06  Final G= 0.00022010426849136525
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 11  Init G= 0.00022010426849136525  Final G= 1.7790811339198436e-06
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 12  Init G= 1.6422287390029323e-06  Final G= 0.0002942326490713588
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 12  Init G= 0.0002942326490713588  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 13  Init G= 0.0  Final G= 0.0002018572825024438
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 13  Init G= 0.0002018572825024438  Final G= 0.0
# SET: Array 0 , device (row= 30 col= 30 ) Repeat= 14  Init G= 0.0  Final G= 0.0002708536982730531
# RESET: Array 0 , device (row= 30 col= 30 ) Repeat= 14  Init G= 0.0002708536982730531  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 0  Init G= 0.0  Final G= 0.00026458129683936137
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 0  Init G= 0.00026458129683936137  Final G= 1.950146627565982e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 1  Init G= 1.3685239491691093e-07  Final G= 0.00023435972629521018
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 1  Init G= 0.00023435972629521018  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 2  Init G= 1.3685239491691093e-07  Final G= 0.0002326490713587488
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 2  Init G= 0.0002326490713587488  Final G= 8.895405669599221e-07
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 3  Init G= 1.0948191593352885e-06  Final G= 0.0002029977191267514
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 3  Init G= 0.0002029977191267514  Final G= 1.265884652981427e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 4  Init G= 1.163245356793744e-06  Final G= 0.000301645487129358
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 4  Init G= 0.000301645487129358  Final G= 1.2316715542521993e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 5  Init G= 1.0212609970674486e-05  Final G= 0.00022010426849136525
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 5  Init G= 0.00022010426849136525  Final G= 1.7961876832844575e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 6  Init G= 1.7790811339198436e-06  Final G= 0.00021896383186705766
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 6  Init G= 0.00021896383186705766  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 7  Init G= 1.2316715542521993e-06  Final G= 0.00023721081785597914
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 7  Init G= 0.00023721081785597914  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 8  Init G= 1.0948191593352885e-06  Final G= 0.0002537471489084392
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 8  Init G= 0.0002537471489084392  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 9  Init G= 1.6422287390029323e-06  Final G= 0.0003176115998696644
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 9  Init G= 0.0003176115998696644  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 10  Init G= 8.211143695014662e-07  Final G= 0.00023721081785597914
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 10  Init G= 0.00023721081785597914  Final G= 1.7790811339198436e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 11  Init G= 1.950146627565982e-06  Final G= 0.0002417725643532095
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 11  Init G= 0.0002417725643532095  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 12  Init G= 8.211143695014662e-07  Final G= 0.0002948028673835125
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 12  Init G= 0.0002948028673835125  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 13  Init G= 1.6422287390029323e-06  Final G= 0.00020527859237536654
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 13  Init G= 0.00020527859237536654  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 40 col= 40 ) Repeat= 14  Init G= 1.7106549364613877e-06  Final G= 0.00029651352231997393
# RESET: Array 0 , device (row= 40 col= 40 ) Repeat= 14  Init G= 0.00029651352231997393  Final G= 5.81622678396872e-07
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 0  Init G= 0.0  Final G= 0.0002309384164222874
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 0  Init G= 0.0002309384164222874  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 1  Init G= 6.842619745845551e-07  Final G= 0.00020527859237536654
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 1  Init G= 0.00020527859237536654  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 2  Init G= 1.1290322580645162e-06  Final G= 0.0002007168458781362
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 2  Init G= 0.0002007168458781362  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 3  Init G= 2.7370478983382186e-07  Final G= 0.00021953405017921144
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 3  Init G= 0.00021953405017921144  Final G= 1.1290322580645162e-06
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 4  Init G= 1.163245356793744e-06  Final G= 0.0002275171065493646
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 4  Init G= 0.0002275171065493646  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 5  Init G= 2.7370478983382186e-07  Final G= 0.0002993646138807429
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 5  Init G= 0.0002993646138807429  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 6  Init G= 5.81622678396872e-07  Final G= 0.00023721081785597914
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 6  Init G= 0.00023721081785597914  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 7  Init G= 1.3685239491691093e-07  Final G= 0.0002144020853698273
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 7  Init G= 0.0002144020853698273  Final G= 1.402737047898338e-06
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 8  Init G= 1.3685239491691102e-06  Final G= 0.000229227761485826
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 8  Init G= 0.000229227761485826  Final G= 6.842619745845546e-08
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 9  Init G= 0.0  Final G= 0.0003062072336265884
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 9  Init G= 0.0003062072336265884  Final G= 1.3685239491691093e-07
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 10  Init G= 1.3685239491691093e-07  Final G= 0.0002782665363310525
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 10  Init G= 0.0002782665363310525  Final G= 1.67644183773216e-06
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 11  Init G= 2.4633431085043987e-06  Final G= 0.0002109807754969045
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 11  Init G= 0.0002109807754969045  Final G= 1.7106549364613877e-06
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 12  Init G= 1.2316715542521993e-06  Final G= 0.00027427500814597585
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 12  Init G= 0.00027427500814597585  Final G= 0.0
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 13  Init G= 0.0  Final G= 0.00025146627565982406
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 13  Init G= 0.00025146627565982406  Final G= 0.0
# SET: Array 0 , device (row= 50 col= 50 ) Repeat= 14  Init G= 0.0  Final G= 0.00022124470511567285
# RESET: Array 0 , device (row= 50 col= 50 ) Repeat= 14  Init G= 0.00022124470511567285  Final G= 1.3856304985337241e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 0  Init G= 0.0  Final G= 0.00022124470511567285
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 0  Init G= 0.00022124470511567285  Final G= 8.895405669599221e-07
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 1  Init G= 6.842619745845551e-07  Final G= 0.0002799771912675138
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 1  Init G= 0.0002799771912675138  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 2  Init G= 1.6422287390029323e-06  Final G= 0.00021668295861844246
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 2  Init G= 0.00021668295861844246  Final G= 6.842619745845551e-07
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 3  Init G= 2.3949169110459433e-06  Final G= 0.00026287064190289993
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 3  Init G= 0.00026287064190289993  Final G= 1.0263929618768318e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 4  Init G= 4.002932551319648e-06  Final G= 0.00022124470511567285
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 4  Init G= 0.00022124470511567285  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 5  Init G= 1.3685239491691093e-07  Final G= 0.00028624959270120564
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 5  Init G= 0.00028624959270120564  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 6  Init G= 6.842619745845551e-07  Final G= 0.0003039263603779732
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 6  Init G= 0.0003039263603779732  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 7  Init G= 4.8069403714565005e-06  Final G= 0.0002121212121212121
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 7  Init G= 0.0002121212121212121  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 8  Init G= 8.553274682306939e-07  Final G= 0.00020812968393613555
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 8  Init G= 0.00020812968393613555  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 9  Init G= 6.158357771260997e-07  Final G= 0.00021896383186705766
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 9  Init G= 0.00021896383186705766  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 10  Init G= 6.603128054740958e-06  Final G= 0.00020527859237536654
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 10  Init G= 0.00020527859237536654  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 11  Init G= 1.0948191593352885e-06  Final G= 0.0003364288041707396
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 11  Init G= 0.0003364288041707396  Final G= 8.211143695014662e-07
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 12  Init G= 8.895405669599221e-07  Final G= 0.0002144020853698273
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 12  Init G= 0.0002144020853698273  Final G= 1.7790811339198436e-06
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 13  Init G= 1.2316715542521993e-06  Final G= 0.0002018572825024438
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 13  Init G= 0.0002018572825024438  Final G= 0.0
# SET: Array 0 , device (row= 60 col= 60 ) Repeat= 14  Init G= 6.842619745845546e-08  Final G= 0.00029993483219289675
# RESET: Array 0 , device (row= 60 col= 60 ) Repeat= 14  Init G= 0.00029993483219289675  Final G= 1.7106549364613877e-06
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191010-021753-RCLab1_Arr0_ON_7Dev_20Rep.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191010-021753-RCLab1_Arr0_ON_7Dev_20Rep.mat

# %%
import dut_func as dut
import serial
import time
import struct
import numpy as np
from bitstring import BitArray
import matplotlib.pyplot as plt
import dut_a0 as a0
from misc import *
drv = dut.drv

from lib_nn_dpe import NN_dpe
from lib_data import *
import time
from IPython import display

load_workspace(vars(), 'dataset/20190815-132601-weights')
load_workspace(vars(), 'dataset/mnist')
# Out:
# Loaded: weights,
# Loaded: train_images, train_labels, test_images, test_labels,
