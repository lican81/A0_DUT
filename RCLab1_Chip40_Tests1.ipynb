# %%
dut.disconnect()

# %%
dut.ground_PIC()
# Out:
# DAC initialized to a span from 0 V to 5 V

# %%
dut.reset_chip()
dut.reset_dpe()

# %%
dut.power_off()

# %%
# %reload_ext autoreload
# %autoreload 2

import dut_func as dut
import serial
import time
import struct
import numpy as np
# from bitarray import bitarray
from bitstring import BitArray
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
import dut_a0 as a0

from misc import *

# dut.drv.serUSB = 'COM19'
drv = dut.drv

ser = serial.Serial('COM3', 9600, timeout=2)
dut.connect(ser)

# %%
from dpe import DPE
from lib_data import *
import matplotlib.pyplot as plt
import numpy as np
from lib_nn_dpe import NN_dpe
from IPython import display

import serial
import matplotlib

dpe = DPE('COM3')
dpe.set_clock(50)
# Out:
# Running <function DPE.init_dut at 0x01205810> with serial
# DAC initialized to a span from -10 V to 10 V
# Setting vrefs to default
# [INFO] Elapsed time = 0.03s
# Serial disconnected
# Running <function DPE.set_clock at 0x01205B70> with serial
# Setting ADC_CK freq=50000.0kHz
# Setting CK_ARRAY freq=50000.0kHz
# [INFO] Elapsed time = 0.00s
# Serial disconnected

# %%
dut.power_on()
dut.reset_chip()
dut.reset_dpe()
# Out:
# Setting vrefs to default

# %%
g = dpe.read(2)
plt.imshow(g * 1e6)
plt.colorbar()
# Out:
# Running <function DPE.read at 0x01143F60> with serial
# [INFO] Elapsed time = 0.27s
# Serial disconnected

# %%
print(g[0,3])
# Out:
# 0.00029822417725643526

# %% [markdown]
# Calibrate all 12 ADCs on A0

# %%
ar=2
r=31
c=0

Vreads = np.arange(0, 0.5, 0.01)
# Vgates = np.arange(0,5,0.5)
# Vgates = [1, 1.1, 1.2, 1.3, 1.4, 1.5, 5]
Vgates = [5]

volts_set = []

for Vgate in Vgates:
    print(f'{Vgate:.2f}', end='-')
    volts = []
    for vread in Vreads:
        volts.append( a0.read_single(vread, Vgate, array=ar, row=r, col=c, gain=4) )
    volts_set.append(volts)
# Out:
# 5.00-

# %%
for volts in volts_set:
    plt.plot(Vreads, [i* 1e6 for i in volts], '.-')
    
plt.xlabel('VPP')
plt.ylabel('Caculated current (uA)')
plt.grid(True, alpha=0.3)
# plt.ylim(-0.1, 6)

# %%
arr=1
rr=9
cc=12

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot([i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot([i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=2
rr=31
cc=0

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=2
rr=38
cc=8

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=1
rr=9
cc=12

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.35, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('2-step Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('1-step Rd Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=1
rr=9
cc=12

VADC_boundary = np.array([0.4, 1.692, 1.927, 2.247, 2.645, 3.045, 3.391, 3.688, 4.1])
VRefHiCmp = np.array([5.5, 4.5, 4.2, 3.8, 3.4, 3.0, 2.7, 2.4])
_gain_ratio = [1e3, 5e3, 30e3, 200e3, 1e6]
vOffset = 0
dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
Vreads = np.arange(0, 0.25, 0.01)
# vRead = 0.2
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrs1 = []
    
for vRead in Vreads:
    adc_raw = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1, raw=True)
    VADC_read_first = dut.adc2volt(adc_raw)
    gainFirst = adc_raw >> 10
    rdCurr1 = (VADC_read_first - 0.5) / _gain_ratio[gainFirst]
    secondVRefHiCmpIndex = np.searchsorted(VADC_boundary,VADC_read_first)-1
    secondVRefHiCmp = VRefHiCmp[secondVRefHiCmpIndex]+vOffset
    dut.dac_set('DAC_VREF_HI_CMP', secondVRefHiCmp+vOffset) 
    VADC_read_sec = dut.adc2volt(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=gainFirst, raw=True))
    finalADCOut = VADC_read_sec - (secondVRefHiCmp - 4.0) 
    dut.dac_set('DAC_VREF_HI_CMP', 4.0+vOffset)
    rdCurr = (finalADCOut - 0.5) / _gain_ratio[gainFirst]
    rdCurrs.append(rdCurr)
    rdCurrs1.append(rdCurr1)    

fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Rd Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs1], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=0
rr=0
cc=0

Vreads = np.arange(0, 0.25, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
    
ts = time.time()
for vRead in Vreads:
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    #rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)    
    #rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    rdCurrs.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))

print(time.time()-ts)
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Read Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()
# Out:
# 11.157131671905518

# %%
arr=0
rr=0
cc=0

Vreads = np.arange(0, 0.25, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
    
ts = time.time()
for vRead in Vreads:
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    #rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)    
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    #rdCurrs.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))

print(time.time()-ts)
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Read Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()
# Out:
# 2.9558515548706055

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0,10])
actualCols = np.array([0,10])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 3.1, 0.1)
vAppliedReset = np.arange(0.1, 3.1, 0.1)
vGateSet = np.arange(0.1, 1.9, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
GTargetOFF = 2e-6
numRepeats = 3

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= maxGProtect:
                    break
            if currG >= maxGProtect:
                break
        if currG >= maxGProtect:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
        fig, ax1 = plt.subplots()
        color = 'tab:blue'
        ax1.set_xlabel('Cycles')
        ax1.set_ylabel('Conductance (uS)', color=color)
        ax1.plot([i* 1e6 for i in thisGHistory], color=color)
        ax1.tick_params(axis='y', labelcolor=color)
        ax2 = ax1.twinx()  
        color = 'tab:red'
        ax2.set_ylabel('Voltage Applied', color=color)
        ax2.plot(thisVHistory, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        fig.tight_layout()  
        plt.show()

    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Array0_SwitchONTests1')
# Out:
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 1  Init G= 0.0  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 2  Init G= 0.0  Final G= 0.0
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), to 20191009-170427-RCLab1_Array0_SwitchONTests1.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), to 20191009-170427-RCLab1_Array0_SwitchONTests1.mat

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0])
actualCols = np.array([0])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 4.5, 0.1)
vAppliedReset = np.arange(0.1, 3.5, 0.1)
vGateSet = np.arange(0.4, 1.9, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
targetGFormed = 50e-6
GTargetOFF = 2e-6
numRepeats = 1

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= targetGFormed:
                    break
            if currG >= targetGFormed:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
        fig, ax1 = plt.subplots()
        color = 'tab:blue'
        ax1.set_xlabel('Cycles')
        ax1.set_ylabel('Conductance (uS)', color=color)
        ax1.plot([i* 1e6 for i in thisGHistory], color=color)
        ax1.tick_params(axis='y', labelcolor=color)
        ax2 = ax1.twinx()  
        color = 'tab:red'
        ax2.set_ylabel('Voltage Applied', color=color)
        ax2.plot(thisVHistory, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        fig.tight_layout()  
        plt.show()

    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Array0_SwitchONTests1')
# Out:
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.00010948191593352881  Final G= 0.00010948191593352881
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.00010948191593352881  Final G= 1.6422287390029323e-06
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205024-RCLab1_Array0_SwitchONTests1.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205024-RCLab1_Array0_SwitchONTests1.mat

# %%
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Cycles')
ax1.set_ylabel('Conductance (uS)', color=color)
ax1.plot([i* 1e6 for i in thisGHistory], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Voltage Applied', color=color)
ax2.plot(thisVHistory, color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0, 10])
actualCols = np.array([0, 10])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 4.5, 0.1)
vAppliedReset = np.arange(0.1, 3.5, 0.1)
vGateSet = np.arange(0.1, 1.9, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
targetGFormed = 100e-6
GTargetOFF = 2e-6
numRepeats = 1

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= targetGFormed:
                    break
            if currG >= targetGFormed:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
        fig, ax1 = plt.subplots()
        color = 'tab:blue'
        ax1.set_xlabel('Cycles')
        ax1.set_ylabel('Conductance (uS)', color=color)
        ax1.plot([i* 1e6 for i in thisGHistory], color=color)
        ax1.tick_params(axis='y', labelcolor=color)
        ax2 = ax1.twinx()  
        color = 'tab:red'
        ax2.set_ylabel('Voltage Applied', color=color)
        ax2.plot(thisVHistory, color=color)
        ax2.tick_params(axis='y', labelcolor=color)
        fig.tight_layout()  
        plt.show()

    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Array0_SwitchONTests1')
# Out:
# SET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 1.1119257086999022e-06  Final G= 0.00020869990224828933
# RESET: Array 0 , device (row= 0 col= 0 ) Repeat= 0  Init G= 0.00020869990224828933  Final G= 1.163245356793744e-06
# SET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0  Final G= 0.0001687846203975236
# RESET: Array 0 , device (row= 10 col= 10 ) Repeat= 0  Init G= 0.0001687846203975236  Final G= 0.0
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205912-RCLab1_Array0_SwitchONTests1.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191009-205912-RCLab1_Array0_SwitchONTests1.mat

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0, 10, 20])
actualCols = np.array([1, 11, 21])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 4.3, 0.1)
vAppliedReset = np.arange(0.1, 3.5, 0.1)
vGateSet = np.arange(0.6, 1.8, 0.05)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
maxGProtect = 500e-6
targetGFormed = 100e-6
GTargetOFF = 2e-6
numRepeats = 10

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= targetGFormed:
                    break
            if currG >= targetGFormed:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)

save_workspace(vars(), note='RCLab1_Arr0_ON_3Dev_10Rep')
# Out:
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 0  Init G= 0.0  Final G= 0.0002811176278918214
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 0  Init G= 0.0002811176278918214  Final G= 6.158357771260997e-07
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 1  Init G= 0.0  Final G= 0.00018703160638644506
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 1  Init G= 0.00018703160638644506  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 2  Init G= 5.474095796676442e-07  Final G= 0.00010035842293906808
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 2  Init G= 0.00010035842293906808  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 3  Init G= 1.7106549364613877e-06  Final G= 0.0002149723036819811
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 3  Init G= 0.0002149723036819811  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 4  Init G= 5.474095796676442e-07  Final G= 0.00018703160638644506
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 4  Init G= 0.00018703160638644506  Final G= 0.0
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 5  Init G= 0.0  Final G= 0.0002121212121212121
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 5  Init G= 0.0002121212121212121  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 6  Init G= 1.6422287390029323e-06  Final G= 0.00010948191593352881
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 6  Init G= 0.00010948191593352881  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 7  Init G= 1.366813294232649e-05  Final G= 0.00022808732486151836
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 7  Init G= 0.00022808732486151836  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 8  Init G= 2.189638318670577e-06  Final G= 0.000114613880742913
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 8  Init G= 0.000114613880742913  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 0 col= 1 ) Repeat= 9  Init G= 1.6422287390029323e-06  Final G= 0.00020527859237536654
# RESET: Array 0 , device (row= 0 col= 1 ) Repeat= 9  Init G= 0.00020527859237536654  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 0  Init G= 0.0  Final G= 0.0002811176278918214
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 0  Init G= 0.0002811176278918214  Final G= 6.842619745845546e-08
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 1  Init G= 1.1889051808406648e-05  Final G= 0.0001687846203975236
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 1  Init G= 0.0001687846203975236  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 2  Init G= 0.0  Final G= 0.0002811176278918214
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 2  Init G= 0.0002811176278918214  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 3  Init G= 1.3685239491691093e-07  Final G= 0.0001459758879113718
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 3  Init G= 0.0001459758879113718  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 4  Init G= 0.0  Final G= 0.0001687846203975236
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 4  Init G= 0.0001687846203975236  Final G= 0.0
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 5  Init G= 0.0  Final G= 0.00013229064841968068
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 5  Init G= 0.00013229064841968068  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 6  Init G= 5.81622678396872e-07  Final G= 0.000301645487129358
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 6  Init G= 0.000301645487129358  Final G= 1.7790811339198436e-06
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 7  Init G= 3.831867057673509e-06  Final G= 0.0002423427826653633
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 7  Init G= 0.0002423427826653633  Final G= 1.2316715542521993e-06
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 8  Init G= 1.6422287390029323e-06  Final G= 0.00023721081785597914
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 8  Init G= 0.00023721081785597914  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 10 col= 11 ) Repeat= 9  Init G= 1.7106549364613877e-06  Final G= 0.0001459758879113718
# RESET: Array 0 , device (row= 10 col= 11 ) Repeat= 9  Init G= 0.0001459758879113718  Final G= 6.842619745845551e-07
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 0  Init G= 0.0  Final G= 0.0002451938742261323
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 0  Init G= 0.0002451938742261323  Final G= 0.0
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 1  Init G= 1.3685239491691093e-07  Final G= 0.00020984033887259693
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 1  Init G= 0.00020984033887259693  Final G= 6.842619745845551e-07
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 2  Init G= 6.842619745845551e-07  Final G= 0.00011176278918214398
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 2  Init G= 0.00011176278918214398  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 3  Init G= 1.0948191593352885e-06  Final G= 0.0002417725643532095
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 3  Init G= 0.0002417725643532095  Final G= 1.0948191593352885e-06
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 4  Init G= 8.211143695014662e-07  Final G= 0.0001824698598892147
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 4  Init G= 0.0001824698598892147  Final G= 0.0
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 5  Init G= 0.0  Final G= 0.0002554578038449006
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 5  Init G= 0.0002554578038449006  Final G= 0.0
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 6  Init G= 0.0  Final G= 0.00015281850765721733
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 6  Init G= 0.00015281850765721733  Final G= 2.7370478983382186e-07
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 7  Init G= 5.474095796676442e-07  Final G= 0.0002337895079830564
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 7  Init G= 0.0002337895079830564  Final G= 5.474095796676442e-07
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 8  Init G= 5.474095796676442e-07  Final G= 0.00019273378950798305
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 8  Init G= 0.00019273378950798305  Final G= 1.6422287390029323e-06
# SET: Array 0 , device (row= 20 col= 21 ) Repeat= 9  Init G= 1.1119257086999022e-06  Final G= 0.00015509938090583252
# RESET: Array 0 , device (row= 20 col= 21 ) Repeat= 9  Init G= 0.00015509938090583252  Final G= 1.7790811339198436e-06
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191010-181024-RCLab1_Arr0_ON_3Dev_10Rep.pkl
# Saving In(<class 'list'>), arr(<class 'int'>), VADC_boundary(<class 'numpy.ndarray'>), VRefHiCmp(<class 'numpy.ndarray'>), vOffset(<class 'int'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), Vref(<class 'float'>), rdCurrs(<class 'list'>), rdCurrs1(<class 'list'>), vRead(<class 'float'>), adc_raw(<class 'int'>), VADC_read_first(<class 'float'>), gainFirst(<class 'int'>), rdCurr1(<class 'float'>), secondVRefHiCmp(<class 'numpy.float64'>), VADC_read_sec(<class 'float'>), finalADCOut(<class 'numpy.float64'>), rdCurr(<class 'float'>), color(<class 'str'>), ts(<class 'float'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vAppliedSet(<class 'numpy.ndarray'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), maxGProtect(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), targetGFormed(<class 'float'>), to 20191010-181024-RCLab1_Arr0_ON_3Dev_10Rep.mat

# %%
import dut_func as dut
import serial
import time
import struct
import numpy as np
from bitstring import BitArray
import matplotlib.pyplot as plt
import dut_a0 as a0
from misc import *
drv = dut.drv

from lib_nn_dpe import NN_dpe
from lib_data import *
import time
from IPython import display

load_workspace(vars(), 'dataset/20190815-132601-weights')
load_workspace(vars(), 'dataset/mnist')
# Out:
# Loaded: weights,
# Loaded: train_images, train_labels, test_images, test_labels,

# %%
aa = np.zeros((3,2))-np.inf
aa[1,1]=(np.inf)
bb = np.zeros((3,2))
print(aa)
if (np.any(aa > 1) | np.all(aa < 0)):
    print('yes')
else:
    print('no')
# Out:
# [[-inf -inf]
#  [-inf  inf]
#  [-inf -inf]]
# yes

# %%
arr=0
rr=0
cc=1

Vreads = np.arange(0, 0.25, 0.01)
Vgate = 5
Vref = 0.5
rdCurrs = []
    
ts = time.time()
for vRead in Vreads:
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    #rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)    
    #rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    rdCurrs.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))

print(time.time()-ts)
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Read Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()
# Out:
# 1.3981940746307373

# %%
import dut_func as dut
import serial
import time
import struct
import numpy as np
from bitstring import BitArray
import matplotlib.pyplot as plt
import dut_a0 as a0
from misc import *
from dpe import DPE
from lib_data import *
from lib_nn_dpe import NN_dpe
from IPython import display


targetG = np.zeros((64,64))
targetTolerance = np.zeros((64,64))+np.inf
#targetG[0,0] = 10e-6
targetG[0,3] = 50e-6

#targetTolerance[0,0] = 4e-6
targetTolerance[0,3] = 30e-6
vSetRamp = np.arange(0.1, 4.35, 0.25)
vResetRamp = np.arange(0.1, 3.5, 0.25)
vGateSetRamp = np.arange(0.5, 1.15, 0.1)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)
array = 0
maxLoops = 2

finalGMatrix = a0.array_program(targetG, targetTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, array, maxLoops=maxLoops)
plt.imshow(finalGMatrix * 1e6)
plt.colorbar()
# Out:
# Now turning ON
# Set, Vgate =  0.5
# Set, Vgate =  0.6
# Set, Vgate =  0.7
# Set, Vgate =  0.7999999999999999
# Set, Vgate =  0.8999999999999999
# Set, Vgate =  0.9999999999999999
# Set, Vgate =  1.0999999999999999
# Current loop =  1
# Completed with total loops =  1

# %%
from lib_data import *
import scipy.io as sio

actualRows = np.array([0])
actualCols = np.array([3])
totalDevices = np.size(actualRows)

VreadGate = 5.0
vRead = 0.2
arr = 0

vAppliedSet = np.arange(0.1, 4.1, 0.5)
vAppliedReset = np.arange(0.1, 3.5, 0.25)
vGateSet = np.arange(0.5, 1.15, 0.05)
vGateReset = np.arange(5.0, 5.5, 0.5)

AllDevicesGHistory = []
AllDevicesVHistory = []
AllDevicesVGateHistory = []

Vref = 0.5
targetGFormed = 50e-6
GTargetOFF = 10e-6
numRepeats = 1

for jj in range(totalDevices):
    rr = actualRows[jj]
    cc = actualCols[jj]
    GHistory = []
    VHistory = []
    VGateHistory = []

    for nn in range(numRepeats):
        thisGHistory = []
        thisVHistory = []
        thisVGateHistory = []
        # Do a first read of this device
        rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
        #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)             
        currG = rdCurr/vRead
        thisGHistory.append(currG)
        thisVHistory.append(0)
        thisVGateHistory.append(0)
        #print('Initial G=', currG, 'Target G =', thisGtarget)
        initG = currG
        
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                thisVGateHistory.append(vgate)
                if currG >= targetGFormed:
                    break
            if currG >= targetGFormed:
                break
        
        print('SET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', initG, ' Final G=', currG)
        beforeRESETG = currG
        # Now try to reset the device to repeat the SET switching again
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=VreadGate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                thisVGateHistory.append(vgate)
                if currG <= GTargetOFF:
                    break
            if currG <= GTargetOFF:
                break

        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)
        VGateHistory.append(thisVGateHistory)
        print('RESET: Array', arr, ', device (row=', rr, 'col=', cc, ') Repeat=', nn,' Init G=', beforeRESETG, ' Final G=', currG)
        
    AllDevicesGHistory.append(GHistory)
    AllDevicesVHistory.append(VHistory)
    AllDevicesVGateHistory.append(VGateHistory)
# Out:
# SET: Array 0 , device (row= 0 col= 3 ) Repeat= 0  Init G= 1.67644183773216e-06  Final G= 0.0002018572825024438
# RESET: Array 0 , device (row= 0 col= 3 ) Repeat= 0  Init G= 0.0002018572825024438  Final G= 9.425708699902249e-06

# %%
zeroMatrix = np.zeros((64,64))
vGateSetMatrix = zeroMatrix + 0
vWriteSetMatrix = zeroMatrix + 0.25
array = 0

ts = time.time()
a0.pic_write_batch(vWriteSetMatrix, vGateSetMatrix, array=array, mode=1)
print(time.time()-ts)
# Out:
# 0.42575812339782715

# %%
targetG = np.zeros((64,64))
targetTolerance = np.zeros((64,64))+np.inf
#targetG[0,0] = 10e-6
targetG[1,1] = 20e-6

plt.imshow(targetG * 1e6)
plt.colorbar()

# %%
arr=0
rr=0
cc=3

Vreads = np.arange(0, 0.25, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
    
ts = time.time()
for vRead in Vreads:
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    #rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)    
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    #rdCurrs.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))

print(time.time()-ts)
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Read Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()
# Out:
# 0.7835493087768555

# %%
arr=0
rr=0
cc=3

Vreads = np.arange(0, 0.25, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
    
ts = time.time()
for vRead in Vreads:
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    #rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)    
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    #rdCurrs.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))

print(time.time()-ts)
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('Read Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()
# Out:
# 1.0414464473724365

# %%
Vread=0.2
array = 1
GMatrix = a0.pic_read_batch(array, Vread=Vread, gain=-1) / Vread
plt.imshow(GMatrix * 1e6)
plt.colorbar()

# %%
GMatrix[2,19]*1e6
# Out:
# 473.8514173998045

# %%
arr=0
rr=0
cc=3

Vreads = np.arange(0, 0.45, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrsBatch = []
    
ts = time.time()
for vRead in Vreads:
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    IMatrix = a0.pic_read_batch(arr, Vread=vRead, gain=-1)
    rdCurrsBatch.append(IMatrix[rr,cc])
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('PIC READ Single Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('PIC Batch Read Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrsBatch], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=0
rr=0
cc=3

Vreads = np.arange(0, 0.45, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrsBatch = []
    
ts = time.time()
for vRead in Vreads:
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=3))
    IMatrix = a0.pic_read_batch(arr, Vread=vRead, gain=3)
    rdCurrsBatch.append(IMatrix[rr,cc])
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('PIC READ Single Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('PIC Batch Read Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrsBatch], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=1
rr=2
cc=19

Vreads = np.arange(0, 0.45, 0.005)
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrsBatch = []
    
ts = time.time()
for vRead in Vreads:
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    IMatrix = a0.pic_read_batch(arr, Vread=vRead, gain=-1)
    rdCurrsBatch.append(IMatrix[rr,cc])
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('PIC READ Single Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('PIC Batch Read Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrsBatch], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=1
rr=2
cc=19

Vreads = np.arange(0, 0.45, 0.01)
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrsBatch = []
    
ts = time.time()
for vRead in Vreads:
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=2))
    time.sleep(1)
    IMatrix = a0.pic_read_batch(arr, Vread=vRead, gain=2)
    rdCurrsBatch.append(IMatrix[rr,cc])
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('PIC READ Single Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('PIC Batch Read Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrsBatch], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

# %%
arr=1
rr=2
cc=19

Vreads = np.arange(0, 0.45, 0.01)
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrsBatch = []
    
start_pic_time = time.time()
for vRead in Vreads:
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))

pic_time = time.time() - start_pic_time

start_single_time = time.time()

for vRead in Vreads:
    #rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    rdCurrsBatch.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))
    
rd_single_time = time.time() - start_single_time 
        
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('PIC READ Single Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Read Single Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrsBatch], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

print('Total Read PIC time = ', pic_time)
print('Total Single Read time = ', rd_single_time)
# Out:
# Total Read PIC time =  1.1304526329040527
# Total Single Read time =  4.657217025756836

# %%
arr=0
rr=0
cc=0

Vreads = np.arange(0, 0.45, 0.01)
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrsBatch = []
    
start_pic_time = time.time()
for vRead in Vreads:
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))

pic_time = time.time() - start_pic_time

start_single_time = time.time()

for vRead in Vreads:
    #rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    rdCurrsBatch.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))
    
rd_single_time = time.time() - start_single_time 
        
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('PIC READ Single Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Read Single Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrsBatch], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

print('Total Read PIC time = ', pic_time)
print('Total Single Read time = ', rd_single_time)
# Out:
# Total Read PIC time =  0.9176204204559326
# Total Single Read time =  3.8172903060913086

# %%
array = 0
targetRow = 0
targetCol = 0

targetG = 60e-6
targetTolerance = 6e-6

vSetRamp = np.arange(0.2, 3.4, 0.1)
vGateSetRamp = np.arange(0.6, 1.4, 0.05)

vResetRamp = np.arange(0.1, 3.5, 0.1)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)

maxLoops = 3

initG = a0.pic_read_single(array, targetRow, targetCol, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
finalG = a0.cell_program(array, targetRow, targetCol, targetG, targetTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)

print('Initial G=', initG, ', Target G=', targetG, ', Final G=', finalG)
# Out:
# Now turning ON
# Current loop =  1
# Now turning ON
# Current loop =  2
# Now turning ON
# Current loop =  3
# Now turning ON
# Current loop =  4
# Completed with total loops =  4
# Initial G= 0.0 , Target G= 6e-05 , Final G= 0.0

# %%
array = 0
targetRow = 0
targetCol = 1

targetG = 60e-6
targetTolerance = 6e-6

vSetRamp = np.arange(0.2, 4.2, 0.25)
vGateSetRamp = np.arange(0.6, 1.4, 0.05)

vResetRamp = np.arange(0.1, 3.5, 0.1)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)

maxLoops = 2

initG = a0.pic_read_single(array, targetRow, targetCol, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
finalG = a0.cell_program(array, targetRow, targetCol, targetG, targetTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)

print('Initial G=', initG, ', Target G=', targetG, ', Final G=', finalG)
# Out:
# Now turning ON
# Now turning OFF
# Current loop =  1
# Now turning ON
# Now turning OFF
# Current loop =  2
# Now turning ON
# Current loop =  3
# Completed with total loops =  3
# Initial G= 0.0 , Target G= 6e-05 , Final G= 6.132697947214077e-05

# %%
array = 0
targetRow = 10
targetCol = 11

targetG = 40e-6
targetTolerance = 5e-6

vSetRamp = np.arange(0.2, 4.2, 0.25)
vGateSetRamp = np.arange(0.6, 1.4, 0.05)

vResetRamp = np.arange(0.1, 3.5, 0.1)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)

maxLoops = 3

initG = a0.pic_read_single(array, targetRow, targetCol, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
finalG = a0.cell_program(array, targetRow, targetCol, targetG, targetTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)

print('Initial G=', initG, ', Target G=', targetG, ', Final G=', finalG)
# Out:
# Now turning ON
# Now turning OFF
# Current loop =  1
# Now turning ON
# Now turning OFF
# Current loop =  2
# Now turning ON
# Now turning OFF
# Current loop =  3
# Now turning ON
# Current loop =  4
# Completed with total loops =  4
# Initial G= 6.220563405314133e-08 , Target G= 4e-05 , Final G= 4.336510263929618e-05

# %%
array = 0
targetRow = 0
targetCol = 0

targetG = 50e-6
targetTolerance = 5e-6

vSetRamp = np.arange(0.2, 4.45, 0.25)
vGateSetRamp = np.arange(0.6, 1.4, 0.1)

vResetRamp = np.arange(0.1, 3.5, 0.1)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)

maxLoops = 1

initG = a0.pic_read_single(array, targetRow, targetCol, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
finalG = a0.cell_program(array, targetRow, targetCol, targetG, targetTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)

print('Initial G=', initG, ', Target G=', targetG, ', Final G=', finalG)
# Out:
# Now turning ON
# Now turning OFF
# Current loop =  1
# Completed with total loops =  1
# Initial G= 0.0 , Target G= 5e-05 , Final G= 4.849706744868035e-05

# %%
arr = 0
vRead=0.2
vgate = 5.0
numRows = 64
numCols = 64
Gmap0pre = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap0pre[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap0pre)
plt.colorbar()

# %%
arr = 1
vRead=0.2
vgate = 5.0
numRows = 64
numCols = 64
Gmap1pre = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap1pre[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap1pre)
plt.colorbar()

# %%
from lib_data import *
import scipy.io as sio
mat_contents = sio.loadmat('Exported20Node_GraphNum0.mat')
turnONRows = mat_contents['turnONRows']
turnONCols = mat_contents['turnONCols']
turnOFFRows = mat_contents['turnOFFRows']
turnOFFCols = mat_contents['turnOFFCols']

turnONRows=turnONRows[0]
turnONCols=turnONCols[0]
turnOFFRows=turnOFFRows[0]
turnOFFCols=turnOFFCols[0]

numDevices = np.size(turnONRows)
numOFFDevices = np.size(turnOFFRows)

vRead = 0.2

arr = 0
Vgate = 5
Vref = 0.5

targetGON = 11e-6
targetONTolerance = 1e-6
targetGOFF = 0.5e-6
targetOFFTolerance = 0.5e-6

vSetRamp = np.arange(0.4, 4.4, 0.2)
vGateSetRamp = np.arange(0.6, 1.4, 0.05)
vResetRamp = np.arange(0.3, 3.8, 0.1)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)
maxLoops = 4

for ii in range(numDevices):
    rr = turnONRows[ii]
    cc = turnONCols[ii]        
    initG = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
    finalG = a0.cell_program(arr, rr, cc, targetGON, targetONTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)
    if ( (finalG >= (targetGON-targetONTolerance)) & (finalG <= (targetGON+targetONTolerance)) ):
        print('Success! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGON))
    else:
        print('Fail! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGON))
    
time.sleep(15)
arr = 0
numRows = 64
numCols = 64
Gmap0post = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap0post[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap0post)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RCLab1_Arr0_Hopfield20_G0_AfterON')


for ii in range(numOFFDevices):
    rr = turnOFFRows[ii]
    cc = turnOFFCols[ii]        
    initG = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
    finalG = a0.cell_program(arr, rr, cc, targetGOFF, targetOFFTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)
    if ( (finalG >= (targetGOFF-targetOFFTolerance)) & (finalG <= (targetGOFF+targetOFFTolerance)) ):
        print('Success! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGOFF))
    else:
        print('Fail! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGOFF))
    
time.sleep(15)
arr = 0
numRows = 64
numCols = 64
Gmap0postOFF = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap0postOFF[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap0postOFF)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RCLab1_Arr0_Hopfield20_G0_AfterOFF')

#
# NOW PROGRAM ARRAY 1 WITH THE SAME GRAPH PROBLEM, BUT A HIGHER CONDUCTANCE
#

from lib_data import *
import scipy.io as sio
mat_contents = sio.loadmat('Exported20Node_GraphNum0.mat')
turnONRows = mat_contents['turnONRows']
turnONCols = mat_contents['turnONCols']
turnOFFRows = mat_contents['turnOFFRows']
turnOFFCols = mat_contents['turnOFFCols']

turnONRows=turnONRows[0]
turnONCols=turnONCols[0]
turnOFFRows=turnOFFRows[0]
turnOFFCols=turnOFFCols[0]

numDevices = np.size(turnONRows)
numOFFDevices = np.size(turnOFFRows)

vRead = 0.2

arr = 1
Vgate = 5
Vref = 0.5

targetGON = 100e-6
targetONTolerance = 10e-6
targetGOFF = 2e-6
targetOFFTolerance = 2e-6

vSetRamp = np.arange(0.4, 4.6, 0.2)
vGateSetRamp = np.arange(0.6, 1.4, 0.05)
vResetRamp = np.arange(0.3, 3.8, 0.1)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)
maxLoops = 4

for ii in range(numDevices):
    rr = turnONRows[ii]
    cc = turnONCols[ii]        
    initG = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
    finalG = a0.cell_program(arr, rr, cc, targetGON, targetONTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)
    if ( (finalG >= (targetGON-targetONTolerance)) & (finalG <= (targetGON+targetONTolerance)) ):
        print('Success! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGON))
    else:
        print('Fail! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGON))
    

time.sleep(15)

numRows = 64
numCols = 64
Gmap1post = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap1post[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap1post)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RCLab1_Arr1_Hopfield20_G0_AfterON')


for ii in range(numOFFDevices):
    rr = turnOFFRows[ii]
    cc = turnOFFCols[ii]        
    initG = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
    finalG = a0.cell_program(arr, rr, cc, targetGOFF, targetOFFTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)
    if ( (finalG >= (targetGOFF-targetOFFTolerance)) & (finalG <= (targetGOFF+targetOFFTolerance)) ):
        print('Success! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGOFF))
    else:
        print('Fail! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', currG, 'Err=', (currG-targetGOFF))
    

time.sleep(15)

numRows = 64
numCols = 64
Gmap1postOFF = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap1postOFF[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap1postOFF)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RCLab1_Arr1_Hopfield20_G0_AfterOFF')
# Out:
# Fail! Array 0 , device (row= 2 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 4 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 6 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 7 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 9 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 13 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 14 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 16 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 17 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 20 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 1 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 3 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 4 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 9 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 11 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 12 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 15 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 17 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 19 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 20 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 2 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 4 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 10 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 11 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 12 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 15 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 16 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 20 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 1 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 2 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 3 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 5 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 8 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 11 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 13 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 14 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 18 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 4 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 9 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 15 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 17 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 18 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 19 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 20 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 1 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 5 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 9 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 10 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 12 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 13 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 16 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 17 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 20 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 1 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 3 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 4 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 5 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 6 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 8 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 12 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 16 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 18 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 20 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 4 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 9 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 12 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 18 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 20 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 1 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 2 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 5 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 6 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 8 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 10 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 13 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 15 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 16 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 17 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 19 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 3 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 9 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 13 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 15 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 16 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 18 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 19 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 2 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 3 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 4 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 15 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 17 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 18 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 19 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 2 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 3 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 7 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 8 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 15 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 16 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 1 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 4 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 9 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 10 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 14 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 15 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 17 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 18 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 19 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 1 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 2 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 4 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 10 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 11 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 13 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 15 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 17 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 19 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 20 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 2 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 3 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 5 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 9 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 10 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 11 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 12 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 13 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 17 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 1 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 3 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 9 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 10 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 12 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 17 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 18 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 1 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 2 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 5 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 9 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 11 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 13 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 15 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 16 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 19 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 20 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 4 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 5 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 7 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 8 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 10 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 11 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 13 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 16 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 20 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 2 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 5 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 9 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 10 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 11 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 13 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 14 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 17 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 1 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 2 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 3 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 5 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 6 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 7 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 8 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Fail! Array 0 , device (row= 14 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 17 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Success! Array 0 , device (row= 18 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= -1.5742913000977507e-06
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), targetG(<class 'float'>), targetTolerance(<class 'float'>), vSetRamp(<class 'numpy.ndarray'>), vResetRamp(<class 'numpy.ndarray'>), vGateSetRamp(<class 'numpy.ndarray'>), vGateResetRamp(<class 'numpy.ndarray'>), array(<class 'int'>), maxLoops(<class 'int'>), finalGMatrix(<class 'numpy.ndarray'>), vAppliedSet(<class 'numpy.ndarray'>), vapp(<class 'numpy.float64'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vRead(<class 'float'>), arr(<class 'int'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), Vref(<class 'float'>), targetGFormed(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), rr(<class 'int'>), cc(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), rdCurr(<class 'float'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'float'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), rdCurrs(<class 'list'>), ts(<class 'float'>), color(<class 'str'>), g(<class 'numpy.ndarray'>), Vread(<class 'float'>), GMatrix(<class 'numpy.ndarray'>), rdCurrsBatch(<class 'list'>), IMatrix(<class 'numpy.ndarray'>), start_pic_time(<class 'float'>), pic_time(<class 'float'>), start_single_time(<class 'float'>), rd_single_time(<class 'float'>), targetRow(<class 'int'>), targetCol(<class 'int'>), finalG(<class 'float'>), numRows(<class 'int'>), numCols(<class 'int'>), Gmap0pre(<class 'numpy.ndarray'>), Gmap1pre(<class 'numpy.ndarray'>), mat_contents(<class 'dict'>), turnONRows(<class 'numpy.ndarray'>), turnONCols(<class 'numpy.ndarray'>), turnOFFRows(<class 'numpy.ndarray'>), turnOFFCols(<class 'numpy.ndarray'>), numDevices(<class 'int'>), numOFFDevices(<class 'int'>), targetGON(<class 'float'>), targetONTolerance(<class 'float'>), targetGOFF(<class 'float'>), targetOFFTolerance(<class 'float'>), ii(<class 'int'>), Gmap0post(<class 'numpy.ndarray'>), to 20191014-233545-RCLab1_Arr0_Hopfield20_G0_AfterON.pkl
# Saving In(<class 'list'>), targetG(<class 'float'>), targetTolerance(<class 'float'>), vSetRamp(<class 'numpy.ndarray'>), vResetRamp(<class 'numpy.ndarray'>), vGateSetRamp(<class 'numpy.ndarray'>), vGateResetRamp(<class 'numpy.ndarray'>), array(<class 'int'>), maxLoops(<class 'int'>), finalGMatrix(<class 'numpy.ndarray'>), vAppliedSet(<class 'numpy.ndarray'>), vapp(<class 'numpy.float64'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vRead(<class 'float'>), arr(<class 'int'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), Vref(<class 'float'>), targetGFormed(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), rr(<class 'int'>), cc(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), rdCurr(<class 'float'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'float'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), rdCurrs(<class 'list'>), ts(<class 'float'>), color(<class 'str'>), g(<class 'numpy.ndarray'>), Vread(<class 'float'>), GMatrix(<class 'numpy.ndarray'>), rdCurrsBatch(<class 'list'>), IMatrix(<class 'numpy.ndarray'>), start_pic_time(<class 'float'>), pic_time(<class 'float'>), start_single_time(<class 'float'>), rd_single_time(<class 'float'>), targetRow(<class 'int'>), targetCol(<class 'int'>), finalG(<class 'float'>), numRows(<class 'int'>), numCols(<class 'int'>), Gmap0pre(<class 'numpy.ndarray'>), Gmap1pre(<class 'numpy.ndarray'>), turnONRows(<class 'numpy.ndarray'>), turnONCols(<class 'numpy.ndarray'>), turnOFFRows(<class 'numpy.ndarray'>), turnOFFCols(<class 'numpy.ndarray'>), numDevices(<class 'int'>), numOFFDevices(<class 'int'>), targetGON(<class 'float'>), targetONTolerance(<class 'float'>), targetGOFF(<class 'float'>), targetOFFTolerance(<class 'float'>), ii(<class 'int'>), Gmap0post(<class 'numpy.ndarray'>), to 20191014-233545-RCLab1_Arr0_Hopfield20_G0_AfterON.mat
# Success! Array 0 , device (row= 1 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 15 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 1 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 2 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 14 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 17 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 3 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 15 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 17 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 4 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 14 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 5 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 15 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 6 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 15 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 17 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 7 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 14 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 15 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 17 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 8 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 14 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 9 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 17 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 10 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 11 ) Init G= 1.3120723362658846e-05  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 11 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 14 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 17 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 14 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 15 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 5 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 11 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 13 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 14 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 15 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 16 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 19 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 20 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 4 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 7 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 8 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 10 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 17 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 18 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 1 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 2 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 3 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 6 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 9 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# Success! Array 0 , device (row= 12 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 8.925708699902249e-06
# ...
# Success! Array 1 , device (row= 4 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 5 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 9 col= 12 ) Init G= 0.0003529651352231997  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 10 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 11 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 12 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 13 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 14 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 17 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 18 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 19 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 20 col= 12 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 2 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 3 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 5 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 7 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 8 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 11 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 12 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 13 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 16 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 20 col= 13 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 3 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 5 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 8 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 9 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 12 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 14 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 16 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 18 col= 14 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 1 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 4 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 6 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 7 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 8 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 15 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 16 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 18 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 19 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 20 col= 15 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 2 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 4 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 5 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 8 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 11 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 13 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 14 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 15 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 16 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 19 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 20 col= 16 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 3 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 4 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 7 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 8 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 10 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 12 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 17 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 18 col= 17 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 1 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 2 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 3 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 6 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 9 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 12 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 14 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 15 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 17 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 18 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 19 col= 18 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 1 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 3 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 4 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 6 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 7 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 8 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 12 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 15 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 16 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 18 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 19 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 20 col= 19 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 4 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 9 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 10 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 11 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 12 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 13 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 15 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 16 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 19 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Success! Array 1 , device (row= 20 col= 20 ) Init G= 0.0  Final G= 9.425708699902249e-06 Err= 7.4257086999022496e-06
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), targetG(<class 'float'>), targetTolerance(<class 'float'>), vSetRamp(<class 'numpy.ndarray'>), vResetRamp(<class 'numpy.ndarray'>), vGateSetRamp(<class 'numpy.ndarray'>), vGateResetRamp(<class 'numpy.ndarray'>), array(<class 'int'>), maxLoops(<class 'int'>), finalGMatrix(<class 'numpy.ndarray'>), vAppliedSet(<class 'numpy.ndarray'>), vapp(<class 'numpy.float64'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vRead(<class 'float'>), arr(<class 'int'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), Vref(<class 'float'>), targetGFormed(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), rr(<class 'int'>), cc(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), rdCurr(<class 'float'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'float'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), rdCurrs(<class 'list'>), ts(<class 'float'>), color(<class 'str'>), g(<class 'numpy.ndarray'>), Vread(<class 'float'>), GMatrix(<class 'numpy.ndarray'>), rdCurrsBatch(<class 'list'>), IMatrix(<class 'numpy.ndarray'>), start_pic_time(<class 'float'>), pic_time(<class 'float'>), start_single_time(<class 'float'>), rd_single_time(<class 'float'>), targetRow(<class 'int'>), targetCol(<class 'int'>), finalG(<class 'float'>), numRows(<class 'int'>), numCols(<class 'int'>), Gmap0pre(<class 'numpy.ndarray'>), Gmap1pre(<class 'numpy.ndarray'>), mat_contents(<class 'dict'>), turnONRows(<class 'numpy.ndarray'>), turnONCols(<class 'numpy.ndarray'>), turnOFFRows(<class 'numpy.ndarray'>), turnOFFCols(<class 'numpy.ndarray'>), numDevices(<class 'int'>), numOFFDevices(<class 'int'>), targetGON(<class 'float'>), targetONTolerance(<class 'float'>), targetGOFF(<class 'float'>), targetOFFTolerance(<class 'float'>), ii(<class 'int'>), Gmap0post(<class 'numpy.ndarray'>), Gmap0postOFF(<class 'numpy.ndarray'>), Gmap1post(<class 'numpy.ndarray'>), Gmap1postOFF(<class 'numpy.ndarray'>), to 20191015-015030-RCLab1_Arr1_Hopfield20_G0_AfterOFF.pkl
# Saving In(<class 'list'>), targetG(<class 'float'>), targetTolerance(<class 'float'>), vSetRamp(<class 'numpy.ndarray'>), vResetRamp(<class 'numpy.ndarray'>), vGateSetRamp(<class 'numpy.ndarray'>), vGateResetRamp(<class 'numpy.ndarray'>), array(<class 'int'>), maxLoops(<class 'int'>), finalGMatrix(<class 'numpy.ndarray'>), vAppliedSet(<class 'numpy.ndarray'>), vapp(<class 'numpy.float64'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vRead(<class 'float'>), arr(<class 'int'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), Vref(<class 'float'>), targetGFormed(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), rr(<class 'int'>), cc(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), rdCurr(<class 'float'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'float'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), rdCurrs(<class 'list'>), ts(<class 'float'>), color(<class 'str'>), g(<class 'numpy.ndarray'>), Vread(<class 'float'>), GMatrix(<class 'numpy.ndarray'>), rdCurrsBatch(<class 'list'>), IMatrix(<class 'numpy.ndarray'>), start_pic_time(<class 'float'>), pic_time(<class 'float'>), start_single_time(<class 'float'>), rd_single_time(<class 'float'>), targetRow(<class 'int'>), targetCol(<class 'int'>), finalG(<class 'float'>), numRows(<class 'int'>), numCols(<class 'int'>), Gmap0pre(<class 'numpy.ndarray'>), Gmap1pre(<class 'numpy.ndarray'>), turnONRows(<class 'numpy.ndarray'>), turnONCols(<class 'numpy.ndarray'>), turnOFFRows(<class 'numpy.ndarray'>), turnOFFCols(<class 'numpy.ndarray'>), numDevices(<class 'int'>), numOFFDevices(<class 'int'>), targetGON(<class 'float'>), targetONTolerance(<class 'float'>), targetGOFF(<class 'float'>), targetOFFTolerance(<class 'float'>), ii(<class 'int'>), Gmap0post(<class 'numpy.ndarray'>), Gmap0postOFF(<class 'numpy.ndarray'>), Gmap1post(<class 'numpy.ndarray'>), Gmap1postOFF(<class 'numpy.ndarray'>), to 20191015-015030-RCLab1_Arr1_Hopfield20_G0_AfterOFF.mat

# %%
mat_contents = sio.loadmat('Exported20Node_GraphNum0.mat')
turnONRows = mat_contents['turnONRows']
turnONCols = mat_contents['turnONCols']
turnOFFRows = mat_contents['turnOFFRows']
turnOFFCols = mat_contents['turnOFFCols']
turnONRows=turnONRows[0]
turnONCols=turnONCols[0]
turnOFFRows=turnOFFRows[0]
turnOFFCols=turnOFFCols[0]
numDevices = np.size(turnONRows)
numOFFDevices = np.size(turnOFFRows)
targetGraph0 = np.zeros((21,21))
for ii in range(numDevices):
    rr = turnONRows[ii]
    cc = turnONCols[ii]        
    targetGraph0[rr,cc] = 1
    
plt.imshow(targetGraph0)
plt.colorbar()

# %%
plt.imshow(Gmap0postOFF[:21,:21], clim=[0, 10])
plt.colorbar()

# %%
plt.imshow(Gmap1postOFF[:21,:21], clim = [0, 100])
plt.colorbar()

# %%
g = dpe.read(1)
plt.imshow(g[:21,:21] * 1e6,  clim = [0, 100])
plt.colorbar()
# Out:
# Running <function DPE.read at 0x01143F60> with serial
# [INFO] Elapsed time = 0.32s
# Serial disconnected

# %%
arr=1
rr=13
cc=9

Vreads = np.arange(0, 0.45, 0.01)
Vgate = 5
Vref = 0.5
rdCurrs = []
rdCurrsBatch = []
    
start_pic_time = time.time()
for vRead in Vreads:
    rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))

pic_time = time.time() - start_pic_time

start_single_time = time.time()

for vRead in Vreads:
    #rdCurrs.append(a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1))
    rdCurrsBatch.append(a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1))
    
rd_single_time = time.time() - start_single_time 
        
fig, ax1 = plt.subplots()
color = 'tab:blue'
ax1.set_xlabel('Vread')
ax1.set_ylabel('PIC READ Single Current (uA)', color=color)
ax1.plot(Vreads, [i* 1e6 for i in rdCurrs], color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Read Single Current (uA)', color=color)
ax2.plot(Vreads, [i* 1e6 for i in rdCurrsBatch], color=color)
ax2.tick_params(axis='y', labelcolor=color)
fig.tight_layout()  
plt.show()

print('Total Read PIC time = ', pic_time)
print('Total Single Read time = ', rd_single_time)
# Out:
# Total Read PIC time =  0.9778304100036621
# Total Single Read time =  6.7029948234558105

# %%
g = dpe.read(1)
plt.imshow(g[:21,:21] * 1e6)
plt.colorbar()

# %%
from lib_data import *
import scipy.io as sio
mat_contents = sio.loadmat('Exported60Node_GraphNum0.mat')
turnONRows = mat_contents['turnONRows']
turnONCols = mat_contents['turnONCols']
turnOFFRows = mat_contents['turnOFFRows']
turnOFFCols = mat_contents['turnOFFCols']

turnONRows=turnONRows[0]
turnONCols=turnONCols[0]
turnOFFRows=turnOFFRows[0]
turnOFFCols=turnOFFCols[0]

numDevices = np.size(turnONRows)
numOFFDevices = np.size(turnOFFRows)

VreadGate = 5.0
vRead = 0.2

arr = 0
startRow = 0
startCol = 0
numRows = 60
numCols = 60
GMin = 2e-6
GMax = 100e-6

targetGVal = GMax
targetGThresh = 4e-6

vAppliedSet = np.arange(0.4, 4.4, 0.25)
vAppliedReset = np.arange(0.5, 3.6, 0.2)
vGateSet = np.arange(0.6, 1.8, 0.1)
vGateReset = np.arange(5.0, 5.5, 0.5)

GHistory = []
VHistory = []

Vgate = 5
Vref = 0.5

for ii in range(numDevices):
    rr = turnONRows[ii]
    cc = turnONCols[ii]        
    thisGtarget = targetGVal
    thisGHistory = []
    thisVHistory = []
    thisGainHistory = []
    # Do a first read of this device
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)
    currG = rdCurr/vRead
    thisGHistory.append(currG)
    thisVHistory.append(0)
    #print('Initial G=', currG, 'Target G =', thisGtarget)
    initG = currG
    # Now, if device is lower than target, SET it
    if currG < (thisGtarget-targetGThresh):
        for vgate in vGateSet:
            for vappset in vAppliedSet:
                # Apply vappset pulse, then read
                a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)
                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(vappset)
                if currG >= (thisGtarget-targetGThresh):
                    break
            if currG >= (thisGtarget-targetGThresh):
                break
        GHistory.append(thisGHistory)
        VHistory.append(thisVHistory)

    # Else, if device is higher than target, RESET it, then SET it
    elif currG > (thisGtarget+targetGThresh):
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)

                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                if currG <= (thisGtarget+targetGThresh):
                    break
            if currG <= (thisGtarget+targetGThresh):
                break

        #Now if it is below Gtarget, then do SET operations; If it is above Gtarget, then Reset failed and device stuck ON
        
        #if currG <= thisGtarget and thisGtarget >= 2.5e-6:
        if currG <= (thisGtarget-targetGThresh):
            for vgate in vGateSet:
                for vappset in vAppliedSet:
                    # Apply vappset pulse, then read
                    a0.set_single_int(vappset, vgate, array=arr, row=rr, col=cc)

                    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1) 
                    rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)
                    currG = rdCurr/vRead
                    thisGHistory.append(currG)
                    thisVHistory.append(vappset)
                    if currG >= (thisGtarget-targetGThresh):
                        break
                if currG >= (thisGtarget-targetGThresh):
                    break

    GHistory.append(thisGHistory)
    VHistory.append(thisVHistory)
    print('Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Target G=', thisGtarget, ' Final G=', currG, 'Err=', (currG-thisGtarget))

time.sleep(15)

arr = 0
numRows = 64
numCols = 64
vRead = 0.2
vReadGate = 5.0
Gmap0post = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)    
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)
            Gmap0post[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap0post)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RC1_60_Graph0_ARRAY0')


mat_contents = sio.loadmat('Exported60Node_GraphNum0.mat')
turnOFFRows = mat_contents['turnOFFRows']
turnOFFCols = mat_contents['turnOFFCols']

turnOFFRows=turnOFFRows[0]
turnOFFCols=turnOFFCols[0]

numDevices = np.size(turnONRows)
numOFFDevices = np.size(turnOFFRows)

VreadGate = 5.0
vRead = 0.2

arr = 0
startRow = 0
startCol = 0
numRows = 60
numCols = 60
GMin = 3e-6
GMax = 100e-6

targetGValOFF = GMin
targetGThresh = 3e-6

vAppliedSet = np.arange(0.4, 4.4, 0.2)
vAppliedReset = np.arange(0.5, 3.6, 0.1)
vGateSet = np.arange(0.4, 1.8, 0.05)
vGateReset = np.arange(5.0, 5.5, 0.5)

GHistoryOFF = []
VHistoryOFF = []

Vgate = 5
Vref = 0.5


for ii in range(numOFFDevices):
    rr = turnOFFRows[ii]
    cc = turnOFFCols[ii]        
    thisGtarget = GMin
    thisGHistory = []
    thisVHistory = []
    thisGainHistory = []
    # Do a first read of this device
    #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
    rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)
    currG = rdCurr/vRead
    thisGHistory.append(currG)
    thisVHistory.append(0)
    #print('Initial G=', currG, 'Target G =', thisGtarget)
    initG = currG
    
    if currG > (thisGtarget+targetGThresh):
        for vgate in vGateReset:
            for vappreset in vAppliedReset:
                # Apply vappreset pulse, then read
                a0.reset_single_int(vappreset, vgate, array=arr, row=rr, col=cc)

                #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)
                rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)

                currG = rdCurr/vRead
                thisGHistory.append(currG)
                thisVHistory.append(-1*vappreset)
                if currG <= (thisGtarget+targetGThresh):
                    break
            if currG <= (thisGtarget+targetGThresh):
                break

    GHistoryOFF.append(thisGHistory)
    VHistoryOFF.append(thisVHistory)
    print('Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Target G=', thisGtarget, ' Final G=', currG, 'Err=', (currG-thisGtarget))


time.sleep(15)
arr = 0
numRows = 64
numCols = 64
vRead = 0.2
vReadGate = 5.0
Gmap0postOFF = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            #rdCurr = a0.read_single_int(vRead, Vgate, array=arr, row=rr, col=cc, gain=-1)  
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)
            Gmap0postOFF[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap0postOFF)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RC1_Hopfield60_Graph0_ARRAY0_OFF')
# Out:
# Array 0 , device (row= 2 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001288693385467579 Err= 2.8869338546757886e-05
# Array 0 , device (row= 3 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 5 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 8 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001847507331378299 Err= 8.475073313782989e-05
# Array 0 , device (row= 9 col= 1 ) Init G= 5.542521994134897e-06  Target G= 0.0001  Final G= 0.00013685239491691107 Err= 3.685239491691107e-05
# Array 0 , device (row= 10 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016536331052460085 Err= 6.536331052460084e-05
# Array 0 , device (row= 11 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 12 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002337895079830564 Err= 0.00013378950798305638
# Array 0 , device (row= 13 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 15 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002896709025741284 Err= 0.0001896709025741284
# Array 0 , device (row= 16 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001710654936461388 Err= 7.10654936461388e-05
# Array 0 , device (row= 19 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 20 col= 1 ) Init G= 1.3685239491691093e-07  Target G= 0.0001  Final G= 0.00011176278918214398 Err= 1.1762789182143978e-05
# Array 0 , device (row= 24 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022865754317367217 Err= 0.00012865754317367218
# Array 0 , device (row= 27 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 30 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015509938090583252 Err= 5.509938090583252e-05
# Array 0 , device (row= 31 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 34 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 35 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001556695992179863 Err= 5.5669599217986304e-05
# Array 0 , device (row= 38 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 39 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 40 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002029977191267514 Err= 0.0001029977191267514
# Array 0 , device (row= 44 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 46 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 47 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001300097751710655 Err= 3.0009775171065483e-05
# Array 0 , device (row= 48 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 50 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019159335288367548 Err= 9.159335288367548e-05
# Array 0 , device (row= 52 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002121212121212121 Err= 0.0001121212121212121
# Array 0 , device (row= 53 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 54 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 57 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011005213424568261 Err= 1.0052134245682609e-05
# Array 0 , device (row= 58 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022808732486151836 Err= 0.00012808732486151836
# Array 0 , device (row= 59 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016650374714890844 Err= 6.650374714890844e-05
# Array 0 , device (row= 60 col= 1 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002788367546432062 Err= 0.0001788367546432062
# Array 0 , device (row= 1 col= 2 ) Init G= 4.516129032258065e-06  Target G= 0.0001  Final G= 0.0002029977191267514 Err= 0.0001029977191267514
# Array 0 , device (row= 4 col= 2 ) Init G= 1.163245356793744e-06  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 5 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 8 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 11 col= 2 ) Init G= 1.0109970674486802e-05  Target G= 0.0001  Final G= 0.00015167807103290973 Err= 5.167807103290973e-05
# Array 0 , device (row= 14 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001847507331378299 Err= 8.475073313782989e-05
# Array 0 , device (row= 16 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013229064841968068 Err= 3.229064841968068e-05
# Array 0 , device (row= 20 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00014825676115998697 Err= 4.825676115998696e-05
# Array 0 , device (row= 23 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013457152166829585 Err= 3.4571521668295846e-05
# Array 0 , device (row= 24 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002018572825024438 Err= 0.0001018572825024438
# Array 0 , device (row= 25 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002417725643532095 Err= 0.00014177256435320948
# Array 0 , device (row= 26 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 27 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017790811339198434 Err= 7.790811339198433e-05
# Array 0 , device (row= 28 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022352557836428802 Err= 0.00012352557836428803
# Array 0 , device (row= 29 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019729553600521344 Err= 9.729553600521344e-05
# Array 0 , device (row= 30 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 31 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 33 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002126914304333659 Err= 0.00011269143043336591
# Array 0 , device (row= 34 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 35 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013229064841968068 Err= 3.229064841968068e-05
# Array 0 , device (row= 37 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00018703160638644506 Err= 8.703160638644506e-05
# Array 0 , device (row= 38 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002275171065493646 Err= 0.0001275171065493646
# Array 0 , device (row= 40 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 42 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016479309221244703 Err= 6.479309221244703e-05
# Array 0 , device (row= 43 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 45 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 46 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002446236559139785 Err= 0.0001446236559139785
# Array 0 , device (row= 47 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001830400782013685 Err= 8.304007820136851e-05
# Array 0 , device (row= 48 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 53 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00025089605734767025 Err= 0.00015089605734767026
# Array 0 , device (row= 54 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 56 col= 2 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011176278918214398 Err= 1.1762789182143978e-05
# Array 0 , device (row= 1 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002121212121212121 Err= 0.0001121212121212121
# Array 0 , device (row= 5 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 8 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 9 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00026230042359074617 Err= 0.00016230042359074618
# Array 0 , device (row= 12 col= 3 ) Init G= 1.199169110459433e-05  Target G= 0.0001  Final G= 0.00015509938090583252 Err= 5.509938090583252e-05
# Array 0 , device (row= 13 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013685239491691107 Err= 3.685239491691107e-05
# Array 0 , device (row= 14 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 18 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00018703160638644506 Err= 8.703160638644506e-05
# Array 0 , device (row= 19 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001556695992179863 Err= 5.5669599217986304e-05
# Array 0 , device (row= 20 col= 3 ) Init G= 7.869012707722384e-06  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 21 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 22 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001847507331378299 Err= 8.475073313782989e-05
# Array 0 , device (row= 23 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019273378950798305 Err= 9.273378950798305e-05
# Array 0 , device (row= 24 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 26 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00024633431085043986 Err= 0.00014633431085043987
# Array 0 , device (row= 29 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 33 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 34 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016536331052460085 Err= 6.536331052460084e-05
# Array 0 , device (row= 37 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00024747474747474743 Err= 0.00014747474747474744
# Array 0 , device (row= 38 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022352557836428802 Err= 0.00012352557836428803
# Array 0 , device (row= 39 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 40 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00014825676115998697 Err= 4.825676115998696e-05
# Array 0 , device (row= 43 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002520364939719778 Err= 0.00015203649397197783
# Array 0 , device (row= 44 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00024861518409905506 Err= 0.00014861518409905506
# Array 0 , device (row= 45 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 46 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 49 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022010426849136525 Err= 0.00012010426849136525
# Array 0 , device (row= 52 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 55 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 57 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011176278918214398 Err= 1.1762789182143978e-05
# Array 0 , device (row= 60 col= 3 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002993646138807429 Err= 0.0001993646138807429
# Array 0 , device (row= 2 col= 4 ) Init G= 8.211143695014662e-07  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 6 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 7 col= 4 ) Init G= 2.189638318670577e-06  Target G= 0.0001  Final G= 0.00022010426849136525 Err= 0.00012010426849136525
# Array 0 , device (row= 8 col= 4 ) Init G= 5.81622678396872e-07  Target G= 0.0001  Final G= 0.0001710654936461388 Err= 7.10654936461388e-05
# Array 0 , device (row= 9 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 13 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022238514173998042 Err= 0.0001223851417399804
# Array 0 , device (row= 14 col= 4 ) Init G= 1.0109970674486802e-05  Target G= 0.0001  Final G= 0.0001282991202346041 Err= 2.82991202346041e-05
# Array 0 , device (row= 15 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 19 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001710654936461388 Err= 7.10654936461388e-05
# Array 0 , device (row= 23 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001573802541544477 Err= 5.738025415444769e-05
# Array 0 , device (row= 24 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022352557836428802 Err= 0.00012352557836428803
# Array 0 , device (row= 27 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00012088628217660475 Err= 2.0886282176604744e-05
# Array 0 , device (row= 28 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001163245356793744 Err= 1.6324535679374395e-05
# Array 0 , device (row= 29 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 31 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 39 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017790811339198434 Err= 7.790811339198433e-05
# Array 0 , device (row= 43 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011005213424568261 Err= 1.0052134245682609e-05
# Array 0 , device (row= 46 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 48 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019615509938090584 Err= 9.615509938090584e-05
# Array 0 , device (row= 49 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00020584881068752035 Err= 0.00010584881068752035
# Array 0 , device (row= 51 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 52 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017391658520690776 Err= 7.391658520690776e-05
# Array 0 , device (row= 53 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 55 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00018703160638644506 Err= 8.703160638644506e-05
# Array 0 , device (row= 58 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 59 col= 4 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011974584555229717 Err= 1.974584555229716e-05
# Array 0 , device (row= 1 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 2 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001573802541544477 Err= 5.738025415444769e-05
# Array 0 , device (row= 3 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 7 col= 5 ) Init G= 1.3394428152492668e-05  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 11 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 13 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002007168458781362 Err= 0.0001007168458781362
# Array 0 , device (row= 14 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001881720430107527 Err= 8.817204301075268e-05
# Array 0 , device (row= 15 col= 5 ) Init G= 5.645161290322581e-07  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 16 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 17 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002440534376018247 Err= 0.00014405343760182467
# Array 0 , device (row= 18 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022124470511567285 Err= 0.00012124470511567285
# Array 0 , device (row= 19 col= 5 ) Init G= 1.6422287390029323e-06  Target G= 0.0001  Final G= 0.00014825676115998697 Err= 4.825676115998696e-05
# Array 0 , device (row= 24 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 26 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 27 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 28 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001573802541544477 Err= 5.738025415444769e-05
# Array 0 , device (row= 29 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001847507331378299 Err= 8.475073313782989e-05
# Array 0 , device (row= 30 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011176278918214398 Err= 1.1762789182143978e-05
# Array 0 , device (row= 32 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 33 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 34 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 35 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002417725643532095 Err= 0.00014177256435320948
# Array 0 , device (row= 37 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000173346366894754 Err= 7.3346366894754e-05
# Array 0 , device (row= 40 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 43 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 44 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 46 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 48 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015509938090583252 Err= 5.509938090583252e-05
# Array 0 , device (row= 50 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 51 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 53 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 54 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 55 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011062235255783641 Err= 1.0622352557836408e-05
# Array 0 , device (row= 58 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00014654610622352558 Err= 4.654610622352558e-05
# Array 0 , device (row= 59 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 60 col= 5 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016536331052460085 Err= 6.536331052460084e-05
# Array 0 , device (row= 4 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001288693385467579 Err= 2.8869338546757886e-05
# Array 0 , device (row= 7 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002109807754969045 Err= 0.0001109807754969045
# Array 0 , device (row= 9 col= 6 ) Init G= 2.7370478983382186e-07  Target G= 0.0001  Final G= 0.00019387422613229065 Err= 9.387422613229064e-05
# Array 0 , device (row= 10 col= 6 ) Init G= 1.0948191593352885e-06  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 11 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002029977191267514 Err= 0.0001029977191267514
# Array 0 , device (row= 13 col= 6 ) Init G= 8.715786901270772e-05  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 14 col= 6 ) Init G= 1.163245356793744e-06  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 17 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001687846203975236 Err= 6.878462039752361e-05
# Array 0 , device (row= 18 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013913326816552624 Err= 3.9133268165526236e-05
# Array 0 , device (row= 19 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019159335288367548 Err= 9.159335288367548e-05
# Array 0 , device (row= 20 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00027142391658520695 Err= 0.00017142391658520696
# Array 0 , device (row= 22 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019159335288367548 Err= 9.159335288367548e-05
# Array 0 , device (row= 23 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001573802541544477 Err= 5.738025415444769e-05
# Array 0 , device (row= 25 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002423427826653633 Err= 0.0001423427826653633
# Array 0 , device (row= 27 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 29 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 30 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 31 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00021896383186705766 Err= 0.00011896383186705765
# Array 0 , device (row= 32 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 34 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 37 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00014825676115998697 Err= 4.825676115998696e-05
# Array 0 , device (row= 39 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 42 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Array 0 , device (row= 44 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001288693385467579 Err= 2.8869338546757886e-05
# Array 0 , device (row= 46 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011974584555229717 Err= 1.974584555229716e-05
# Array 0 , device (row= 47 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002144020853698273 Err= 0.00011440208536982729
# Array 0 , device (row= 48 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019159335288367548 Err= 9.159335288367548e-05
# Array 0 , device (row= 52 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 53 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 57 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00021896383186705766 Err= 0.00011896383186705765
# Array 0 , device (row= 59 col= 6 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000173346366894754 Err= 7.3346366894754e-05
# Array 0 , device (row= 4 col= 7 ) Init G= 1.7106549364613877e-06  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 5 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 6 col= 7 ) Init G= 5.474095796676442e-07  Target G= 0.0001  Final G= 0.00014825676115998697 Err= 4.825676115998696e-05
# Array 0 , device (row= 9 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002417725643532095 Err= 0.00014177256435320948
# Array 0 , device (row= 10 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 12 col= 7 ) Init G= 2.326490713587488e-06  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 15 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 17 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00018703160638644506 Err= 8.703160638644506e-05
# Array 0 , device (row= 18 col= 7 ) Init G= 3.4213098729227755e-06  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 22 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017562724014336914 Err= 7.562724014336914e-05
# Array 0 , device (row= 23 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001876018246985989 Err= 8.76018246985989e-05
# Array 0 , device (row= 24 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 28 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017448680351906155 Err= 7.448680351906154e-05
# Array 0 , device (row= 31 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 33 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 34 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 35 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013229064841968068 Err= 3.229064841968068e-05
# Array 0 , device (row= 38 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001881720430107527 Err= 8.817204301075268e-05
# Array 0 , device (row= 39 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 44 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011176278918214398 Err= 1.1762789182143978e-05
# Array 0 , device (row= 45 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00023721081785597914 Err= 0.00013721081785597914
# Array 0 , device (row= 47 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011005213424568261 Err= 1.0052134245682609e-05
# Array 0 , device (row= 49 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017562724014336914 Err= 7.562724014336914e-05
# Array 0 , device (row= 54 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 56 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000229227761485826 Err= 0.000129227761485826
# Array 0 , device (row= 57 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00019273378950798305 Err= 9.273378950798305e-05
# Array 0 , device (row= 59 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 60 col= 7 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013457152166829585 Err= 3.4571521668295846e-05
# Array 0 , device (row= 1 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 2 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00020413815575105894 Err= 0.00010413815575105894
# Array 0 , device (row= 3 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00012088628217660475 Err= 2.0886282176604744e-05
# Array 0 , device (row= 4 col= 8 ) Init G= 0.00016536331052460085  Target G= 0.0001  Final G= 0.00019273378950798305 Err= 9.273378950798305e-05
# Array 0 , device (row= 9 col= 8 ) Init G= 1.9501466275659822e-05  Target G= 0.0001  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Array 0 , device (row= 11 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 12 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001163245356793744 Err= 1.6324535679374395e-05
# Array 0 , device (row= 17 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00024633431085043986 Err= 0.00014633431085043987
# Array 0 , device (row= 18 col= 8 ) Init G= 1.0657380254154446e-05  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 26 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00021896383186705766 Err= 0.00011896383186705765
# Array 0 , device (row= 27 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00021896383186705766 Err= 0.00011896383186705765
# Array 0 , device (row= 28 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00020869990224828933 Err= 0.00010869990224828933
# Array 0 , device (row= 29 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015509938090583252 Err= 5.509938090583252e-05
# Array 0 , device (row= 30 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013799283154121867 Err= 3.7992831541218666e-05
# Array 0 , device (row= 32 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017562724014336914 Err= 7.562724014336914e-05
# Array 0 , device (row= 35 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001881720430107527 Err= 8.817204301075268e-05
# Array 0 , device (row= 36 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 37 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013685239491691107 Err= 3.685239491691107e-05
# Array 0 , device (row= 39 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 43 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 44 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 46 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 47 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 51 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 52 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 55 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002121212121212121 Err= 0.0001121212121212121
# Array 0 , device (row= 57 col= 8 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 1 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 3 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 4 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016536331052460085 Err= 6.536331052460084e-05
# Array 0 , device (row= 6 col= 9 ) Init G= 1.642228739002932e-05  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 7 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022124470511567285 Err= 0.00012124470511567285
# Array 0 , device (row= 8 col= 9 ) Init G= 1.0948191593352885e-06  Target G= 0.0001  Final G= 0.0002144020853698273 Err= 0.00011440208536982729
# Array 0 , device (row= 16 col= 9 ) Init G= 1.0948191593352885e-06  Target G= 0.0001  Final G= 0.00013685239491691107 Err= 3.685239491691107e-05
# Array 0 , device (row= 18 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001687846203975236 Err= 6.878462039752361e-05
# Array 0 , device (row= 19 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001830400782013685 Err= 8.304007820136851e-05
# Array 0 , device (row= 20 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001556695992179863 Err= 5.5669599217986304e-05
# Array 0 , device (row= 21 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00018703160638644506 Err= 8.703160638644506e-05
# Array 0 , device (row= 22 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 24 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 25 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015509938090583252 Err= 5.509938090583252e-05
# Array 0 , device (row= 26 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002429130009775171 Err= 0.0001429130009775171
# Array 0 , device (row= 28 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013685239491691107 Err= 3.685239491691107e-05
# Array 0 , device (row= 29 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022124470511567285 Err= 0.00012124470511567285
# Array 0 , device (row= 32 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000173346366894754 Err= 7.3346366894754e-05
# Array 0 , device (row= 33 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000229227761485826 Err= 0.000129227761485826
# Array 0 , device (row= 34 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 35 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001573802541544477 Err= 5.738025415444769e-05
# Array 0 , device (row= 37 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 38 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 39 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 44 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022352557836428802 Err= 0.00012352557836428803
# Array 0 , device (row= 47 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013685239491691107 Err= 3.685239491691107e-05
# Array 0 , device (row= 49 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001562398175301401 Err= 5.623981753014009e-05
# Array 0 , device (row= 53 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 60 col= 9 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 1 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022466601498859562 Err= 0.0001246660149885956
# Array 0 , device (row= 6 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 7 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002691430433365917 Err= 0.0001691430433365917
# Array 0 , device (row= 14 col= 10 ) Init G= 1.4027370478983381e-05  Target G= 0.0001  Final G= 0.00022580645161290321 Err= 0.00012580645161290322
# Array 0 , device (row= 15 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001288693385467579 Err= 2.8869338546757886e-05
# Array 0 , device (row= 16 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 22 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013457152166829585 Err= 3.4571521668295846e-05
# Array 0 , device (row= 23 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015281850765721733 Err= 5.2818507657217324e-05
# Array 0 , device (row= 24 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017448680351906155 Err= 7.448680351906154e-05
# Array 0 , device (row= 27 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00021896383186705766 Err= 0.00011896383186705765
# Array 0 , device (row= 29 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 32 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 33 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013229064841968068 Err= 3.229064841968068e-05
# Array 0 , device (row= 34 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00014825676115998697 Err= 4.825676115998696e-05
# Array 0 , device (row= 39 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 40 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016650374714890844 Err= 6.650374714890844e-05
# Array 0 , device (row= 42 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001300097751710655 Err= 3.0009775171065483e-05
# Array 0 , device (row= 43 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00023835125448028673 Err= 0.00013835125448028671
# Array 0 , device (row= 45 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 46 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 47 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015509938090583252 Err= 5.509938090583252e-05
# Array 0 , device (row= 48 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001300097751710655 Err= 3.0009775171065483e-05
# Array 0 , device (row= 51 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 52 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 53 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000173346366894754 Err= 7.3346366894754e-05
# Array 0 , device (row= 54 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011005213424568261 Err= 1.0052134245682609e-05
# Array 0 , device (row= 55 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015167807103290973 Err= 5.167807103290973e-05
# Array 0 , device (row= 56 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001288693385467579 Err= 2.8869338546757886e-05
# Array 0 , device (row= 57 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001847507331378299 Err= 8.475073313782989e-05
# Array 0 , device (row= 58 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 59 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 60 col= 10 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001151840990550668 Err= 1.5184099055066798e-05
# Array 0 , device (row= 1 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 2 col= 11 ) Init G= 5.474095796676442e-07  Target G= 0.0001  Final G= 0.00025089605734767025 Err= 0.00015089605734767026
# Array 0 , device (row= 5 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013685239491691107 Err= 3.685239491691107e-05
# Array 0 , device (row= 6 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 8 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 12 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 13 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00020527859237536654 Err= 0.00010527859237536654
# Array 0 , device (row= 15 col= 11 ) Init G= 1.6422287390029323e-06  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 16 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 19 col= 11 ) Init G= 5.474095796676442e-07  Target G= 0.0001  Final G= 0.00015509938090583252 Err= 5.509938090583252e-05
# Array 0 , device (row= 20 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016422287390029325 Err= 6.422287390029324e-05
# Array 0 , device (row= 22 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 27 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 29 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00022010426849136525 Err= 0.00012010426849136525
# Array 0 , device (row= 31 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011062235255783641 Err= 1.0622352557836408e-05
# Array 0 , device (row= 34 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011005213424568261 Err= 1.0052134245682609e-05
# Array 0 , device (row= 37 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013229064841968068 Err= 3.229064841968068e-05
# Array 0 , device (row= 39 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 45 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002144020853698273 Err= 0.00011440208536982729
# Array 0 , device (row= 48 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001687846203975236 Err= 6.878462039752361e-05
# Array 0 , device (row= 49 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 50 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 53 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 54 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 55 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001824698598892147 Err= 8.24698598892147e-05
# Array 0 , device (row= 56 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 57 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001471163245356794 Err= 4.711632453567939e-05
# Array 0 , device (row= 58 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00016650374714890844 Err= 6.650374714890844e-05
# Array 0 , device (row= 60 col= 11 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00026401107852720755 Err= 0.00016401107852720756
# Array 0 , device (row= 1 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 3 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013913326816552624 Err= 3.9133268165526236e-05
# Array 0 , device (row= 7 col= 12 ) Init G= 5.200391006842619e-06  Target G= 0.0001  Final G= 0.00011176278918214398 Err= 1.1762789182143978e-05
# Array 0 , device (row= 8 col= 12 ) Init G= 1.0948191593352885e-06  Target G= 0.0001  Final G= 0.00022124470511567285 Err= 0.00012124470511567285
# Array 0 , device (row= 11 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Array 0 , device (row= 13 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Array 0 , device (row= 16 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 18 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017562724014336914 Err= 7.562724014336914e-05
# Array 0 , device (row= 19 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 20 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 21 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00018931247963506029 Err= 8.931247963506028e-05
# Array 0 , device (row= 22 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001282991202346041 Err= 2.82991202346041e-05
# Array 0 , device (row= 23 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 24 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00017790811339198434 Err= 7.790811339198433e-05
# Array 0 , device (row= 27 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 28 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002144020853698273 Err= 0.00011440208536982729
# Array 0 , device (row= 29 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00013742261322906486 Err= 3.742261322906485e-05
# Array 0 , device (row= 31 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00020527859237536654 Err= 0.00010527859237536654
# Array 0 , device (row= 32 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 36 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001151840990550668 Err= 1.5184099055066798e-05
# Array 0 , device (row= 38 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001300097751710655 Err= 3.0009775171065483e-05
# Array 0 , device (row= 40 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001687846203975236 Err= 6.878462039752361e-05
# Array 0 , device (row= 41 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011860540892798957 Err= 1.8605408927989563e-05
# Array 0 , device (row= 42 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 44 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000173346366894754 Err= 7.3346366894754e-05
# Array 0 , device (row= 45 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 47 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001277289019224503 Err= 2.772890192245029e-05
# Array 0 , device (row= 50 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001693548387096774 Err= 6.935483870967739e-05
# Array 0 , device (row= 52 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00020527859237536654 Err= 0.00010527859237536654
# Array 0 , device (row= 53 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 55 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010948191593352881 Err= 9.48191593352881e-06
# Array 0 , device (row= 56 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00014825676115998697 Err= 4.825676115998696e-05
# Array 0 , device (row= 57 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00010092864125122187 Err= 9.286412512218698e-07
# Array 0 , device (row= 60 col= 12 ) Init G= 0.0  Target G= 0.0001  Final G= 0.000173346366894754 Err= 7.3346366894754e-05
# Array 0 , device (row= 1 col= 13 ) Init G= 6.842619745845546e-08  Target G= 0.0001  Final G= 0.00019273378950798305 Err= 9.273378950798305e-05
# Array 0 , device (row= 3 col= 13 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0001459758879113718 Err= 4.5975887911371794e-05
# Array 0 , device (row= 4 col= 13 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011404366243075916 Err= 1.404366243075916e-05
# Array 0 , device (row= 5 col= 13 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002326490713587488 Err= 0.0001326490713587488
# Array 0 , device (row= 6 col= 13 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00026230042359074617 Err= 0.00016230042359074618
# Array 0 , device (row= 11 col= 13 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00015053763440860216 Err= 5.0537634408602156e-05
# Array 0 , device (row= 12 col= 13 ) Init G= 0.0  Target G= 0.0001  Final G= 0.00011917562724014337 Err= 1.917562724014336e-05
# Array 0 , device (row= 15 col= 13 ) Init G= 0.0  Target G= 0.0001  Final G= 0.0002520364939719778 Err= 0.00015203649397197783
# Array 0 , device (row= 17 col= 13 ) Init G= 3.421309872922773e-08  Target G= 0.0001  Final G= 0.00016650374714890844 Err= 6.650374714890844e-05
# ...
# Array 0 , device (row= 21 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 23 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 28 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 31 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 35 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 38 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 39 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 40 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 41 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 42 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 43 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 44 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 45 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 50 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 57 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 59 col= 57 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 2 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 3 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 6 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 7 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 8 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 9 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 12 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 14 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 15 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 17 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 18 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 19 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 20 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 22 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 26 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 31 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 33 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 34 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 35 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 36 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 38 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 39 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 40 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 45 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 46 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 47 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 54 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 56 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 58 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 59 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 60 col= 58 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 2 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 3 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 8 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 9 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 11 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 12 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 14 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 16 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 17 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 18 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 21 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 22 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 24 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 27 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 29 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 30 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 32 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 34 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 37 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 38 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 39 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 42 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 44 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 46 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 50 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 52 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 57 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 58 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 59 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 60 col= 59 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 2 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 4 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 6 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 8 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 13 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 15 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 16 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 18 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 20 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 23 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 26 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 31 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 34 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 35 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 38 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 39 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 40 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 41 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 46 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 47 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 48 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 49 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 50 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 51 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 55 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 56 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 58 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 59 col= 60 ) Init G= 0.0  Target G= 3e-06  Final G= 0.0 Err= -3e-06
# Array 0 , device (row= 60 col= 60 ) Init G= 1.2316715542521993e-06  Target G= 3e-06  Final G= 1.2316715542521993e-06 Err= -1.7683284457478007e-06
# Saving In(<class 'list'>), Out(<class 'dict'>), PIC_PINS(<class 'dict'>), DAC_CH(<class 'dict'>), DAC_SPAN(<class 'dict'>), REFCLKO(<class 'dict'>), targetG(<class 'float'>), targetTolerance(<class 'float'>), vSetRamp(<class 'numpy.ndarray'>), vResetRamp(<class 'numpy.ndarray'>), vGateSetRamp(<class 'numpy.ndarray'>), vGateResetRamp(<class 'numpy.ndarray'>), array(<class 'int'>), maxLoops(<class 'int'>), finalGMatrix(<class 'numpy.ndarray'>), vAppliedSet(<class 'numpy.ndarray'>), vapp(<class 'numpy.float64'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vRead(<class 'float'>), arr(<class 'int'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), Vref(<class 'float'>), targetGFormed(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), rr(<class 'int'>), cc(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), rdCurr(<class 'float'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), rdCurrs(<class 'list'>), ts(<class 'float'>), color(<class 'str'>), g(<class 'numpy.ndarray'>), Vread(<class 'float'>), GMatrix(<class 'numpy.ndarray'>), rdCurrsBatch(<class 'list'>), IMatrix(<class 'numpy.ndarray'>), start_pic_time(<class 'float'>), pic_time(<class 'float'>), start_single_time(<class 'float'>), rd_single_time(<class 'float'>), targetRow(<class 'int'>), targetCol(<class 'int'>), finalG(<class 'float'>), numRows(<class 'int'>), numCols(<class 'int'>), Gmap0pre(<class 'numpy.ndarray'>), Gmap1pre(<class 'numpy.ndarray'>), mat_contents(<class 'dict'>), turnONRows(<class 'numpy.ndarray'>), turnONCols(<class 'numpy.ndarray'>), turnOFFRows(<class 'numpy.ndarray'>), turnOFFCols(<class 'numpy.ndarray'>), numDevices(<class 'int'>), numOFFDevices(<class 'int'>), targetGON(<class 'float'>), targetONTolerance(<class 'float'>), targetGOFF(<class 'float'>), targetOFFTolerance(<class 'float'>), ii(<class 'int'>), Gmap0post(<class 'numpy.ndarray'>), Gmap0postOFF(<class 'numpy.ndarray'>), Gmap1post(<class 'numpy.ndarray'>), Gmap1postOFF(<class 'numpy.ndarray'>), targetGraph0(<class 'numpy.ndarray'>), ar(<class 'int'>), r(<class 'int'>), c(<class 'int'>), Vgates(<class 'list'>), volts_set(<class 'list'>), volts(<class 'list'>), vread(<class 'numpy.float64'>), startRow(<class 'int'>), startCol(<class 'int'>), GMin(<class 'float'>), GMax(<class 'float'>), targetGVal(<class 'float'>), targetGThresh(<class 'float'>), thisGtarget(<class 'float'>), thisGainHistory(<class 'list'>), vReadGate(<class 'float'>), targetGValOFF(<class 'float'>), GHistoryOFF(<class 'list'>), VHistoryOFF(<class 'list'>), to 20191027-225816-RC1_Hopfield60_Graph0_ARRAY0_OFF.pkl
# Saving In(<class 'list'>), targetG(<class 'float'>), targetTolerance(<class 'float'>), vSetRamp(<class 'numpy.ndarray'>), vResetRamp(<class 'numpy.ndarray'>), vGateSetRamp(<class 'numpy.ndarray'>), vGateResetRamp(<class 'numpy.ndarray'>), array(<class 'int'>), maxLoops(<class 'int'>), finalGMatrix(<class 'numpy.ndarray'>), vAppliedSet(<class 'numpy.ndarray'>), vapp(<class 'numpy.float64'>), actualRows(<class 'numpy.ndarray'>), actualCols(<class 'numpy.ndarray'>), totalDevices(<class 'int'>), VreadGate(<class 'float'>), vRead(<class 'float'>), arr(<class 'int'>), vAppliedReset(<class 'numpy.ndarray'>), vGateSet(<class 'numpy.ndarray'>), vGateReset(<class 'numpy.ndarray'>), AllDevicesGHistory(<class 'list'>), AllDevicesVHistory(<class 'list'>), AllDevicesVGateHistory(<class 'list'>), Vref(<class 'float'>), targetGFormed(<class 'float'>), GTargetOFF(<class 'float'>), numRepeats(<class 'int'>), jj(<class 'int'>), rr(<class 'int'>), cc(<class 'int'>), GHistory(<class 'list'>), VHistory(<class 'list'>), VGateHistory(<class 'list'>), nn(<class 'int'>), thisGHistory(<class 'list'>), thisVHistory(<class 'list'>), thisVGateHistory(<class 'list'>), rdCurr(<class 'float'>), currG(<class 'float'>), initG(<class 'float'>), vgate(<class 'numpy.float64'>), vappset(<class 'numpy.float64'>), beforeRESETG(<class 'float'>), vappreset(<class 'numpy.float64'>), Vreads(<class 'numpy.ndarray'>), Vgate(<class 'int'>), rdCurrs(<class 'list'>), ts(<class 'float'>), color(<class 'str'>), g(<class 'numpy.ndarray'>), Vread(<class 'float'>), GMatrix(<class 'numpy.ndarray'>), rdCurrsBatch(<class 'list'>), IMatrix(<class 'numpy.ndarray'>), start_pic_time(<class 'float'>), pic_time(<class 'float'>), start_single_time(<class 'float'>), rd_single_time(<class 'float'>), targetRow(<class 'int'>), targetCol(<class 'int'>), finalG(<class 'float'>), numRows(<class 'int'>), numCols(<class 'int'>), Gmap0pre(<class 'numpy.ndarray'>), Gmap1pre(<class 'numpy.ndarray'>), turnONRows(<class 'numpy.ndarray'>), turnONCols(<class 'numpy.ndarray'>), turnOFFRows(<class 'numpy.ndarray'>), turnOFFCols(<class 'numpy.ndarray'>), numDevices(<class 'int'>), numOFFDevices(<class 'int'>), targetGON(<class 'float'>), targetONTolerance(<class 'float'>), targetGOFF(<class 'float'>), targetOFFTolerance(<class 'float'>), ii(<class 'int'>), Gmap0post(<class 'numpy.ndarray'>), Gmap0postOFF(<class 'numpy.ndarray'>), Gmap1post(<class 'numpy.ndarray'>), Gmap1postOFF(<class 'numpy.ndarray'>), targetGraph0(<class 'numpy.ndarray'>), ar(<class 'int'>), r(<class 'int'>), c(<class 'int'>), Vgates(<class 'list'>), volts_set(<class 'list'>), volts(<class 'list'>), vread(<class 'numpy.float64'>), startRow(<class 'int'>), startCol(<class 'int'>), GMin(<class 'float'>), GMax(<class 'float'>), targetGVal(<class 'float'>), targetGThresh(<class 'float'>), thisGtarget(<class 'float'>), thisGainHistory(<class 'list'>), vReadGate(<class 'float'>), targetGValOFF(<class 'float'>), GHistoryOFF(<class 'list'>), VHistoryOFF(<class 'list'>), to 20191027-225816-RC1_Hopfield60_Graph0_ARRAY0_OFF.mat

# %%
plt.imshow(Gmap0postOFF, clim=[0, 100])
plt.colorbar()

# %%
from lib_data import *
import scipy.io as sio
mat_contents = sio.loadmat('Exported60Node_GraphNum0.mat')
turnONRows = mat_contents['turnONRows']
turnONCols = mat_contents['turnONCols']
turnOFFRows = mat_contents['turnOFFRows']
turnOFFCols = mat_contents['turnOFFCols']

turnONRows=turnONRows[0]
turnONCols=turnONCols[0]
turnOFFRows=turnOFFRows[0]
turnOFFCols=turnOFFCols[0]

numDevices = np.size(turnONRows)
numOFFDevices = np.size(turnOFFRows)

vRead = 0.2

arr = 0
Vgate = 5
Vref = 0.5

targetGON = 100e-6
targetONTolerance = 3e-6
targetGOFF = 2.5e-6
targetOFFTolerance = 2.5e-6

vSetRamp = np.arange(0.4, 3.3, 0.1)
vGateSetRamp = np.arange(0.6, 1.4, 0.08)
vResetRamp = np.arange(0.3, 4.05, 0.25)
vGateResetRamp = np.arange(5.0, 5.5, 0.5)
maxLoops = 5

for ii in range(numDevices):
    rr = turnONRows[ii]
    cc = turnONCols[ii]        
    initG = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
    finalG = a0.cell_program(arr, rr, cc, targetGON, targetONTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)
    if ( (finalG >= (targetGON-targetONTolerance)) & (finalG <= (targetGON+targetONTolerance)) ):
        print('Success! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', finalG, 'Err=', (finalG-targetGON))
    else:
        print('Fail! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', finalG, 'Err=', (finalG-targetGON))
    
time.sleep(15)
arr = 0
numRows = 64
numCols = 64
Gmap0post = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap0post[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap0post)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RCLab1_Arr0_Hopfield60_G0_AfterON')


for ii in range(numOFFDevices):
    rr = turnOFFRows[ii]
    cc = turnOFFCols[ii]        
    initG = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1) / vRead
    finalG = a0.cell_program(arr, rr, cc, targetGOFF, targetOFFTolerance, vSetRamp, vResetRamp, vGateSetRamp, vGateResetRamp, maxLoops=maxLoops)
    if ( (finalG >= (targetGOFF-targetOFFTolerance)) & (finalG <= (targetGOFF+targetOFFTolerance)) ):
        print('Success! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', finalG, 'Err=', (finalG-targetGOFF))
    else:
        print('Fail! Array', arr, ', device (row=', rr, 'col=', cc, ') Init G=', initG, ' Final G=', finalG, 'Err=', (finalG-targetGOFF))
    
time.sleep(15)
arr = 0
numRows = 64
numCols = 64
Gmap0postOFF = np.zeros((numRows, numCols))
for rr in range(numRows):
        for cc in range(numCols):
            rdCurr = a0.pic_read_single(arr, rr, cc, Vread=vRead, Vgate=Vgate, gain=-1)  
            Gmap0postOFF[rr,cc] = 1e6*rdCurr/vRead
plt.imshow(Gmap0postOFF)
plt.colorbar()

time.sleep(15)
save_workspace(vars(), note='RCLab1_Arr0_Hopfield60_G0_AfterOFF')
# Out:
# Success! Array 0 , device (row= 2 col= 1 ) Init G= 4.379276637341154e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 3 col= 1 ) Init G= 8.185483870967741e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 5 col= 1 ) Init G= 9.579667644183771e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 8 col= 1 ) Init G= 7.5183284457478e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 9 col= 1 ) Init G= 0.00015167807103290973  Final G= 2.6344086021505373e-05 Err= -7.365591397849464e-05
# Fail! Array 0 , device (row= 10 col= 1 ) Init G= 8.040078201368523e-06  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 11 col= 1 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 12 col= 1 ) Init G= 0.0001824698598892147  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 13 col= 1 ) Init G= 4.7470674486803524e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 15 col= 1 ) Init G= 0.0002680026067122841  Final G= 9.237536656891495e-05 Err= -7.624633431085057e-06
# Success! Array 0 , device (row= 16 col= 1 ) Init G= 7.29879439556859e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 19 col= 1 ) Init G= 0.00014825676115998697  Final G= 1.1341642228739003e-05 Err= -8.8658357771261e-05
# Fail! Array 0 , device (row= 20 col= 1 ) Init G= 0.00010948191593352881  Final G= 9.237536656891495e-05 Err= -7.624633431085057e-06
# Fail! Array 0 , device (row= 24 col= 1 ) Init G= 0.00019159335288367548  Final G= 7.754969045291626e-05 Err= -2.2450309547083743e-05
# Fail! Array 0 , device (row= 27 col= 1 ) Init G= 9.186217008797652e-06  Final G= 6.637341153470185e-06 Err= -9.336265884652981e-05
# Fail! Array 0 , device (row= 30 col= 1 ) Init G= 0.00011860540892798957  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 31 col= 1 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 34 col= 1 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 35 col= 1 ) Init G= 4.233870967741935e-05  Final G= 7.116324535679374e-06 Err= -9.288367546432064e-05
# Success! Array 0 , device (row= 38 col= 1 ) Init G= 7.754969045291626e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 39 col= 1 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 40 col= 1 ) Init G= 0.0001573802541544477  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 44 col= 1 ) Init G= 8.211143695014662e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 46 col= 1 ) Init G= 0.00011860540892798957  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 47 col= 1 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 48 col= 1 ) Init G= 0.0002451938742261323  Final G= 7.766373411534701e-06 Err= -9.22336265884653e-05
# Fail! Array 0 , device (row= 50 col= 1 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 52 col= 1 ) Init G= 0.00015509938090583252  Final G= 5.6708211143695017e-05 Err= -4.329178885630499e-05
# Fail! Array 0 , device (row= 53 col= 1 ) Init G= 7.424242424242424e-06  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 54 col= 1 ) Init G= 1.7106549364613866e-08  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 57 col= 1 ) Init G= 3.917399804496578e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 58 col= 1 ) Init G= 0.00027370478983382215  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 59 col= 1 ) Init G= 2.189638318670577e-06  Final G= 3.558162267839687e-06 Err= -9.644183773216031e-05
# Fail! Array 0 , device (row= 60 col= 1 ) Init G= 0.00027655588139459104  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 1 col= 2 ) Init G= 0.00019159335288367548  Final G= 5.816226783968719e-06 Err= -9.418377321603128e-05
# Fail! Array 0 , device (row= 4 col= 2 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 5 col= 2 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 8 col= 2 ) Init G= 7.150537634408602e-06  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 11 col= 2 ) Init G= 0.0001459758879113718  Final G= 1.0281036168132942e-05 Err= -8.971896383186706e-05
# Fail! Array 0 , device (row= 14 col= 2 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 16 col= 2 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 20 col= 2 ) Init G= 0.00011404366243075916  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 23 col= 2 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 24 col= 2 ) Init G= 0.00016422287390029325  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 25 col= 2 ) Init G= 0.0002144020853698273  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Fail! Array 0 , device (row= 26 col= 2 ) Init G= 1.2539100684261973e-05  Final G= 7.65518084066471e-05 Err= -2.34481915933529e-05
# Fail! Array 0 , device (row= 27 col= 2 ) Init G= 0.0001710654936461388  Final G= 5.542521994134897e-06 Err= -9.445747800586511e-05
# Fail! Array 0 , device (row= 28 col= 2 ) Init G= 0.0002007168458781362  Final G= 5.474095796676441e-06 Err= -9.452590420332356e-05
# Fail! Array 0 , device (row= 29 col= 2 ) Init G= 0.0001459758879113718  Final G= 3.1818181818181814e-05 Err= -6.81818181818182e-05
# Fail! Array 0 , device (row= 30 col= 2 ) Init G= 4.6102150537634394e-05  Final G= 7.29879439556859e-05 Err= -2.7012056044314106e-05
# Success! Array 0 , device (row= 31 col= 2 ) Init G= 1.163245356793744e-06  Final G= 0.00010092864125122187 Err= 9.286412512218698e-07
# Fail! Array 0 , device (row= 33 col= 2 ) Init G= 0.00018931247963506029  Final G= 4.6273216031280534e-05 Err= -5.372678396871947e-05
# Fail! Array 0 , device (row= 34 col= 2 ) Init G= 0.0001163245356793744  Final G= 4.379276637341154e-06 Err= -9.562072336265884e-05
# Success! Array 0 , device (row= 35 col= 2 ) Init G= 6.842619745845546e-08  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 37 col= 2 ) Init G= 0.00018703160638644506  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 38 col= 2 ) Init G= 0.00022466601498859562  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 40 col= 2 ) Init G= 1.0657380254154446e-05  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Fail! Array 0 , device (row= 42 col= 2 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 43 col= 2 ) Init G= 7.595307917888563e-06  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Success! Array 0 , device (row= 45 col= 2 ) Init G= 0.00010948191593352881  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 46 col= 2 ) Init G= 0.0002651515151515151  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 47 col= 2 ) Init G= 0.0001573802541544477  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 48 col= 2 ) Init G= 3.079178885630498e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 53 col= 2 ) Init G= 0.0004168295861844249  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 54 col= 2 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 56 col= 2 ) Init G= 7.29879439556859e-05  Final G= 0.00010092864125122187 Err= 9.286412512218698e-07
# Fail! Array 0 , device (row= 1 col= 3 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 5 col= 3 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 8 col= 3 ) Init G= 0.00016650374714890844  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 9 col= 3 ) Init G= 0.0002754154447702835  Final G= 8.211143695014662e-05 Err= -1.788856304985338e-05
# Fail! Array 0 , device (row= 12 col= 3 ) Init G= 0.00023949169110459433  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Success! Array 0 , device (row= 13 col= 3 ) Init G= 0.0002109807754969045  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 14 col= 3 ) Init G= 0.00015509938090583252  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 18 col= 3 ) Init G= 0.00015110785272075595  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 19 col= 3 ) Init G= 0.00015509938090583252  Final G= 3.592375366568915e-05 Err= -6.407624633431085e-05
# Success! Array 0 , device (row= 20 col= 3 ) Init G= 0.0001459758879113718  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 21 col= 3 ) Init G= 8.202590420332356e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 22 col= 3 ) Init G= 8.211143695014662e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 23 col= 3 ) Init G= 0.0002018572825024438  Final G= 4.319403714565004e-05 Err= -5.6805962854349964e-05
# Fail! Array 0 , device (row= 24 col= 3 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 26 col= 3 ) Init G= 0.0002440534376018247  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 29 col= 3 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 33 col= 3 ) Init G= 1.0948191593352885e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 34 col= 3 ) Init G= 0.0002007168458781362  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 37 col= 3 ) Init G= 0.0001876018246985989  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 38 col= 3 ) Init G= 0.00015167807103290973  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 39 col= 3 ) Init G= 6.423509286412512e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 40 col= 3 ) Init G= 0.00013229064841968068  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 43 col= 3 ) Init G= 0.000229227761485826  Final G= 2.258064516129032e-05 Err= -7.741935483870968e-05
# Success! Array 0 , device (row= 44 col= 3 ) Init G= 0.00027427500814597585  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 45 col= 3 ) Init G= 5.876099706744868e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 46 col= 3 ) Init G= 8.040078201368523e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 49 col= 3 ) Init G= 0.00020984033887259693  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 52 col= 3 ) Init G= 9.351580319322253e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 55 col= 3 ) Init G= 7.35581622678397e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 57 col= 3 ) Init G= 7.38147605083089e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 60 col= 3 ) Init G= 0.00030563701531443466  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 2 col= 4 ) Init G= 8.202590420332356e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 6 col= 4 ) Init G= 7.620967741935484e-05  Final G= 3.4213098729227755e-05 Err= -6.578690127077226e-05
# Fail! Array 0 , device (row= 7 col= 4 ) Init G= 0.0002007168458781362  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Success! Array 0 , device (row= 8 col= 4 ) Init G= 9.123492994460735e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 9 col= 4 ) Init G= 0.0001277289019224503  Final G= 8.407869012707723e-05 Err= -1.592130987292277e-05
# Success! Array 0 , device (row= 13 col= 4 ) Init G= 0.000229227761485826  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 14 col= 4 ) Init G= 8.211143695014662e-05  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 15 col= 4 ) Init G= 6.816959921798631e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 19 col= 4 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 23 col= 4 ) Init G= 0.00016422287390029325  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 24 col= 4 ) Init G= 0.00020527859237536654  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 27 col= 4 ) Init G= 6.021505376344086e-06  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 28 col= 4 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 29 col= 4 ) Init G= 9.351580319322253e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 31 col= 4 ) Init G= 1.6422287390029323e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 39 col= 4 ) Init G= 1.3685239491691093e-07  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 43 col= 4 ) Init G= 6.834066471163244e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 46 col= 4 ) Init G= 1.0948191593352885e-05  Final G= 5.123411534701857e-05 Err= -4.8765884652981436e-05
# Fail! Array 0 , device (row= 48 col= 4 ) Init G= 1.0948191593352885e-06  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 49 col= 4 ) Init G= 6.526148582600194e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 51 col= 4 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 52 col= 4 ) Init G= 0.0  Final G= 3.96871945259042e-06 Err= -9.603128054740958e-05
# Success! Array 0 , device (row= 53 col= 4 ) Init G= 0.00013229064841968068  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 55 col= 4 ) Init G= 4.601661779081134e-05  Final G= 2.189638318670577e-05 Err= -7.810361681329423e-05
# Success! Array 0 , device (row= 58 col= 4 ) Init G= 1.3685239491691093e-07  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 59 col= 4 ) Init G= 0.0001459758879113718  Final G= 5.431329423264906e-05 Err= -4.568670576735094e-05
# Fail! Array 0 , device (row= 1 col= 5 ) Init G= 0.00015053763440860216  Final G= 3.908846529814272e-05 Err= -6.091153470185729e-05
# Fail! Array 0 , device (row= 2 col= 5 ) Init G= 0.0  Final G= 3.284457478005865e-05 Err= -6.715542521994135e-05
# Fail! Array 0 , device (row= 3 col= 5 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 7 col= 5 ) Init G= 1.0948191593352885e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 11 col= 5 ) Init G= 7.928885630498534e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 13 col= 5 ) Init G= 0.00017562724014336914  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 14 col= 5 ) Init G= 0.0002007168458781362  Final G= 8.091397849462365e-06 Err= -9.190860215053764e-05
# Fail! Array 0 , device (row= 15 col= 5 ) Init G= 6.218230694037146e-05  Final G= 4.105571847507332e-06 Err= -9.589442815249267e-05
# Fail! Array 0 , device (row= 16 col= 5 ) Init G= 6.0129521016617795e-05  Final G= 4.516129032258065e-06 Err= -9.548387096774195e-05
# Success! Array 0 , device (row= 17 col= 5 ) Init G= 0.0002121212121212121  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 18 col= 5 ) Init G= 0.00013229064841968068  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 19 col= 5 ) Init G= 0.00011404366243075916  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 24 col= 5 ) Init G= 9.351580319322253e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 26 col= 5 ) Init G= 4.541788856304985e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 27 col= 5 ) Init G= 2.258064516129032e-05  Final G= 5.200391006842619e-06 Err= -9.479960899315739e-05
# Fail! Array 0 , device (row= 28 col= 5 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 29 col= 5 ) Init G= 2.189638318670577e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 30 col= 5 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 32 col= 5 ) Init G= 3.575268817204301e-05  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Fail! Array 0 , device (row= 33 col= 5 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 34 col= 5 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 35 col= 5 ) Init G= 0.0002497556207233626  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 37 col= 5 ) Init G= 0.00013685239491691107  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 40 col= 5 ) Init G= 0.0001277289019224503  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 43 col= 5 ) Init G= 1.2316715542521993e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 44 col= 5 ) Init G= 0.00022580645161290321  Final G= 2.7370478983382186e-07 Err= -9.972629521016618e-05
# Fail! Array 0 , device (row= 46 col= 5 ) Init G= 1.2436461388074291e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 48 col= 5 ) Init G= 2.8054740957966762e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 50 col= 5 ) Init G= 0.00011860540892798957  Final G= 1.2316715542521993e-06 Err= -9.87683284457478e-05
# Success! Array 0 , device (row= 51 col= 5 ) Init G= 9.117790811339198e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 53 col= 5 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 54 col= 5 ) Init G= 8.741446725317692e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 55 col= 5 ) Init G= 6.816959921798631e-05  Final G= 7.754969045291626e-05 Err= -2.2450309547083743e-05
# Fail! Array 0 , device (row= 58 col= 5 ) Init G= 0.0  Final G= 9.351580319322253e-05 Err= -6.484196806777473e-06
# Success! Array 0 , device (row= 59 col= 5 ) Init G= 0.00022808732486151836  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 60 col= 5 ) Init G= 0.00023835125448028673  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 4 col= 6 ) Init G= 1.0948191593352885e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 7 col= 6 ) Init G= 0.00010035842293906808  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 9 col= 6 ) Init G= 0.00019387422613229065  Final G= 7.039345063538612e-05 Err= -2.9606549364613886e-05
# Success! Array 0 , device (row= 10 col= 6 ) Init G= 7.586754643206256e-05  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Success! Array 0 , device (row= 11 col= 6 ) Init G= 0.00015053763440860216  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 13 col= 6 ) Init G= 0.00013229064841968068  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 14 col= 6 ) Init G= 0.0001163245356793744  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Success! Array 0 , device (row= 17 col= 6 ) Init G= 4.7727272727272724e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 18 col= 6 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 19 col= 6 ) Init G= 7.928885630498534e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 20 col= 6 ) Init G= 0.000285109156076898  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 22 col= 6 ) Init G= 0.0  Final G= 9.351580319322253e-05 Err= -6.484196806777473e-06
# Fail! Array 0 , device (row= 23 col= 6 ) Init G= 0.0  Final G= 2.4633431085043987e-06 Err= -9.753665689149561e-05
# Fail! Array 0 , device (row= 25 col= 6 ) Init G= 0.0001459758879113718  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 27 col= 6 ) Init G= 4.456256109481915e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 29 col= 6 ) Init G= 0.0001277289019224503  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 30 col= 6 ) Init G= 0.0  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Fail! Array 0 , device (row= 31 col= 6 ) Init G= 0.00020641902899967414  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 32 col= 6 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 34 col= 6 ) Init G= 0.00011404366243075916  Final G= 5.217497556207233e-06 Err= -9.478250244379278e-05
# Fail! Array 0 , device (row= 37 col= 6 ) Init G= 0.0  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Success! Array 0 , device (row= 39 col= 6 ) Init G= 8.749999999999999e-05  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 42 col= 6 ) Init G= 0.00010035842293906808  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 44 col= 6 ) Init G= 9.237536656891495e-05  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Success! Array 0 , device (row= 46 col= 6 ) Init G= 9.237536656891495e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 47 col= 6 ) Init G= 0.00022466601498859562  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 48 col= 6 ) Init G= 0.0001847507331378299  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 52 col= 6 ) Init G= 0.00011176278918214398  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 53 col= 6 ) Init G= 4.7299608993157385e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 57 col= 6 ) Init G= 9.123492994460735e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 59 col= 6 ) Init G= 0.00018703160638644506  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 4 col= 7 ) Init G= 0.00010948191593352881  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 5 col= 7 ) Init G= 3.695014662756598e-05  Final G= 8.211143695014662e-05 Err= -1.788856304985338e-05
# Success! Array 0 , device (row= 6 col= 7 ) Init G= 3.695014662756598e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 9 col= 7 ) Init G= 0.0001881720430107527  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 10 col= 7 ) Init G= 4.30229716520039e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 12 col= 7 ) Init G= 7.928885630498534e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 15 col= 7 ) Init G= 7.869012707722384e-06  Final G= 1.4369501466275657e-05 Err= -8.563049853372434e-05
# Fail! Array 0 , device (row= 17 col= 7 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 18 col= 7 ) Init G= 1.6422287390029323e-06  Final G= 7.754969045291626e-05 Err= -2.2450309547083743e-05
# Success! Array 0 , device (row= 22 col= 7 ) Init G= 0.00023949169110459433  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 23 col= 7 ) Init G= 5.944525904203324e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 24 col= 7 ) Init G= 4.721407624633431e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 28 col= 7 ) Init G= 2.4633431085043987e-05  Final G= 8.211143695014662e-05 Err= -1.788856304985338e-05
# Success! Array 0 , device (row= 31 col= 7 ) Init G= 8.211143695014662e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 33 col= 7 ) Init G= 5.7050342130987296e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 34 col= 7 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 35 col= 7 ) Init G= 0.00013229064841968068  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 38 col= 7 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 39 col= 7 ) Init G= 7.107771260997068e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 44 col= 7 ) Init G= 0.00011860540892798957  Final G= 7.039345063538612e-05 Err= -2.9606549364613886e-05
# Fail! Array 0 , device (row= 45 col= 7 ) Init G= 0.00016536331052460085  Final G= 7.800586510263928e-06 Err= -9.219941348973608e-05
# Success! Array 0 , device (row= 47 col= 7 ) Init G= 0.00010948191593352881  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 49 col= 7 ) Init G= 0.0001710654936461388  Final G= 5.474095796676442e-07 Err= -9.945259042033236e-05
# Fail! Array 0 , device (row= 54 col= 7 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 56 col= 7 ) Init G= 0.00026344086021505374  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 57 col= 7 ) Init G= 0.00011860540892798957  Final G= 8.211143695014662e-05 Err= -1.788856304985338e-05
# Fail! Array 0 , device (row= 59 col= 7 ) Init G= 0.00014654610622352558  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 60 col= 7 ) Init G= 7.38147605083089e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 1 col= 8 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 2 col= 8 ) Init G= 0.0002457640925382861  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 3 col= 8 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 4 col= 8 ) Init G= 0.00016422287390029325  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 9 col= 8 ) Init G= 7.65518084066471e-05  Final G= 7.29879439556859e-05 Err= -2.7012056044314106e-05
# Fail! Array 0 , device (row= 11 col= 8 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 12 col= 8 ) Init G= 1.1119257086999025e-05  Final G= 0.00010092864125122187 Err= 9.286412512218698e-07
# Success! Array 0 , device (row= 17 col= 8 ) Init G= 0.00011176278918214398  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 18 col= 8 ) Init G= 0.00011404366243075916  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 26 col= 8 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 27 col= 8 ) Init G= 0.00019615509938090584  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 28 col= 8 ) Init G= 0.00022808732486151836  Final G= 1.67644183773216e-06 Err= -9.832355816226784e-05
# Fail! Array 0 , device (row= 29 col= 8 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 30 col= 8 ) Init G= 9.123492994460735e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 32 col= 8 ) Init G= 0.0002429130009775171  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 35 col= 8 ) Init G= 0.00011860540892798957  Final G= 2.4633431085043987e-05 Err= -7.536656891495602e-05
# Success! Array 0 , device (row= 36 col= 8 ) Init G= 0.0001710654936461388  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 37 col= 8 ) Init G= 0.0001836102965135223  Final G= 2.6344086021505373e-05 Err= -7.365591397849464e-05
# Success! Array 0 , device (row= 39 col= 8 ) Init G= 6.158357771260997e-07  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 43 col= 8 ) Init G= 6.842619745845546e-08  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 44 col= 8 ) Init G= 0.00013799283154121867  Final G= 4.199657869012707e-05 Err= -5.8003421309872935e-05
# Fail! Array 0 , device (row= 46 col= 8 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 47 col= 8 ) Init G= 1.0948191593352885e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 51 col= 8 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 52 col= 8 ) Init G= 6.560361681329422e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 55 col= 8 ) Init G= 0.00022466601498859562  Final G= 1.9159335288367544e-06 Err= -9.808406647116325e-05
# Success! Array 0 , device (row= 57 col= 8 ) Init G= 7.412838057999348e-05  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 1 col= 9 ) Init G= 6.423509286412512e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 3 col= 9 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 4 col= 9 ) Init G= 0.0001459758879113718  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 6 col= 9 ) Init G= 1.0948191593352885e-05  Final G= 6.252443792766374e-05 Err= -3.747556207233627e-05
# Fail! Array 0 , device (row= 7 col= 9 ) Init G= 5.474095796676442e-07  Final G= 7.526881720430108e-05 Err= -2.4731182795698924e-05
# Success! Array 0 , device (row= 8 col= 9 ) Init G= 0.00010948191593352881  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 16 col= 9 ) Init G= 1.3685239491691102e-06  Final G= 4.901026392961877e-05 Err= -5.098973607038124e-05
# Fail! Array 0 , device (row= 18 col= 9 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 19 col= 9 ) Init G= 2.189638318670577e-06  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 20 col= 9 ) Init G= 7.412838057999348e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 21 col= 9 ) Init G= 0.0001824698598892147  Final G= 2.189638318670577e-05 Err= -7.810361681329423e-05
# Fail! Array 0 , device (row= 22 col= 9 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 24 col= 9 ) Init G= 9.123492994460735e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 25 col= 9 ) Init G= 0.00018931247963506029  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 26 col= 9 ) Init G= 0.00017790811339198434  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 28 col= 9 ) Init G= 7.754969045291626e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 29 col= 9 ) Init G= 0.00013685239491691107  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 32 col= 9 ) Init G= 7.313049853372434e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 33 col= 9 ) Init G= 0.0002029977191267514  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 34 col= 9 ) Init G= 6.0129521016617795e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 35 col= 9 ) Init G= 0.00021041055718475072  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 37 col= 9 ) Init G= 6.491935483870966e-05  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Fail! Array 0 , device (row= 38 col= 9 ) Init G= 0.00021896383186705766  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 39 col= 9 ) Init G= 0.0  Final G= 4.114125122189638e-05 Err= -5.8858748778103626e-05
# Fail! Array 0 , device (row= 44 col= 9 ) Init G= 0.0002662919517758227  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Fail! Array 0 , device (row= 47 col= 9 ) Init G= 0.0001459758879113718  Final G= 8.74144672531769e-06 Err= -9.125855327468232e-05
# Success! Array 0 , device (row= 49 col= 9 ) Init G= 7.754969045291626e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 53 col= 9 ) Init G= 7.894672531769306e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 60 col= 9 ) Init G= 1.3685239491691104e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 1 col= 10 ) Init G= 0.00027370478983382215  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 6 col= 10 ) Init G= 8.211143695014662e-07  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 7 col= 10 ) Init G= 0.0002457640925382861  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 14 col= 10 ) Init G= 0.00021953405017921144  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 15 col= 10 ) Init G= 1.7790811339198436e-05  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Success! Array 0 , device (row= 16 col= 10 ) Init G= 9.123492994460735e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 22 col= 10 ) Init G= 0.0001824698598892147  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 23 col= 10 ) Init G= 0.0  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Success! Array 0 , device (row= 24 col= 10 ) Init G= 0.0002007168458781362  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 27 col= 10 ) Init G= 8.442082111436949e-05  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Success! Array 0 , device (row= 29 col= 10 ) Init G= 3.0193059628543497e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 32 col= 10 ) Init G= 0.0  Final G= 8.211143695014662e-05 Err= -1.788856304985338e-05
# Fail! Array 0 , device (row= 33 col= 10 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 34 col= 10 ) Init G= 3.489736070381231e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 39 col= 10 ) Init G= 0.0001596611274030629  Final G= 3.2844574780058646e-06 Err= -9.671554252199414e-05
# Fail! Array 0 , device (row= 40 col= 10 ) Init G= 0.00010948191593352881  Final G= 5.816226783968719e-06 Err= -9.418377321603128e-05
# Success! Array 0 , device (row= 42 col= 10 ) Init G= 8.211143695014662e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 43 col= 10 ) Init G= 0.00022580645161290321  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 45 col= 10 ) Init G= 8.749999999999999e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 46 col= 10 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 47 col= 10 ) Init G= 2.3264907135874877e-05  Final G= 9.767839687194525e-06 Err= -9.023216031280548e-05
# Fail! Array 0 , device (row= 48 col= 10 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 51 col= 10 ) Init G= 8.749999999999999e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 52 col= 10 ) Init G= 7.039345063538612e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 53 col= 10 ) Init G= 6.295210166177908e-06  Final G= 7.107771260997068e-05 Err= -2.8922287390029328e-05
# Success! Array 0 , device (row= 54 col= 10 ) Init G= 6.269550342130987e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 55 col= 10 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 56 col= 10 ) Init G= 0.0001277289019224503  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 57 col= 10 ) Init G= 0.00019387422613229065  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 58 col= 10 ) Init G= 0.0001277289019224503  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 59 col= 10 ) Init G= 1.3685239491691104e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 60 col= 10 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 1 col= 11 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 2 col= 11 ) Init G= 0.00026058976865428473  Final G= 1.3685239491691104e-05 Err= -8.63147605083089e-05
# Fail! Array 0 , device (row= 5 col= 11 ) Init G= 0.00013742261322906486  Final G= 5.063538611925708e-06 Err= -9.49364613880743e-05
# Fail! Array 0 , device (row= 6 col= 11 ) Init G= 3.35288367546432e-05  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Fail! Array 0 , device (row= 8 col= 11 ) Init G= 0.0001459758879113718  Final G= 7.29879439556859e-05 Err= -2.7012056044314106e-05
# Fail! Array 0 , device (row= 12 col= 11 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 13 col= 11 ) Init G= 0.00018703160638644506  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 15 col= 11 ) Init G= 0.00010948191593352881  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 16 col= 11 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 19 col= 11 ) Init G= 9.579667644183771e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 20 col= 11 ) Init G= 0.0  Final G= 5.474095796676442e-07 Err= -9.945259042033236e-05
# Fail! Array 0 , device (row= 22 col= 11 ) Init G= 7.29879439556859e-05  Final G= 5.191837732160313e-05 Err= -4.808162267839688e-05
# Success! Array 0 , device (row= 27 col= 11 ) Init G= 3.216031280547409e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 29 col= 11 ) Init G= 0.00020984033887259693  Final G= 2.3350439882697946e-05 Err= -7.664956011730206e-05
# Fail! Array 0 , device (row= 31 col= 11 ) Init G= 2.7370478983382186e-07  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 34 col= 11 ) Init G= 2.5317693059628545e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 37 col= 11 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 39 col= 11 ) Init G= 1.3120723362658846e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 45 col= 11 ) Init G= 0.00011176278918214398  Final G= 3.2844574780058646e-06 Err= -9.671554252199414e-05
# Success! Array 0 , device (row= 48 col= 11 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 49 col= 11 ) Init G= 0.00013229064841968068  Final G= 3.4213098729227755e-06 Err= -9.657869012707723e-05
# Fail! Array 0 , device (row= 50 col= 11 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 53 col= 11 ) Init G= 9.425708699902249e-06  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 54 col= 11 ) Init G= 0.00010948191593352881  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 55 col= 11 ) Init G= 1.1615347018572826e-05  Final G= 6.560361681329422e-05 Err= -3.439638318670578e-05
# Fail! Array 0 , device (row= 56 col= 11 ) Init G= 2.189638318670577e-06  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 57 col= 11 ) Init G= 0.0001459758879113718  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 58 col= 11 ) Init G= 7.313049853372434e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 60 col= 11 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 1 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 3 col= 12 ) Init G= 9.22043010752688e-06  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Fail! Array 0 , device (row= 7 col= 12 ) Init G= 4.13978494623656e-05  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 8 col= 12 ) Init G= 0.00015509938090583252  Final G= 7.29879439556859e-05 Err= -2.7012056044314106e-05
# Fail! Array 0 , device (row= 11 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 13 col= 12 ) Init G= 0.00011404366243075916  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 16 col= 12 ) Init G= 1.67644183773216e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 18 col= 12 ) Init G= 3.4213098729227755e-06  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 19 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 20 col= 12 ) Init G= 0.00011860540892798957  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 21 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 22 col= 12 ) Init G= 4.045698924731182e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 23 col= 12 ) Init G= 0.00013685239491691107  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 24 col= 12 ) Init G= 0.00013229064841968068  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 27 col= 12 ) Init G= 5.474095796676442e-07  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 28 col= 12 ) Init G= 0.00022010426849136525  Final G= 9.351580319322253e-05 Err= -6.484196806777473e-06
# Fail! Array 0 , device (row= 29 col= 12 ) Init G= 4.216764418377321e-05  Final G= 7.928885630498534e-05 Err= -2.0711143695014667e-05
# Fail! Array 0 , device (row= 31 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 32 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 36 col= 12 ) Init G= 8.065738025415444e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 38 col= 12 ) Init G= 9.237536656891495e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 40 col= 12 ) Init G= 0.000173346366894754  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 41 col= 12 ) Init G= 6.423509286412512e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 42 col= 12 ) Init G= 9.123492994460735e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 44 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 45 col= 12 ) Init G= 0.00012088628217660475  Final G= 1.6422287390029323e-06 Err= -9.835777126099708e-05
# Success! Array 0 , device (row= 47 col= 12 ) Init G= 8.749999999999999e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 50 col= 12 ) Init G= 0.00017562724014336914  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 52 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 53 col= 12 ) Init G= 3.643695014662756e-05  Final G= 0.00010092864125122187 Err= 9.286412512218698e-07
# Fail! Array 0 , device (row= 55 col= 12 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 56 col= 12 ) Init G= 8.202590420332356e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 57 col= 12 ) Init G= 1.0948191593352885e-06  Final G= 3.9601661779081136e-05 Err= -6.039833822091887e-05
# Success! Array 0 , device (row= 60 col= 12 ) Init G= 0.0002029977191267514  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 1 col= 13 ) Init G= 0.0002554578038449006  Final G= 4.233870967741935e-05 Err= -5.7661290322580655e-05
# Success! Array 0 , device (row= 3 col= 13 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 4 col= 13 ) Init G= 0.00014825676115998697  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 5 col= 13 ) Init G= 0.00011404366243075916  Final G= 7.107771260997068e-05 Err= -2.8922287390029328e-05
# Fail! Array 0 , device (row= 6 col= 13 ) Init G= 0.0002554578038449006  Final G= 7.754969045291626e-05 Err= -2.2450309547083743e-05
# Fail! Array 0 , device (row= 11 col= 13 ) Init G= 1.2504887585532747e-05  Final G= 1.4369501466275657e-05 Err= -8.563049853372434e-05
# Fail! Array 0 , device (row= 12 col= 13 ) Init G= 1.6764418377321598e-05  Final G= 1.0109970674486802e-05 Err= -8.98900293255132e-05
# Success! Array 0 , device (row= 15 col= 13 ) Init G= 0.0002121212121212121  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 17 col= 13 ) Init G= 3.0449657869012707e-05  Final G= 2.805474095796676e-06 Err= -9.719452590420333e-05
# Success! Array 0 , device (row= 18 col= 13 ) Init G= 6.286656891495602e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 26 col= 13 ) Init G= 0.00024633431085043986  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 28 col= 13 ) Init G= 0.0  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 30 col= 13 ) Init G= 0.00028282828282828287  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 31 col= 13 ) Init G= 0.0003119094167481263  Final G= 1.4027370478983381e-05 Err= -8.597262952101662e-05
# Fail! Array 0 , device (row= 34 col= 13 ) Init G= 0.0001824698598892147  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 37 col= 13 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 38 col= 13 ) Init G= 0.0  Final G= 5.474095796676442e-07 Err= -9.945259042033236e-05
# Fail! Array 0 , device (row= 39 col= 13 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 41 col= 13 ) Init G= 0.000173346366894754  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 43 col= 13 ) Init G= 0.00016536331052460085  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 46 col= 13 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 48 col= 13 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 49 col= 13 ) Init G= 0.0  Final G= 1.642228739002932e-05 Err= -8.357771260997068e-05
# Fail! Array 0 , device (row= 51 col= 13 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 55 col= 13 ) Init G= 3.2844574780058646e-06  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 57 col= 13 ) Init G= 0.0  Final G= 9.579667644183771e-05 Err= -4.203323558162292e-06
# Fail! Array 0 , device (row= 58 col= 13 ) Init G= 0.00011176278918214398  Final G= 1.9501466275659822e-05 Err= -8.049853372434018e-05
# Fail! Array 0 , device (row= 59 col= 13 ) Init G= 9.351580319322253e-05  Final G= 8.211143695014662e-07 Err= -9.917888563049853e-05
# Success! Array 0 , device (row= 2 col= 14 ) Init G= 6.491935483870966e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 3 col= 14 ) Init G= 5.4227761485825995e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 4 col= 14 ) Init G= 6.680107526881719e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 5 col= 14 ) Init G= 3.087732160312805e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 6 col= 14 ) Init G= 1.642228739002932e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 10 col= 14 ) Init G= 0.0  Final G= 7.869012707722385e-05 Err= -2.130987292277616e-05
# ...
# Fail! Array 0 , device (row= 10 col= 29 ) Init G= 0.0  Final G= 3.96871945259042e-06 Err= -9.603128054740958e-05
# Fail! Array 0 , device (row= 11 col= 29 ) Init G= 1.3685239491691104e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 12 col= 29 ) Init G= 6.970918866080156e-05  Final G= 7.526881720430108e-05 Err= -2.4731182795698924e-05
# Fail! Array 0 , device (row= 16 col= 29 ) Init G= 0.00013229064841968068  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 20 col= 29 ) Init G= 8.211143695014662e-07  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 22 col= 29 ) Init G= 2.4633431085043987e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 28 col= 29 ) Init G= 1.3685239491691093e-07  Final G= 1.642228739002932e-05 Err= -8.357771260997068e-05
# Success! Array 0 , device (row= 30 col= 29 ) Init G= 4.704301075268817e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 31 col= 29 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 34 col= 29 ) Init G= 0.00017448680351906155  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 36 col= 29 ) Init G= 7.754969045291626e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 37 col= 29 ) Init G= 0.00013685239491691107  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 38 col= 29 ) Init G= 0.00026230042359074617  Final G= 8.339442815249268e-05 Err= -1.660557184750733e-05
# Success! Array 0 , device (row= 39 col= 29 ) Init G= 8.211143695014662e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 40 col= 29 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 44 col= 29 ) Init G= 0.00011062235255783641  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 45 col= 29 ) Init G= 0.0001277289019224503  Final G= 8.442082111436949e-05 Err= -1.557917888563052e-05
# Fail! Array 0 , device (row= 47 col= 29 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 50 col= 29 ) Init G= 0.00011404366243075916  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 51 col= 29 ) Init G= 0.000173346366894754  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 53 col= 29 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 56 col= 29 ) Init G= 0.00013685239491691107  Final G= 6.765640273704788e-05 Err= -3.234359726295212e-05
# Success! Array 0 , device (row= 57 col= 29 ) Init G= 0.0001459758879113718  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 58 col= 29 ) Init G= 0.00015053763440860216  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 60 col= 29 ) Init G= 0.0  Final G= 4.781280547409579e-05 Err= -5.2187194525904215e-05
# Success! Array 0 , device (row= 1 col= 30 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 2 col= 30 ) Init G= 2.189638318670577e-06  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 5 col= 30 ) Init G= 9.579667644183771e-05  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Fail! Array 0 , device (row= 6 col= 30 ) Init G= 0.0001699250570218312  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 8 col= 30 ) Init G= 0.0002240957966764418  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 13 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 16 col= 30 ) Init G= 0.0002674323884001303  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 17 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 18 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 19 col= 30 ) Init G= 1.9159335288367544e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 20 col= 30 ) Init G= 2.7370478983382186e-07  Final G= 2.4975562072336266e-05 Err= -7.502443792766374e-05
# Success! Array 0 , device (row= 22 col= 30 ) Init G= 7.107771260997068e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 24 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 28 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 29 col= 30 ) Init G= 9.579667644183771e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 31 col= 30 ) Init G= 0.0001277289019224503  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 32 col= 30 ) Init G= 0.0002109807754969045  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 38 col= 30 ) Init G= 2.8396871945259045e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 39 col= 30 ) Init G= 0.00011176278918214398  Final G= 4.91813294232649e-05 Err= -5.0818670576735104e-05
# Fail! Array 0 , device (row= 41 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 43 col= 30 ) Init G= 0.00015053763440860216  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Fail! Array 0 , device (row= 48 col= 30 ) Init G= 3.0193059628543497e-05  Final G= 9.237536656891495e-05 Err= -7.624633431085057e-06
# Fail! Array 0 , device (row= 49 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 50 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 52 col= 30 ) Init G= 1.0948191593352885e-05  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 53 col= 30 ) Init G= 5.00366568914956e-05  Final G= 9.237536656891495e-05 Err= -7.624633431085057e-06
# Fail! Array 0 , device (row= 54 col= 30 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 55 col= 30 ) Init G= 9.630987292277615e-06  Final G= 2.5659824046920818e-05 Err= -7.434017595307918e-05
# Fail! Array 0 , device (row= 57 col= 30 ) Init G= 0.00022124470511567285  Final G= 6.158357771260997e-06 Err= -9.3841642228739e-05
# Success! Array 0 , device (row= 58 col= 30 ) Init G= 9.180514825676115e-05  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Success! Array 0 , device (row= 60 col= 30 ) Init G= 0.00010035842293906808  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 1 col= 31 ) Init G= 6.14980449657869e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 2 col= 31 ) Init G= 0.0001277289019224503  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 4 col= 31 ) Init G= 0.0002303681981101336  Final G= 1.7106549364613877e-05 Err= -8.289345063538612e-05
# Success! Array 0 , device (row= 6 col= 31 ) Init G= 1.0948191593352885e-06  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 7 col= 31 ) Init G= 7.039345063538612e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 11 col= 31 ) Init G= 0.00013685239491691107  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 12 col= 31 ) Init G= 0.0003244542196155099  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Success! Array 0 , device (row= 13 col= 31 ) Init G= 0.00026344086021505374  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 14 col= 31 ) Init G= 0.00023949169110459433  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 17 col= 31 ) Init G= 8.749999999999999e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 18 col= 31 ) Init G= 1.3685239491691093e-07  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 21 col= 31 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 22 col= 31 ) Init G= 0.0002303681981101336  Final G= 9.494134897360703e-06 Err= -9.05058651026393e-05
# Success! Array 0 , device (row= 23 col= 31 ) Init G= 1.642228739002932e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 25 col= 31 ) Init G= 6.560361681329422e-05  Final G= 5.4227761485825995e-05 Err= -4.577223851417401e-05
# Success! Array 0 , device (row= 28 col= 31 ) Init G= 0.00011860540892798957  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 29 col= 31 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 30 col= 31 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 32 col= 31 ) Init G= 0.0001459758879113718  Final G= 1.1119257086999025e-05 Err= -8.888074291300098e-05
# Fail! Array 0 , device (row= 34 col= 31 ) Init G= 9.186217008797652e-06  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 37 col= 31 ) Init G= 5.380009775171064e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 40 col= 31 ) Init G= 0.0002685728250244379  Final G= 2.189638318670577e-05 Err= -7.810361681329423e-05
# Success! Array 0 , device (row= 41 col= 31 ) Init G= 2.5317693059628545e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 43 col= 31 ) Init G= 0.00018931247963506029  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 44 col= 31 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 45 col= 31 ) Init G= 1.0948191593352885e-06  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 46 col= 31 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 47 col= 31 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 48 col= 31 ) Init G= 0.00030050505050505046  Final G= 6.56891495601173e-06 Err= -9.343108504398827e-05
# Success! Array 0 , device (row= 49 col= 31 ) Init G= 9.579667644183771e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 50 col= 31 ) Init G= 5.431329423264906e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 51 col= 31 ) Init G= 1.4027370478983381e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 52 col= 31 ) Init G= 8.476295210166177e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 54 col= 31 ) Init G= 9.579667644183771e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 56 col= 31 ) Init G= 1.3685239491691102e-06  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 59 col= 31 ) Init G= 8.749999999999999e-05  Final G= 1.0383675464320624e-05 Err= -8.961632453567938e-05
# Success! Array 0 , device (row= 5 col= 32 ) Init G= 0.0  Final G= 0.00010092864125122187 Err= 9.286412512218698e-07
# Success! Array 0 , device (row= 6 col= 32 ) Init G= 3.3186705767350924e-05  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 8 col= 32 ) Init G= 0.0  Final G= 9.123492994460735e-05 Err= -8.765070055392654e-06
# Fail! Array 0 , device (row= 9 col= 32 ) Init G= 1.0298142717497554e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 10 col= 32 ) Init G= 0.00021896383186705766  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Success! Array 0 , device (row= 12 col= 32 ) Init G= 0.00010149885956337567  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 14 col= 32 ) Init G= 7.412838057999348e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 17 col= 32 ) Init G= 2.7370478983382207e-05  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Success! Array 0 , device (row= 19 col= 32 ) Init G= 8.43923101987618e-05  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 20 col= 32 ) Init G= 0.000173346366894754  Final G= 7.754969045291626e-05 Err= -2.2450309547083743e-05
# Fail! Array 0 , device (row= 21 col= 32 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 23 col= 32 ) Init G= 0.00019729553600521344  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 24 col= 32 ) Init G= 1.0075757575757576e-05  Final G= 3.0107526881720428e-05 Err= -6.989247311827958e-05
# Fail! Array 0 , device (row= 30 col= 32 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 31 col= 32 ) Init G= 0.00023492994460736394  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 33 col= 32 ) Init G= 0.00024006190941674814  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 38 col= 32 ) Init G= 7.983056370153144e-05  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 40 col= 32 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 41 col= 32 ) Init G= 6.081378299120235e-05  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Success! Array 0 , device (row= 44 col= 32 ) Init G= 0.0002776963180188986  Final G= 9.807754969045291e-05 Err= -1.9224503095470967e-06
# Fail! Array 0 , device (row= 49 col= 32 ) Init G= 0.0001881720430107527  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 50 col= 32 ) Init G= 0.0001459758879113718  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Success! Array 0 , device (row= 51 col= 32 ) Init G= 6.953812316715543e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 52 col= 32 ) Init G= 7.38147605083089e-05  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 53 col= 32 ) Init G= 3.3870967741935475e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 54 col= 32 ) Init G= 0.0  Final G= 3.558162267839687e-05 Err= -6.441837732160314e-05
# Fail! Array 0 , device (row= 57 col= 32 ) Init G= 5.474095796676442e-07  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 58 col= 32 ) Init G= 0.0001687846203975236  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Success! Array 0 , device (row= 60 col= 32 ) Init G= 7.928885630498534e-05  Final G= 0.00010263929618768326 Err= 2.6392961876832525e-06
# Fail! Array 0 , device (row= 2 col= 33 ) Init G= 0.00011860540892798957  Final G= 1.659335288367546e-05 Err= -8.340664711632455e-05
# Fail! Array 0 , device (row= 3 col= 33 ) Init G= 7.894672531769306e-05  Final G= 1.7790811339198436e-05 Err= -8.220918866080157e-05
# Fail! Array 0 , device (row= 5 col= 33 ) Init G= 0.0  Final G= 4.379276637341154e-06 Err= -9.562072336265884e-05
# Fail! Array 0 , device (row= 7 col= 33 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 9 col= 33 ) Init G= 7.928885630498534e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 10 col= 33 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
# Fail! Array 0 , device (row= 14 col= 33 ) Init G= 0.00020527859237536654  Final G= 7.347262952101662e-05 Err= -2.6527370478983387e-05
# Fail! Array 0 , device (row= 15 col= 33 ) Init G= 0.0002440534376018247  Final G= 7.29879439556859e-05 Err= -2.7012056044314106e-05
# Success! Array 0 , device (row= 16 col= 33 ) Init G= 5.474095796676442e-07  Final G= 0.00010149885956337567 Err= 1.4988595633756686e-06
# Success! Array 0 , device (row= 18 col= 33 ) Init G= 0.0  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 21 col= 33 ) Init G= 0.00018703160638644506  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 22 col= 33 ) Init G= 0.00021896383186705766  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 25 col= 33 ) Init G= 0.0001824698598892147  Final G= 0.0 Err= -0.0001
# Success! Array 0 , device (row= 27 col= 33 ) Init G= 9.123492994460735e-05  Final G= 0.00010035842293906808 Err= 3.584229390680711e-07
# Fail! Array 0 , device (row= 32 col= 33 ) Init G= 0.0  Final G= 0.0 Err= -0.0001
